# %%
# !pip install yfinance
# !pip install TA-Lib
# !pip install numpy
# !pip install pandas
# !pip install vectorbt
# !pip install scipy
# %pip install scikit-optimize
# %pip install optuna

# %%
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import vectorbt as vbt
import warnings
from scipy import stats
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", message="Degrees of freedom <= 0 for slice", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="invalid value encountered in scalar divide", category=RuntimeWarning)

# %%
# DOWNLOAD STOCK DATA FROM 2018 USING YFINANCE

TICKER = 'TQQQ'
START_DATE = '2010-01-01'
TRAIN_RATIO = 0.6
# Download data
stock_data = yf.download(TICKER, start=START_DATE, interval='1d')

if not stock_data.empty:
    print(f"Successfully downloaded {len(stock_data)} records for {TICKER}")
    print(f"Data range: {stock_data.index.min().date()} to {stock_data.index.max().date()}")
else:
    print(f"Failed to download {TICKER} data")

stock_data
# Out:
# C:\Users\harka\AppData\Local\Temp\ipykernel_4356\1714875129.py:7: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Successfully downloaded 1966 records for TQQQ
# Data range: 2018-01-02 to 2025-10-27
# Price            Close        High         Low        Open    Volume
# Ticker            TQQQ        TQQQ        TQQQ        TQQQ      TQQQ
# Date
# 2018-01-02   11.621360   11.645266   11.147231   11.227713  45867600
# 2018-01-03   11.961617   12.005444   11.666779   11.668374  42612000
# 2018-01-04   12.031743   12.144896   11.989509   12.101866  35012400
# 2018-01-05   12.395106   12.421403   12.136925   12.199877  41190000
# 2018-01-08   12.532965   12.558464   12.381561   12.393514  36126000
# ...                ...         ...         ...         ...       ...
# 2025-10-21  107.769997  108.480003  106.669998  107.900002  39905700
# 2025-10-22  104.599998  107.739998  101.580002  107.449997  67190400
# 2025-10-23  107.220001  107.629997  104.080002  104.269997  45622500
# 2025-10-24  110.559998  111.260002  109.529999  109.989998  42044500
# 2025-10-27  116.430000  116.690002  114.270103  114.514000  38256099
#
# [1966 rows x 5 columns]

# %%
# PREPARE PRICE SERIES

def select_close_series(df, ticker):
    if isinstance(df.columns, pd.MultiIndex):
        if ('Close', ticker) in df.columns:
            s = df[('Close', ticker)]
        else:
            cols = [c for c in df.columns if 'Close' in str(c)]
            if not cols:
                raise KeyError("Close not found")
            s = df[cols[0]]
    else:
        s = df['Close']
    return s.astype(float).squeeze()

close = select_close_series(stock_data, TICKER)
close.name = 'price'

# Simple split

split_idx = int(len(close) * TRAIN_RATIO)
train_close = close.iloc[:split_idx].copy()
val_close = close.iloc[split_idx:].copy()

print(f"Data ready: train={train_close.index[0].date()} → {train_close.index[-1].date()} | val={val_close.index[0].date()} → {val_close.index[-1].date()}")
# Out:
# Data ready: train=2018-01-02 → 2022-09-07 | val=2022-09-08 → 2025-10-27

# %% [markdown]
# # Triple EMA Strategy - NO RSI FILTER
#
# This notebook optimizes a **pure Triple EMA crossover strategy** without RSI confirmation.
#
# **Strategy Logic**: Buy when any EMA crosses above another. Sell when any EMA crosses below another.
#
# No additional filters - pure trend-following approach.

# %%
# Define Parameter Ranges for Triple EMA Optimization (NO RSI)

param_bounds = {
    'ema1': (4, 39),    # Fast EMA (shortest-term)
    'ema2': (50, 89),   # Medium EMA (medium-term) 
    'ema3': (120, 249), # Slow EMA (longest-term)
}

print("Parameter Bounds for Optimization (Daily Data):")
print(f"  EMA1 (Fast): {param_bounds['ema1'][0]} - {param_bounds['ema1'][1]} periods")
print(f"  EMA2 (Medium): {param_bounds['ema2'][0]} - {param_bounds['ema2'][1]} periods")
print(f"  EMA3 (Slow): {param_bounds['ema3'][0]} - {param_bounds['ema3'][1]} periods")

# Constraint: ema1 < ema2 < ema3
def is_valid_params(ema1, ema2, ema3):
    return ema1 < ema2 < ema3

print(f"\nConstraint: EMA1 < EMA2 < EMA3")
print("✅ Ready for optimization!")
# Out:
# Parameter Bounds for Optimization (Daily Data):
#   EMA1 (Fast): 4 - 39 periods
#   EMA2 (Medium): 50 - 89 periods
#   EMA3 (Slow): 120 - 249 periods
#
# Constraint: EMA1 < EMA2 < EMA3
# ✅ Ready for optimization!

# %%
# Core Optimization Function for Triple EMA Strategy (NO RSI FILTER)

def evaluate_triple_ema_strategy(params, data=train_close, return_metrics=False):
    """
    Evaluate Triple EMA crossover strategy WITHOUT RSI filter.
    
    Args:
        params: tuple of (ema1, ema2, ema3) periods
        data: price data to test on
        return_metrics: if True, return full metrics dict; if False, return negative Sortino ratio
    
    Returns:
        Negative Sortino ratio (for minimization) or full metrics dict
    """
    ema1_period, ema2_period, ema3_period = params
    
    # Validate parameter constraints
    if not is_valid_params(ema1_period, ema2_period, ema3_period):
        return 999.0  # Large penalty for invalid parameters
    
    try:
        # Calculate EMAs
        ema1 = vbt.MA.run(data, ema1_period, ewm=True)
        ema2 = vbt.MA.run(data, ema2_period, ewm=True)
        ema3 = vbt.MA.run(data, ema3_period, ewm=True)
        
        # Generate EMA crossover signals (NO RSI FILTER)
        entries = (
            ema1.ma_crossed_above(ema2.ma) |
            ema1.ma_crossed_above(ema3.ma) |
            ema2.ma_crossed_above(ema3.ma)
        )
        exits = (
            ema1.ma_crossed_below(ema2.ma) |
            ema1.ma_crossed_below(ema3.ma) |
            ema2.ma_crossed_below(ema3.ma)
        )
        
        # Convert to arrays
        entries_array = pd.Series(np.asarray(entries).ravel(), index=data.index, dtype=bool)
        exits_array = pd.Series(np.asarray(exits).ravel(), index=data.index, dtype=bool)
        
        # Backtest
        portfolio = vbt.Portfolio.from_signals(
            close=data,
            entries=entries_array,
            exits=exits_array,
            init_cash=100_000,
            fees=0.0005,
            slippage=0.0005,
            freq='D'
        )
        
        # Calculate key metrics
        sharpe_ratio = float(portfolio.sharpe_ratio(freq='D'))
        sortino_ratio = float(portfolio.sortino_ratio(freq='D'))
        total_return = float(portfolio.total_return())
        max_drawdown = float(portfolio.max_drawdown())
        volatility = float(portfolio.annualized_volatility(freq='D'))
        
        # Trade metrics
        trades = portfolio.trades
        total_trades = len(trades)
        
        # Check for sufficient trading activity
        years = max((data.index[-1] - data.index[0]).days / 365.25, 1e-9)
        trades_per_year = total_trades / years
        
        if trades_per_year < 1:  # Too few trades
            if return_metrics:
                return {
                    'ema1_period': ema1_period,
                    'ema2_period': ema2_period,
                    'ema3_period': ema3_period,
                    'sharpe_ratio': np.nan,
                    'sortino_ratio': np.nan,
                    'total_return': np.nan,
                    'annualized_return': np.nan,
                    'max_drawdown': np.nan,
                    'volatility': np.nan,
                    'total_trades': total_trades,
                    'win_rate': np.nan,
                    'profit_factor': np.nan,
                    'expectancy': np.nan,
                    'trades_per_year': trades_per_year
                }
            return 999.0
        
        if return_metrics:
            # Calculate additional metrics
            win_rate_pct = np.nan
            profit_factor = np.nan
            expectancy = 0.0
            annualized_return = (1.0 + total_return) ** (1.0 / years) - 1.0 if years > 0 else np.nan
            
            if total_trades > 0:
                tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
                if tr.size > 0:
                    pos = tr[tr > 0]
                    neg = tr[tr < 0]
                    win_rate_pct = (len(pos) / len(tr)) * 100.0
                    gains = pos.sum() if len(pos) else 0.0
                    losses = abs(neg.sum()) if len(neg) else 0.0
                    profit_factor = (gains / losses) if losses > 0 else np.inf
                    expectancy = float(tr.mean())
            
            return {
                'ema1_period': ema1_period,
                'ema2_period': ema2_period,
                'ema3_period': ema3_period,
                'sharpe_ratio': sharpe_ratio,
                'sortino_ratio': sortino_ratio,
                'total_return': total_return,
                'annualized_return': annualized_return,
                'max_drawdown': max_drawdown,
                'volatility': volatility,
                'total_trades': total_trades,
                'win_rate': win_rate_pct,
                'profit_factor': profit_factor,
                'expectancy': expectancy,
                'trades_per_year': trades_per_year
            }
        else:
            # Return negative Sortino for minimization
            return -sortino_ratio
            
    except Exception as e:
        return 999.0  # Large penalty for errors

print("✅ Core optimization function created - NO RSI FILTER!")
print("Function evaluates Triple EMA strategy without any confirmation filter.")
# Out:
# ✅ Core optimization function created - NO RSI FILTER!
# Function evaluates Triple EMA strategy without any confirmation filter.

# %%
# Import optimization libraries
try:
    from skopt import gp_minimize
    from skopt.space import Real
    from skopt.utils import use_named_args
    SKOPT_AVAILABLE = True
except ImportError:
    SKOPT_AVAILABLE = False

try:
    import optuna
    OPTUNA_AVAILABLE = True
except ImportError:
    OPTUNA_AVAILABLE = False

print(f"scikit-optimize: {'✅' if SKOPT_AVAILABLE else '❌'}")
print(f"Optuna: {'✅' if OPTUNA_AVAILABLE else '❌'}")
# Out:
# scikit-optimize: ✅
# Optuna: ✅

# %%
# OPTUNA OPTIMIZATION - Pure 3EMA Strategy

print("=" * 70)
print("OPTUNA OPTIMIZATION: Triple EMA Strategy (NO RSI FILTER)")
print(f"Training Period: {train_close.index[0].date()} → {train_close.index[-1].date()}")
print("=" * 70)

optimization_results = []
evaluation_count = 0

def objective(trial):
    """Optuna objective function - NO RSI."""
    global evaluation_count
    evaluation_count += 1
    
    # Suggest parameters (NO RSI threshold)
    ema1 = trial.suggest_int('ema1', param_bounds['ema1'][0], param_bounds['ema1'][1])
    ema2 = trial.suggest_int('ema2', param_bounds['ema2'][0], param_bounds['ema2'][1])
    ema3 = trial.suggest_int('ema3', param_bounds['ema3'][0], param_bounds['ema3'][1])
    
    # Validate constraints
    if not is_valid_params(ema1, ema2, ema3):
        return 999.0
    
    # Evaluate strategy (params is now just 3 values, not 4)
    result = evaluate_triple_ema_strategy((ema1, ema2, ema3))
    
    # Debug output
    if result == 999.0 and evaluation_count <= 5:
        print(f"Trial {evaluation_count}: EMA({ema1},{ema2},{ema3}) → No valid trades")
    elif evaluation_count % 10 == 0 or result != 999.0:
        print(f"Trial {evaluation_count}: EMA({ema1},{ema2},{ema3}) → Sortino: {-result:.3f}")
    
    return result

if OPTUNA_AVAILABLE:
    # Create study
    study = optuna.create_study(
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
    )
    
    print("\nStarting Optuna optimization...\n")
    
    study.optimize(objective, n_trials=1000, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params
    best_ema1 = best_params['ema1']
    best_ema2 = best_params['ema2']
    best_ema3 = best_params['ema3']
    best_sortino = -study.best_value
    
    # Evaluate best parameters to get full metrics
    best_result = evaluate_triple_ema_strategy(
        (best_ema1, best_ema2, best_ema3), 
        return_metrics=True
    )
    
    # Create results dataframe
    results_df = pd.DataFrame([best_result])
    
    print("\n✅ Optimization complete!")
    print(f"Best Parameters: EMA({best_ema1},{best_ema2},{best_ema3})")
    print(f"Sortino Ratio: {best_sortino:.3f}")
    
else:
    print("❌ Optuna not available")
# Out:
# [I 2025-10-27 23:00:52,648] A new study created in memory with name: no-name-9ee1fb28-0e54-4382-947a-d36033eadc25
# ======================================================================
# OPTUNA OPTIMIZATION: Triple EMA Strategy (NO RSI FILTER)
# Training Period: 2018-01-02 → 2022-09-07
# ======================================================================
#
# Starting Optuna optimization...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Trial 1: EMA(17,88,215) → Sortino: 1.130
# [I 2025-10-27 23:01:00,524] Trial 0 finished with value: -1.1304127359790836 and parameters: {'ema1': 17, 'ema2': 88, 'ema3': 215}. Best is trial 0 with value: -1.1304127359790836.
# Trial 2: EMA(25,56,140) → Sortino: 0.691
# [I 2025-10-27 23:01:00,618] Trial 1 finished with value: -0.6913087185304836 and parameters: {'ema1': 25, 'ema2': 56, 'ema3': 140}. Best is trial 0 with value: -1.1304127359790836.
# Trial 3: EMA(6,84,198) → Sortino: 0.889
# [I 2025-10-27 23:01:00,703] Trial 2 finished with value: -0.8894151251747183 and parameters: {'ema1': 6, 'ema2': 84, 'ema3': 198}. Best is trial 0 with value: -1.1304127359790836.
# Trial 4: EMA(29,50,246) → Sortino: 0.695
# [I 2025-10-27 23:01:00,804] Trial 3 finished with value: -0.6949150021943784 and parameters: {'ema1': 29, 'ema2': 50, 'ema3': 246}. Best is trial 0 with value: -1.1304127359790836.
# Trial 5: EMA(33,58,143) → Sortino: 1.011
# [I 2025-10-27 23:01:00,888] Trial 4 finished with value: -1.0105676410247117 and parameters: {'ema1': 33, 'ema2': 58, 'ema3': 143}. Best is trial 0 with value: -1.1304127359790836.
# Trial 6: EMA(10,62,188) → Sortino: 0.906
# [I 2025-10-27 23:01:00,962] Trial 5 finished with value: -0.9056372659407627 and parameters: {'ema1': 10, 'ema2': 62, 'ema3': 188}. Best is trial 0 with value: -1.1304127359790836.
# Trial 7: EMA(19,61,199) → Sortino: 0.893
# [I 2025-10-27 23:01:01,056] Trial 6 finished with value: -0.8930261564426865 and parameters: {'ema1': 19, 'ema2': 61, 'ema3': 199}. Best is trial 0 with value: -1.1304127359790836.
# Trial 8: EMA(9,61,167) → Sortino: 0.575
# [I 2025-10-27 23:01:01,145] Trial 7 finished with value: -0.5745173748858169 and parameters: {'ema1': 9, 'ema2': 61, 'ema3': 167}. Best is trial 0 with value: -1.1304127359790836.
# Trial 9: EMA(20,81,145) → Sortino: 1.131
# [I 2025-10-27 23:01:01,250] Trial 8 finished with value: -1.130824671317598 and parameters: {'ema1': 20, 'ema2': 81, 'ema3': 145}. Best is trial 8 with value: -1.130824671317598.
# Trial 10: EMA(22,73,126) → Sortino: 0.989
# [I 2025-10-27 23:01:01,338] Trial 9 finished with value: -0.9889511884065537 and parameters: {'ema1': 22, 'ema2': 73, 'ema3': 126}. Best is trial 8 with value: -1.130824671317598.
# [I 2025-10-27 23:01:01,435] Trial 10 finished with value: 999.0 and parameters: {'ema1': 38, 'ema2': 77, 'ema3': 161}. Best is trial 8 with value: -1.130824671317598.
# Trial 12: EMA(16,89,231) → Sortino: 1.236
# [I 2025-10-27 23:01:01,531] Trial 11 finished with value: -1.2355894548370479 and parameters: {'ema1': 16, 'ema2': 89, 'ema3': 231}. Best is trial 11 with value: -1.2355894548370479.
# Trial 13: EMA(14,81,243) → Sortino: 0.882
# [I 2025-10-27 23:01:01,683] Trial 12 finished with value: -0.8817773573079676 and parameters: {'ema1': 14, 'ema2': 81, 'ema3': 243}. Best is trial 11 with value: -1.2355894548370479.
# [I 2025-10-27 23:01:01,842] Trial 13 finished with value: 999.0 and parameters: {'ema1': 26, 'ema2': 89, 'ema3': 220}. Best is trial 11 with value: -1.2355894548370479.
# Trial 15: EMA(14,69,165) → Sortino: 0.805
# [I 2025-10-27 23:01:01,975] Trial 14 finished with value: -0.8048805221271265 and parameters: {'ema1': 14, 'ema2': 69, 'ema3': 165}. Best is trial 11 with value: -1.2355894548370479.
# Trial 16: EMA(22,82,224) → Sortino: 1.122
# [I 2025-10-27 23:01:02,072] Trial 15 finished with value: -1.1219608013529887 and parameters: {'ema1': 22, 'ema2': 82, 'ema3': 224}. Best is trial 11 with value: -1.2355894548370479.
# Trial 17: EMA(15,76,178) → Sortino: 1.109
# [I 2025-10-27 23:01:02,153] Trial 16 finished with value: -1.109150026118526 and parameters: {'ema1': 15, 'ema2': 76, 'ema3': 178}. Best is trial 11 with value: -1.2355894548370479.
# Trial 18: EMA(4,69,126) → Sortino: 0.622
# [I 2025-10-27 23:01:02,255] Trial 17 finished with value: -0.6217505620714299 and parameters: {'ema1': 4, 'ema2': 69, 'ema3': 126}. Best is trial 11 with value: -1.2355894548370479.
# Trial 19: EMA(19,85,147) → Sortino: 1.245
# [I 2025-10-27 23:01:02,373] Trial 18 finished with value: -1.244693632401888 and parameters: {'ema1': 19, 'ema2': 85, 'ema3': 147}. Best is trial 18 with value: -1.244693632401888.
# Trial 20: EMA(11,86,206) → Sortino: 1.072
# [I 2025-10-27 23:01:02,507] Trial 19 finished with value: -1.0723757660143112 and parameters: {'ema1': 11, 'ema2': 86, 'ema3': 206}. Best is trial 18 with value: -1.244693632401888.
# Trial 21: EMA(30,77,232) → Sortino: 0.933
# [I 2025-10-27 23:01:02,640] Trial 20 finished with value: -0.9328225971125841 and parameters: {'ema1': 30, 'ema2': 77, 'ema3': 232}. Best is trial 18 with value: -1.244693632401888.
# Trial 22: EMA(19,81,149) → Sortino: 1.184
# [I 2025-10-27 23:01:02,749] Trial 21 finished with value: -1.1838531853431935 and parameters: {'ema1': 19, 'ema2': 81, 'ema3': 149}. Best is trial 18 with value: -1.244693632401888.
# Trial 23: EMA(17,85,155) → Sortino: 1.081
# [I 2025-10-27 23:01:02,884] Trial 22 finished with value: -1.0811821296049406 and parameters: {'ema1': 17, 'ema2': 85, 'ema3': 155}. Best is trial 18 with value: -1.244693632401888.
# Trial 24: EMA(24,89,184) → Sortino: 0.901
# [I 2025-10-27 23:01:03,006] Trial 23 finished with value: -0.9011585150847444 and parameters: {'ema1': 24, 'ema2': 89, 'ema3': 184}. Best is trial 18 with value: -1.244693632401888.
# Trial 25: EMA(18,79,174) → Sortino: 0.942
# [I 2025-10-27 23:01:03,090] Trial 24 finished with value: -0.9423085965273972 and parameters: {'ema1': 18, 'ema2': 79, 'ema3': 174}. Best is trial 18 with value: -1.244693632401888.
# Trial 26: EMA(12,73,120) → Sortino: 0.832
# [I 2025-10-27 23:01:03,181] Trial 25 finished with value: -0.8315998826146158 and parameters: {'ema1': 12, 'ema2': 73, 'ema3': 120}. Best is trial 18 with value: -1.244693632401888.
# Trial 27: EMA(22,84,154) → Sortino: 1.120
# [I 2025-10-27 23:01:03,303] Trial 26 finished with value: -1.1197068353099446 and parameters: {'ema1': 22, 'ema2': 84, 'ema3': 154}. Best is trial 18 with value: -1.244693632401888.
# Trial 28: EMA(15,86,136) → Sortino: 0.959
# [I 2025-10-27 23:01:03,402] Trial 27 finished with value: -0.9592259704745589 and parameters: {'ema1': 15, 'ema2': 86, 'ema3': 136}. Best is trial 18 with value: -1.244693632401888.
# Trial 29: EMA(28,74,151) → Sortino: 1.194
# [I 2025-10-27 23:01:03,506] Trial 28 finished with value: -1.193893267726268 and parameters: {'ema1': 28, 'ema2': 74, 'ema3': 151}. Best is trial 18 with value: -1.244693632401888.
# Trial 30: EMA(28,66,211) → Sortino: 0.951
# [I 2025-10-27 23:01:03,613] Trial 29 finished with value: -0.9509703359022413 and parameters: {'ema1': 28, 'ema2': 66, 'ema3': 211}. Best is trial 18 with value: -1.244693632401888.
# [I 2025-10-27 23:01:03,713] Trial 30 finished with value: 999.0 and parameters: {'ema1': 34, 'ema2': 87, 'ema3': 234}. Best is trial 18 with value: -1.244693632401888.
# Trial 32: EMA(19,75,154) → Sortino: 0.800
# [I 2025-10-27 23:01:03,816] Trial 31 finished with value: -0.7995081363527716 and parameters: {'ema1': 19, 'ema2': 75, 'ema3': 154}. Best is trial 18 with value: -1.244693632401888.
# Trial 33: EMA(25,80,137) → Sortino: 1.208
# [I 2025-10-27 23:01:03,942] Trial 32 finished with value: -1.2077752114757725 and parameters: {'ema1': 25, 'ema2': 80, 'ema3': 137}. Best is trial 18 with value: -1.244693632401888.
# Trial 34: EMA(26,84,135) → Sortino: 0.944
# [I 2025-10-27 23:01:04,057] Trial 33 finished with value: -0.943812489076831 and parameters: {'ema1': 26, 'ema2': 84, 'ema3': 135}. Best is trial 18 with value: -1.244693632401888.
# [I 2025-10-27 23:01:04,158] Trial 34 finished with value: 999.0 and parameters: {'ema1': 32, 'ema2': 79, 'ema3': 131}. Best is trial 18 with value: -1.244693632401888.
# Trial 36: EMA(24,83,141) → Sortino: 1.182
# [I 2025-10-27 23:01:04,269] Trial 35 finished with value: -1.1820853751345122 and parameters: {'ema1': 24, 'ema2': 83, 'ema3': 141}. Best is trial 18 with value: -1.244693632401888.
# Trial 37: EMA(27,72,172) → Sortino: 1.224
# [I 2025-10-27 23:01:04,369] Trial 36 finished with value: -1.2239517588060478 and parameters: {'ema1': 27, 'ema2': 72, 'ema3': 172}. Best is trial 18 with value: -1.244693632401888.
# Trial 38: EMA(36,65,174) → Sortino: 1.001
# [I 2025-10-27 23:01:04,468] Trial 37 finished with value: -1.0007335453495596 and parameters: {'ema1': 36, 'ema2': 65, 'ema3': 174}. Best is trial 18 with value: -1.244693632401888.
# Trial 39: EMA(31,52,198) → Sortino: 0.643
# [I 2025-10-27 23:01:04,570] Trial 38 finished with value: -0.642962206771608 and parameters: {'ema1': 31, 'ema2': 52, 'ema3': 198}. Best is trial 18 with value: -1.244693632401888.
# Trial 40: EMA(8,79,188) → Sortino: 0.826
# [I 2025-10-27 23:01:04,675] Trial 39 finished with value: -0.8260766433569684 and parameters: {'ema1': 8, 'ema2': 79, 'ema3': 188}. Best is trial 18 with value: -1.244693632401888.
# Trial 41: EMA(21,71,165) → Sortino: 0.810
# [I 2025-10-27 23:01:04,782] Trial 40 finished with value: -0.8095472103195084 and parameters: {'ema1': 21, 'ema2': 71, 'ema3': 165}. Best is trial 18 with value: -1.244693632401888.
# Trial 42: EMA(28,74,160) → Sortino: 1.194
# [I 2025-10-27 23:01:04,887] Trial 41 finished with value: -1.193893267726268 and parameters: {'ema1': 28, 'ema2': 74, 'ema3': 160}. Best is trial 18 with value: -1.244693632401888.
# Trial 43: EMA(25,72,148) → Sortino: 0.974
# [I 2025-10-27 23:01:04,997] Trial 42 finished with value: -0.9742758477628586 and parameters: {'ema1': 25, 'ema2': 72, 'ema3': 148}. Best is trial 18 with value: -1.244693632401888.
# [I 2025-10-27 23:01:05,105] Trial 43 finished with value: 999.0 and parameters: {'ema1': 27, 'ema2': 88, 'ema3': 144}. Best is trial 18 with value: -1.244693632401888.
# Trial 45: EMA(24,67,134) → Sortino: 0.778
# [I 2025-10-27 23:01:05,216] Trial 44 finished with value: -0.7778004207007172 and parameters: {'ema1': 24, 'ema2': 67, 'ema3': 134}. Best is trial 18 with value: -1.244693632401888.
# Trial 46: EMA(29,71,173) → Sortino: 1.194
# [I 2025-10-27 23:01:05,311] Trial 45 finished with value: -1.194301671731783 and parameters: {'ema1': 29, 'ema2': 71, 'ema3': 173}. Best is trial 18 with value: -1.244693632401888.
# Trial 47: EMA(34,63,196) → Sortino: 0.878
# [I 2025-10-27 23:01:05,402] Trial 46 finished with value: -0.8778486835917284 and parameters: {'ema1': 34, 'ema2': 63, 'ema3': 196}. Best is trial 18 with value: -1.244693632401888.
# Trial 48: EMA(17,70,171) → Sortino: 0.854
# [I 2025-10-27 23:01:05,494] Trial 47 finished with value: -0.8543825768540829 and parameters: {'ema1': 17, 'ema2': 70, 'ema3': 171}. Best is trial 18 with value: -1.244693632401888.
# Trial 49: EMA(21,57,183) → Sortino: 0.720
# [I 2025-10-27 23:01:05,574] Trial 48 finished with value: -0.7200259746888954 and parameters: {'ema1': 21, 'ema2': 57, 'ema3': 183}. Best is trial 18 with value: -1.244693632401888.
# Trial 50: EMA(23,87,249) → Sortino: 1.260
# [I 2025-10-27 23:01:05,664] Trial 49 finished with value: -1.2595692246469514 and parameters: {'ema1': 23, 'ema2': 87, 'ema3': 249}. Best is trial 49 with value: -1.2595692246469514.
# Trial 51: EMA(13,87,245) → Sortino: 1.031
# [I 2025-10-27 23:01:05,754] Trial 50 finished with value: -1.0311540725982404 and parameters: {'ema1': 13, 'ema2': 87, 'ema3': 245}. Best is trial 49 with value: -1.2595692246469514.
# [I 2025-10-27 23:01:05,839] Trial 51 finished with value: 999.0 and parameters: {'ema1': 30, 'ema2': 89, 'ema3': 241}. Best is trial 49 with value: -1.2595692246469514.
# Trial 53: EMA(26,83,249) → Sortino: 0.963
# [I 2025-10-27 23:01:05,918] Trial 52 finished with value: -0.9629247032070465 and parameters: {'ema1': 26, 'ema2': 83, 'ema3': 249}. Best is trial 49 with value: -1.2595692246469514.
# Trial 54: EMA(23,86,237) → Sortino: 1.203
# [I 2025-10-27 23:01:06,010] Trial 53 finished with value: -1.2034914865550048 and parameters: {'ema1': 23, 'ema2': 86, 'ema3': 237}. Best is trial 49 with value: -1.2595692246469514.
# Trial 55: EMA(20,82,234) → Sortino: 1.159
# [I 2025-10-27 23:01:06,089] Trial 54 finished with value: -1.1586705776516848 and parameters: {'ema1': 20, 'ema2': 82, 'ema3': 234}. Best is trial 49 with value: -1.2595692246469514.
# Trial 56: EMA(23,86,228) → Sortino: 1.161
# [I 2025-10-27 23:01:06,177] Trial 55 finished with value: -1.1611811603225457 and parameters: {'ema1': 23, 'ema2': 86, 'ema3': 228}. Best is trial 49 with value: -1.2595692246469514.
# Trial 57: EMA(16,85,238) → Sortino: 1.018
# [I 2025-10-27 23:01:06,260] Trial 56 finished with value: -1.0183126025489881 and parameters: {'ema1': 16, 'ema2': 85, 'ema3': 238}. Best is trial 49 with value: -1.2595692246469514.
# Trial 58: EMA(23,88,224) → Sortino: 1.174
# [I 2025-10-27 23:01:06,347] Trial 57 finished with value: -1.1735384442008276 and parameters: {'ema1': 23, 'ema2': 88, 'ema3': 224}. Best is trial 49 with value: -1.2595692246469514.
# Trial 59: EMA(18,80,218) → Sortino: 0.967
# [I 2025-10-27 23:01:06,427] Trial 58 finished with value: -0.9667751599897116 and parameters: {'ema1': 18, 'ema2': 80, 'ema3': 218}. Best is trial 49 with value: -1.2595692246469514.
# Trial 60: EMA(25,77,238) → Sortino: 1.222
# [I 2025-10-27 23:01:06,521] Trial 59 finished with value: -1.2216938516108093 and parameters: {'ema1': 25, 'ema2': 77, 'ema3': 238}. Best is trial 49 with value: -1.2595692246469514.
# Trial 61: EMA(20,76,212) → Sortino: 0.989
# [I 2025-10-27 23:01:06,607] Trial 60 finished with value: -0.989003253742353 and parameters: {'ema1': 20, 'ema2': 76, 'ema3': 212}. Best is trial 49 with value: -1.2595692246469514.
# Trial 62: EMA(25,78,238) → Sortino: 1.235
# [I 2025-10-27 23:01:06,689] Trial 61 finished with value: -1.2348996336239972 and parameters: {'ema1': 25, 'ema2': 78, 'ema3': 238}. Best is trial 49 with value: -1.2595692246469514.
# Trial 63: EMA(25,78,248) → Sortino: 1.212
# [I 2025-10-27 23:01:06,776] Trial 62 finished with value: -1.2116472733079986 and parameters: {'ema1': 25, 'ema2': 78, 'ema3': 248}. Best is trial 49 with value: -1.2595692246469514.
# Trial 64: EMA(27,77,247) → Sortino: 1.200
# [I 2025-10-27 23:01:06,864] Trial 63 finished with value: -1.2004388417437855 and parameters: {'ema1': 27, 'ema2': 77, 'ema3': 247}. Best is trial 49 with value: -1.2595692246469514.
# Trial 65: EMA(22,78,243) → Sortino: 1.116
# [I 2025-10-27 23:01:07,102] Trial 64 finished with value: -1.1157045919597761 and parameters: {'ema1': 22, 'ema2': 78, 'ema3': 243}. Best is trial 49 with value: -1.2595692246469514.
# Trial 66: EMA(25,75,228) → Sortino: 1.170
# [I 2025-10-27 23:01:07,190] Trial 65 finished with value: -1.1695798037027552 and parameters: {'ema1': 25, 'ema2': 75, 'ema3': 228}. Best is trial 49 with value: -1.2595692246469514.
# Trial 67: EMA(27,82,240) → Sortino: 0.917
# [I 2025-10-27 23:01:07,271] Trial 66 finished with value: -0.9167281270259823 and parameters: {'ema1': 27, 'ema2': 82, 'ema3': 240}. Best is trial 49 with value: -1.2595692246469514.
# Trial 68: EMA(18,68,229) → Sortino: 0.834
# [I 2025-10-27 23:01:07,363] Trial 67 finished with value: -0.8340409411541925 and parameters: {'ema1': 18, 'ema2': 68, 'ema3': 229}. Best is trial 49 with value: -1.2595692246469514.
# Trial 69: EMA(21,81,204) → Sortino: 1.177
# [I 2025-10-27 23:01:07,442] Trial 68 finished with value: -1.177278679684468 and parameters: {'ema1': 21, 'ema2': 81, 'ema3': 204}. Best is trial 49 with value: -1.2595692246469514.
# Trial 70: EMA(15,84,249) → Sortino: 1.022
# [I 2025-10-27 23:01:07,526] Trial 69 finished with value: -1.0215764535301202 and parameters: {'ema1': 15, 'ema2': 84, 'ema3': 249}. Best is trial 49 with value: -1.2595692246469514.
# Trial 71: EMA(29,78,222) → Sortino: 0.964
# [I 2025-10-27 23:01:07,606] Trial 70 finished with value: -0.9641868986505943 and parameters: {'ema1': 29, 'ema2': 78, 'ema3': 222}. Best is trial 49 with value: -1.2595692246469514.
# Trial 72: EMA(26,80,238) → Sortino: 1.144
# [I 2025-10-27 23:01:07,692] Trial 71 finished with value: -1.14429726137353 and parameters: {'ema1': 26, 'ema2': 80, 'ema3': 238}. Best is trial 49 with value: -1.2595692246469514.
# Trial 73: EMA(24,77,244) → Sortino: 1.122
# [I 2025-10-27 23:01:07,775] Trial 72 finished with value: -1.1219608013529887 and parameters: {'ema1': 24, 'ema2': 77, 'ema3': 244}. Best is trial 49 with value: -1.2595692246469514.
# Trial 74: EMA(25,75,128) → Sortino: 1.170
# [I 2025-10-27 23:01:07,859] Trial 73 finished with value: -1.1695798037027552 and parameters: {'ema1': 25, 'ema2': 75, 'ema3': 128}. Best is trial 49 with value: -1.2595692246469514.
# Trial 75: EMA(23,80,232) → Sortino: 1.122
# [I 2025-10-27 23:01:07,947] Trial 74 finished with value: -1.1219608013529887 and parameters: {'ema1': 23, 'ema2': 80, 'ema3': 232}. Best is trial 49 with value: -1.2595692246469514.
# Trial 76: EMA(24,83,140) → Sortino: 1.182
# [I 2025-10-27 23:01:08,036] Trial 75 finished with value: -1.1820853751345122 and parameters: {'ema1': 24, 'ema2': 83, 'ema3': 140}. Best is trial 49 with value: -1.2595692246469514.
# [I 2025-10-27 23:01:08,114] Trial 76 finished with value: 999.0 and parameters: {'ema1': 27, 'ema2': 87, 'ema3': 192}. Best is trial 49 with value: -1.2595692246469514.
# Trial 78: EMA(25,73,121) → Sortino: 1.119
# [I 2025-10-27 23:01:08,205] Trial 77 finished with value: -1.118900586516748 and parameters: {'ema1': 25, 'ema2': 73, 'ema3': 121}. Best is trial 49 with value: -1.2595692246469514.
# [I 2025-10-27 23:01:08,291] Trial 78 finished with value: 999.0 and parameters: {'ema1': 30, 'ema2': 89, 'ema3': 234}. Best is trial 49 with value: -1.2595692246469514.
# Trial 80: EMA(20,85,160) → Sortino: 1.175
# [I 2025-10-27 23:01:08,379] Trial 79 finished with value: -1.1748896295760642 and parameters: {'ema1': 20, 'ema2': 85, 'ema3': 160}. Best is trial 49 with value: -1.2595692246469514.
# Trial 81: EMA(26,78,241) → Sortino: 1.198
# [I 2025-10-27 23:01:08,465] Trial 80 finished with value: -1.1981813395916803 and parameters: {'ema1': 26, 'ema2': 78, 'ema3': 241}. Best is trial 49 with value: -1.2595692246469514.
# Trial 82: EMA(23,88,239) → Sortino: 1.210
# [I 2025-10-27 23:01:08,547] Trial 81 finished with value: -1.210256902356791 and parameters: {'ema1': 23, 'ema2': 88, 'ema3': 239}. Best is trial 49 with value: -1.2595692246469514.
# Trial 83: EMA(22,88,245) → Sortino: 1.191
# [I 2025-10-27 23:01:08,626] Trial 82 finished with value: -1.1913063225264084 and parameters: {'ema1': 22, 'ema2': 88, 'ema3': 245}. Best is trial 49 with value: -1.2595692246469514.
# Trial 84: EMA(19,85,237) → Sortino: 1.274
# [I 2025-10-27 23:01:08,768] Trial 83 finished with value: -1.2743446969318504 and parameters: {'ema1': 19, 'ema2': 85, 'ema3': 237}. Best is trial 83 with value: -1.2743446969318504.
# Trial 85: EMA(19,85,236) → Sortino: 1.274
# [I 2025-10-27 23:01:08,901] Trial 84 finished with value: -1.2743446969318504 and parameters: {'ema1': 19, 'ema2': 85, 'ema3': 236}. Best is trial 83 with value: -1.2743446969318504.
# Trial 86: EMA(16,85,225) → Sortino: 1.016
# [I 2025-10-27 23:01:08,993] Trial 85 finished with value: -1.015537800169273 and parameters: {'ema1': 16, 'ema2': 85, 'ema3': 225}. Best is trial 83 with value: -1.2743446969318504.
# Trial 87: EMA(19,87,236) → Sortino: 1.215
# [I 2025-10-27 23:01:09,078] Trial 86 finished with value: -1.2148157262774775 and parameters: {'ema1': 19, 'ema2': 87, 'ema3': 236}. Best is trial 83 with value: -1.2743446969318504.
# Trial 88: EMA(19,87,217) → Sortino: 1.215
# [I 2025-10-27 23:01:09,164] Trial 87 finished with value: -1.2148157262774775 and parameters: {'ema1': 19, 'ema2': 87, 'ema3': 217}. Best is trial 83 with value: -1.2743446969318504.
# Trial 89: EMA(18,83,232) → Sortino: 1.103
# [I 2025-10-27 23:01:09,243] Trial 88 finished with value: -1.1025497454276483 and parameters: {'ema1': 18, 'ema2': 83, 'ema3': 232}. Best is trial 83 with value: -1.2743446969318504.
# Trial 90: EMA(16,85,236) → Sortino: 1.018
# [I 2025-10-27 23:01:09,335] Trial 89 finished with value: -1.0183126025489881 and parameters: {'ema1': 16, 'ema2': 85, 'ema3': 236}. Best is trial 83 with value: -1.2743446969318504.
# Trial 91: EMA(17,86,230) → Sortino: 1.097
# [I 2025-10-27 23:01:09,415] Trial 90 finished with value: -1.0968942295084967 and parameters: {'ema1': 17, 'ema2': 86, 'ema3': 230}. Best is trial 83 with value: -1.2743446969318504.
# Trial 92: EMA(19,87,217) → Sortino: 1.215
# [I 2025-10-27 23:01:09,500] Trial 91 finished with value: -1.2148157262774775 and parameters: {'ema1': 19, 'ema2': 87, 'ema3': 217}. Best is trial 83 with value: -1.2743446969318504.
# Trial 93: EMA(14,88,226) → Sortino: 1.008
# [I 2025-10-27 23:01:09,581] Trial 92 finished with value: -1.007649965699131 and parameters: {'ema1': 14, 'ema2': 88, 'ema3': 226}. Best is trial 83 with value: -1.2743446969318504.
# Trial 94: EMA(20,89,178) → Sortino: 1.092
# [I 2025-10-27 23:01:09,671] Trial 93 finished with value: -1.0917233003173215 and parameters: {'ema1': 20, 'ema2': 89, 'ema3': 178}. Best is trial 83 with value: -1.2743446969318504.
# Trial 95: EMA(19,84,221) → Sortino: 1.274
# [I 2025-10-27 23:01:09,753] Trial 94 finished with value: -1.2743446969318504 and parameters: {'ema1': 19, 'ema2': 84, 'ema3': 221}. Best is trial 83 with value: -1.2743446969318504.
# Trial 96: EMA(17,84,236) → Sortino: 1.054
# [I 2025-10-27 23:01:09,843] Trial 95 finished with value: -1.0540579374430308 and parameters: {'ema1': 17, 'ema2': 84, 'ema3': 236}. Best is trial 83 with value: -1.2743446969318504.
# Trial 97: EMA(21,82,242) → Sortino: 1.169
# [I 2025-10-27 23:01:09,924] Trial 96 finished with value: -1.1691876682695792 and parameters: {'ema1': 21, 'ema2': 82, 'ema3': 242}. Best is trial 83 with value: -1.2743446969318504.
# Trial 98: EMA(18,86,231) → Sortino: 1.251
# [I 2025-10-27 23:01:10,014] Trial 97 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 86, 'ema3': 231}. Best is trial 83 with value: -1.2743446969318504.
# Trial 99: EMA(14,84,220) → Sortino: 0.937
# [I 2025-10-27 23:01:10,094] Trial 98 finished with value: -0.9373010877694946 and parameters: {'ema1': 14, 'ema2': 84, 'ema3': 220}. Best is trial 83 with value: -1.2743446969318504.
# Trial 100: EMA(15,86,231) → Sortino: 0.959
# [I 2025-10-27 23:01:10,183] Trial 99 finished with value: -0.9585621786227612 and parameters: {'ema1': 15, 'ema2': 86, 'ema3': 231}. Best is trial 83 with value: -1.2743446969318504.
# Trial 101: EMA(18,86,227) → Sortino: 1.251
# [I 2025-10-27 23:01:10,266] Trial 100 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 86, 'ema3': 227}. Best is trial 83 with value: -1.2743446969318504.
# Trial 102: EMA(18,82,226) → Sortino: 1.064
# [I 2025-10-27 23:01:10,350] Trial 101 finished with value: -1.0643624924354071 and parameters: {'ema1': 18, 'ema2': 82, 'ema3': 226}. Best is trial 83 with value: -1.2743446969318504.
# Trial 103: EMA(16,85,222) → Sortino: 1.016
# [I 2025-10-27 23:01:10,436] Trial 102 finished with value: -1.015537800169273 and parameters: {'ema1': 16, 'ema2': 85, 'ema3': 222}. Best is trial 83 with value: -1.2743446969318504.
# Trial 104: EMA(17,86,210) → Sortino: 1.097
# [I 2025-10-27 23:01:10,522] Trial 103 finished with value: -1.0968942295084967 and parameters: {'ema1': 17, 'ema2': 86, 'ema3': 210}. Best is trial 83 with value: -1.2743446969318504.
# Trial 105: EMA(21,54,234) → Sortino: 0.928
# [I 2025-10-27 23:01:10,604] Trial 104 finished with value: -0.9279692480836291 and parameters: {'ema1': 21, 'ema2': 54, 'ema3': 234}. Best is trial 83 with value: -1.2743446969318504.
# Trial 106: EMA(20,84,246) → Sortino: 1.215
# [I 2025-10-27 23:01:10,691] Trial 105 finished with value: -1.2145729577002051 and parameters: {'ema1': 20, 'ema2': 84, 'ema3': 246}. Best is trial 83 with value: -1.2743446969318504.
# Trial 107: EMA(18,83,242) → Sortino: 1.103
# [I 2025-10-27 23:01:10,778] Trial 106 finished with value: -1.1025497454276483 and parameters: {'ema1': 18, 'ema2': 83, 'ema3': 242}. Best is trial 83 with value: -1.2743446969318504.
# Trial 108: EMA(22,89,228) → Sortino: 1.125
# [I 2025-10-27 23:01:10,864] Trial 107 finished with value: -1.1245290464535653 and parameters: {'ema1': 22, 'ema2': 89, 'ema3': 228}. Best is trial 83 with value: -1.2743446969318504.
# Trial 109: EMA(20,81,239) → Sortino: 1.094
# [I 2025-10-27 23:01:10,946] Trial 108 finished with value: -1.0935422347737276 and parameters: {'ema1': 20, 'ema2': 81, 'ema3': 239}. Best is trial 83 with value: -1.2743446969318504.
# Trial 110: EMA(19,86,213) → Sortino: 1.223
# [I 2025-10-27 23:01:11,039] Trial 109 finished with value: -1.222902352149324 and parameters: {'ema1': 19, 'ema2': 86, 'ema3': 213}. Best is trial 83 with value: -1.2743446969318504.
# Trial 111: EMA(12,88,221) → Sortino: 1.275
# [I 2025-10-27 23:01:11,119] Trial 110 finished with value: -1.275404357536903 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 221}. Best is trial 110 with value: -1.275404357536903.
# Trial 112: EMA(12,88,221) → Sortino: 1.275
# [I 2025-10-27 23:01:11,245] Trial 111 finished with value: -1.275404357536903 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 221}. Best is trial 110 with value: -1.275404357536903.
# Trial 113: EMA(8,88,222) → Sortino: 1.088
# [I 2025-10-27 23:01:11,325] Trial 112 finished with value: -1.0881709717769161 and parameters: {'ema1': 8, 'ema2': 88, 'ema3': 222}. Best is trial 110 with value: -1.275404357536903.
# Trial 114: EMA(11,87,215) → Sortino: 1.107
# [I 2025-10-27 23:01:11,412] Trial 113 finished with value: -1.1068337999513391 and parameters: {'ema1': 11, 'ema2': 87, 'ema3': 215}. Best is trial 110 with value: -1.275404357536903.
# Trial 115: EMA(12,85,206) → Sortino: 1.110
# [I 2025-10-27 23:01:11,498] Trial 114 finished with value: -1.1097120487298062 and parameters: {'ema1': 12, 'ema2': 85, 'ema3': 206}. Best is trial 110 with value: -1.275404357536903.
# Trial 116: EMA(10,88,227) → Sortino: 1.017
# [I 2025-10-27 23:01:11,591] Trial 115 finished with value: -1.016843963744905 and parameters: {'ema1': 10, 'ema2': 88, 'ema3': 227}. Best is trial 110 with value: -1.275404357536903.
# Trial 117: EMA(13,89,220) → Sortino: 1.031
# [I 2025-10-27 23:01:11,681] Trial 116 finished with value: -1.0311540725982404 and parameters: {'ema1': 13, 'ema2': 89, 'ema3': 220}. Best is trial 110 with value: -1.275404357536903.
# Trial 118: EMA(13,87,157) → Sortino: 0.988
# [I 2025-10-27 23:01:11,770] Trial 117 finished with value: -0.9884120648536783 and parameters: {'ema1': 13, 'ema2': 87, 'ema3': 157}. Best is trial 110 with value: -1.275404357536903.
# Trial 119: EMA(9,85,233) → Sortino: 0.891
# [I 2025-10-27 23:01:11,849] Trial 118 finished with value: -0.8910492436417422 and parameters: {'ema1': 9, 'ema2': 85, 'ema3': 233}. Best is trial 110 with value: -1.275404357536903.
# Trial 120: EMA(17,86,223) → Sortino: 1.097
# [I 2025-10-27 23:01:11,936] Trial 119 finished with value: -1.0968942295084967 and parameters: {'ema1': 17, 'ema2': 86, 'ema3': 223}. Best is trial 110 with value: -1.275404357536903.
# Trial 121: EMA(5,88,231) → Sortino: 0.990
# [I 2025-10-27 23:01:12,016] Trial 120 finished with value: -0.9895661910647198 and parameters: {'ema1': 5, 'ema2': 88, 'ema3': 231}. Best is trial 110 with value: -1.275404357536903.
# Trial 122: EMA(19,86,212) → Sortino: 1.196
# [I 2025-10-27 23:01:12,105] Trial 121 finished with value: -1.1961294015511326 and parameters: {'ema1': 19, 'ema2': 86, 'ema3': 212}. Best is trial 110 with value: -1.275404357536903.
# Trial 123: EMA(19,86,215) → Sortino: 1.223
# [I 2025-10-27 23:01:12,182] Trial 122 finished with value: -1.222902352149324 and parameters: {'ema1': 19, 'ema2': 86, 'ema3': 215}. Best is trial 110 with value: -1.275404357536903.
# Trial 124: EMA(12,64,219) → Sortino: 1.001
# [I 2025-10-27 23:01:12,274] Trial 123 finished with value: -1.0005673663003718 and parameters: {'ema1': 12, 'ema2': 64, 'ema3': 219}. Best is trial 110 with value: -1.275404357536903.
# Trial 125: EMA(18,83,224) → Sortino: 1.103
# [I 2025-10-27 23:01:12,352] Trial 124 finished with value: -1.1025497454276483 and parameters: {'ema1': 18, 'ema2': 83, 'ema3': 224}. Best is trial 110 with value: -1.275404357536903.
# Trial 126: EMA(20,88,229) → Sortino: 1.060
# [I 2025-10-27 23:01:12,450] Trial 125 finished with value: -1.0596589875368543 and parameters: {'ema1': 20, 'ema2': 88, 'ema3': 229}. Best is trial 110 with value: -1.275404357536903.
# Trial 127: EMA(16,87,181) → Sortino: 1.049
# [I 2025-10-27 23:01:12,546] Trial 126 finished with value: -1.048792077227742 and parameters: {'ema1': 16, 'ema2': 87, 'ema3': 181}. Best is trial 110 with value: -1.275404357536903.
# Trial 128: EMA(21,60,189) → Sortino: 0.746
# [I 2025-10-27 23:01:12,634] Trial 127 finished with value: -0.7460449075047537 and parameters: {'ema1': 21, 'ema2': 60, 'ema3': 189}. Best is trial 110 with value: -1.275404357536903.
# Trial 129: EMA(15,85,146) → Sortino: 0.965
# [I 2025-10-27 23:01:12,715] Trial 128 finished with value: -0.9652182221635179 and parameters: {'ema1': 15, 'ema2': 85, 'ema3': 146}. Best is trial 110 with value: -1.275404357536903.
# Trial 130: EMA(18,89,167) → Sortino: 1.248
# [I 2025-10-27 23:01:12,803] Trial 129 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 167}. Best is trial 110 with value: -1.275404357536903.
# Trial 131: EMA(18,89,169) → Sortino: 1.248
# [I 2025-10-27 23:01:12,887] Trial 130 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 169}. Best is trial 110 with value: -1.275404357536903.
# Trial 132: EMA(18,89,167) → Sortino: 1.248
# [I 2025-10-27 23:01:12,974] Trial 131 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 167}. Best is trial 110 with value: -1.275404357536903.
# Trial 133: EMA(18,89,165) → Sortino: 1.248
# [I 2025-10-27 23:01:13,056] Trial 132 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 165}. Best is trial 110 with value: -1.275404357536903.
# Trial 134: EMA(18,89,166) → Sortino: 1.248
# [I 2025-10-27 23:01:13,148] Trial 133 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 166}. Best is trial 110 with value: -1.275404357536903.
# Trial 135: EMA(18,89,165) → Sortino: 1.248
# [I 2025-10-27 23:01:13,228] Trial 134 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 165}. Best is trial 110 with value: -1.275404357536903.
# Trial 136: EMA(18,89,162) → Sortino: 1.248
# [I 2025-10-27 23:01:13,324] Trial 135 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 162}. Best is trial 110 with value: -1.275404357536903.
# Trial 137: EMA(16,89,168) → Sortino: 1.236
# [I 2025-10-27 23:01:13,408] Trial 136 finished with value: -1.2355894548370479 and parameters: {'ema1': 16, 'ema2': 89, 'ema3': 168}. Best is trial 110 with value: -1.275404357536903.
# Trial 138: EMA(17,88,168) → Sortino: 1.128
# [I 2025-10-27 23:01:13,493] Trial 137 finished with value: -1.1276317907938993 and parameters: {'ema1': 17, 'ema2': 88, 'ema3': 168}. Best is trial 110 with value: -1.275404357536903.
# Trial 139: EMA(19,89,164) → Sortino: 1.175
# [I 2025-10-27 23:01:13,583] Trial 138 finished with value: -1.1748896295760642 and parameters: {'ema1': 19, 'ema2': 89, 'ema3': 164}. Best is trial 110 with value: -1.275404357536903.
# Trial 140: EMA(17,88,175) → Sortino: 1.128
# [I 2025-10-27 23:01:13,672] Trial 139 finished with value: -1.1276317907938993 and parameters: {'ema1': 17, 'ema2': 88, 'ema3': 175}. Best is trial 110 with value: -1.275404357536903.
# Trial 141: EMA(18,89,156) → Sortino: 1.248
# [I 2025-10-27 23:01:13,754] Trial 140 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 156}. Best is trial 110 with value: -1.275404357536903.
# Trial 142: EMA(18,89,164) → Sortino: 1.248
# [I 2025-10-27 23:01:13,843] Trial 141 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 164}. Best is trial 110 with value: -1.275404357536903.
# Trial 143: EMA(18,87,162) → Sortino: 1.248
# [I 2025-10-27 23:01:13,928] Trial 142 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 87, 'ema3': 162}. Best is trial 110 with value: -1.275404357536903.
# Trial 144: EMA(19,88,171) → Sortino: 1.218
# [I 2025-10-27 23:01:14,016] Trial 143 finished with value: -1.2178448076720356 and parameters: {'ema1': 19, 'ema2': 88, 'ema3': 171}. Best is trial 110 with value: -1.275404357536903.
# Trial 145: EMA(16,89,167) → Sortino: 1.236
# [I 2025-10-27 23:01:14,103] Trial 144 finished with value: -1.2355894548370479 and parameters: {'ema1': 16, 'ema2': 89, 'ema3': 167}. Best is trial 110 with value: -1.275404357536903.
# Trial 146: EMA(17,87,159) → Sortino: 1.206
# [I 2025-10-27 23:01:14,189] Trial 145 finished with value: -1.2061952340440354 and parameters: {'ema1': 17, 'ema2': 87, 'ema3': 159}. Best is trial 110 with value: -1.275404357536903.
# Trial 147: EMA(20,88,162) → Sortino: 1.065
# [I 2025-10-27 23:01:14,272] Trial 146 finished with value: -1.065328382361191 and parameters: {'ema1': 20, 'ema2': 88, 'ema3': 162}. Best is trial 110 with value: -1.275404357536903.
# Trial 148: EMA(18,89,150) → Sortino: 1.248
# [I 2025-10-27 23:01:14,373] Trial 147 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 150}. Best is trial 110 with value: -1.275404357536903.
# Trial 149: EMA(20,87,176) → Sortino: 1.175
# [I 2025-10-27 23:01:14,455] Trial 148 finished with value: -1.1748896295760642 and parameters: {'ema1': 20, 'ema2': 87, 'ema3': 176}. Best is trial 110 with value: -1.275404357536903.
# Trial 150: EMA(17,86,170) → Sortino: 1.094
# [I 2025-10-27 23:01:14,542] Trial 149 finished with value: -1.0941289151076417 and parameters: {'ema1': 17, 'ema2': 86, 'ema3': 170}. Best is trial 110 with value: -1.275404357536903.
# Trial 151: EMA(15,89,168) → Sortino: 1.043
# [I 2025-10-27 23:01:14,629] Trial 150 finished with value: -1.0429325392203663 and parameters: {'ema1': 15, 'ema2': 89, 'ema3': 168}. Best is trial 110 with value: -1.275404357536903.
# Trial 152: EMA(18,89,153) → Sortino: 1.248
# [I 2025-10-27 23:01:14,716] Trial 151 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 153}. Best is trial 110 with value: -1.275404357536903.
# Trial 153: EMA(19,88,158) → Sortino: 1.218
# [I 2025-10-27 23:01:14,800] Trial 152 finished with value: -1.2178448076720356 and parameters: {'ema1': 19, 'ema2': 88, 'ema3': 158}. Best is trial 110 with value: -1.275404357536903.
# Trial 154: EMA(21,87,155) → Sortino: 1.152
# [I 2025-10-27 23:01:14,889] Trial 153 finished with value: -1.1517499569142156 and parameters: {'ema1': 21, 'ema2': 87, 'ema3': 155}. Best is trial 110 with value: -1.275404357536903.
# Trial 155: EMA(18,89,165) → Sortino: 1.248
# [I 2025-10-27 23:01:14,973] Trial 154 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 165}. Best is trial 110 with value: -1.275404357536903.
# Trial 156: EMA(19,88,166) → Sortino: 1.218
# [I 2025-10-27 23:01:15,059] Trial 155 finished with value: -1.2178448076720356 and parameters: {'ema1': 19, 'ema2': 88, 'ema3': 166}. Best is trial 110 with value: -1.275404357536903.
# Trial 157: EMA(18,86,157) → Sortino: 1.248
# [I 2025-10-27 23:01:15,148] Trial 156 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 86, 'ema3': 157}. Best is trial 110 with value: -1.275404357536903.
# Trial 158: EMA(22,87,162) → Sortino: 1.098
# [I 2025-10-27 23:01:15,249] Trial 157 finished with value: -1.0979080105272703 and parameters: {'ema1': 22, 'ema2': 87, 'ema3': 162}. Best is trial 110 with value: -1.275404357536903.
# [I 2025-10-27 23:01:15,332] Trial 158 finished with value: 999.0 and parameters: {'ema1': 39, 'ema2': 89, 'ema3': 170}. Best is trial 110 with value: -1.275404357536903.
# Trial 160: EMA(16,88,160) → Sortino: 1.123
# [I 2025-10-27 23:01:15,421] Trial 159 finished with value: -1.1231142847884723 and parameters: {'ema1': 16, 'ema2': 88, 'ema3': 160}. Best is trial 110 with value: -1.275404357536903.
# Trial 161: EMA(17,84,153) → Sortino: 1.051
# [I 2025-10-27 23:01:15,500] Trial 160 finished with value: -1.0512887869315368 and parameters: {'ema1': 17, 'ema2': 84, 'ema3': 153}. Best is trial 110 with value: -1.275404357536903.
# Trial 162: EMA(18,89,164) → Sortino: 1.248
# [I 2025-10-27 23:01:15,622] Trial 161 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 164}. Best is trial 110 with value: -1.275404357536903.
# Trial 163: EMA(18,89,163) → Sortino: 1.248
# [I 2025-10-27 23:01:15,755] Trial 162 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 163}. Best is trial 110 with value: -1.275404357536903.
# Trial 164: EMA(20,88,165) → Sortino: 1.065
# [I 2025-10-27 23:01:15,860] Trial 163 finished with value: -1.065328382361191 and parameters: {'ema1': 20, 'ema2': 88, 'ema3': 165}. Best is trial 110 with value: -1.275404357536903.
# Trial 165: EMA(19,87,171) → Sortino: 1.188
# [I 2025-10-27 23:01:15,962] Trial 164 finished with value: -1.1880427756792868 and parameters: {'ema1': 19, 'ema2': 87, 'ema3': 171}. Best is trial 110 with value: -1.275404357536903.
# Trial 166: EMA(17,89,159) → Sortino: 1.248
# [I 2025-10-27 23:01:16,102] Trial 165 finished with value: -1.2479656678411766 and parameters: {'ema1': 17, 'ema2': 89, 'ema3': 159}. Best is trial 110 with value: -1.275404357536903.
# Trial 167: EMA(20,87,179) → Sortino: 1.202
# [I 2025-10-27 23:01:16,211] Trial 166 finished with value: -1.2016664690686647 and parameters: {'ema1': 20, 'ema2': 87, 'ema3': 179}. Best is trial 110 with value: -1.275404357536903.
# Trial 168: EMA(15,86,167) → Sortino: 0.971
# [I 2025-10-27 23:01:16,321] Trial 167 finished with value: -0.9712364384840838 and parameters: {'ema1': 15, 'ema2': 86, 'ema3': 167}. Best is trial 110 with value: -1.275404357536903.
# Trial 169: EMA(19,88,173) → Sortino: 1.218
# [I 2025-10-27 23:01:16,482] Trial 168 finished with value: -1.2178448076720356 and parameters: {'ema1': 19, 'ema2': 88, 'ema3': 173}. Best is trial 110 with value: -1.275404357536903.
# Trial 170: EMA(18,89,161) → Sortino: 1.248
# [I 2025-10-27 23:01:16,663] Trial 169 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 161}. Best is trial 110 with value: -1.275404357536903.
# Trial 171: EMA(11,85,169) → Sortino: 1.004
# [I 2025-10-27 23:01:16,792] Trial 170 finished with value: -1.0037835633487624 and parameters: {'ema1': 11, 'ema2': 85, 'ema3': 169}. Best is trial 110 with value: -1.275404357536903.
# Trial 172: EMA(17,87,162) → Sortino: 1.206
# [I 2025-10-27 23:01:17,088] Trial 171 finished with value: -1.2061952340440354 and parameters: {'ema1': 17, 'ema2': 87, 'ema3': 162}. Best is trial 110 with value: -1.275404357536903.
# Trial 173: EMA(18,88,165) → Sortino: 1.248
# [I 2025-10-27 23:01:17,276] Trial 172 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 88, 'ema3': 165}. Best is trial 110 with value: -1.275404357536903.
# Trial 174: EMA(18,87,157) → Sortino: 1.248
# [I 2025-10-27 23:01:17,420] Trial 173 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 87, 'ema3': 157}. Best is trial 110 with value: -1.275404357536903.
# Trial 175: EMA(21,86,163) → Sortino: 1.154
# [I 2025-10-27 23:01:17,528] Trial 174 finished with value: -1.1540030537005896 and parameters: {'ema1': 21, 'ema2': 86, 'ema3': 163}. Best is trial 110 with value: -1.275404357536903.
# Trial 176: EMA(17,88,173) → Sortino: 1.128
# [I 2025-10-27 23:01:17,686] Trial 175 finished with value: -1.1276317907938993 and parameters: {'ema1': 17, 'ema2': 88, 'ema3': 173}. Best is trial 110 with value: -1.275404357536903.
# Trial 177: EMA(19,89,155) → Sortino: 1.172
# [I 2025-10-27 23:01:17,796] Trial 176 finished with value: -1.172117313668835 and parameters: {'ema1': 19, 'ema2': 89, 'ema3': 155}. Best is trial 110 with value: -1.275404357536903.
# Trial 178: EMA(18,87,161) → Sortino: 1.248
# [I 2025-10-27 23:01:17,889] Trial 177 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 87, 'ema3': 161}. Best is trial 110 with value: -1.275404357536903.
# Trial 179: EMA(16,85,166) → Sortino: 1.016
# [I 2025-10-27 23:01:17,988] Trial 178 finished with value: -1.015537800169273 and parameters: {'ema1': 16, 'ema2': 85, 'ema3': 166}. Best is trial 110 with value: -1.275404357536903.
# Trial 180: EMA(14,88,225) → Sortino: 1.008
# [I 2025-10-27 23:01:18,112] Trial 179 finished with value: -1.007649965699131 and parameters: {'ema1': 14, 'ema2': 88, 'ema3': 225}. Best is trial 110 with value: -1.275404357536903.
# Trial 181: EMA(19,86,235) → Sortino: 1.223
# [I 2025-10-27 23:01:18,209] Trial 180 finished with value: -1.222902352149324 and parameters: {'ema1': 19, 'ema2': 86, 'ema3': 235}. Best is trial 110 with value: -1.275404357536903.
# Trial 182: EMA(18,89,152) → Sortino: 1.248
# [I 2025-10-27 23:01:18,293] Trial 181 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 152}. Best is trial 110 with value: -1.275404357536903.
# Trial 183: EMA(17,89,156) → Sortino: 1.248
# [I 2025-10-27 23:01:18,380] Trial 182 finished with value: -1.2479656678411766 and parameters: {'ema1': 17, 'ema2': 89, 'ema3': 156}. Best is trial 110 with value: -1.275404357536903.
# Trial 184: EMA(19,88,151) → Sortino: 1.215
# [I 2025-10-27 23:01:18,460] Trial 183 finished with value: -1.2150724917648068 and parameters: {'ema1': 19, 'ema2': 88, 'ema3': 151}. Best is trial 110 with value: -1.275404357536903.
# Trial 185: EMA(18,89,150) → Sortino: 1.248
# [I 2025-10-27 23:01:18,580] Trial 184 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 150}. Best is trial 110 with value: -1.275404357536903.
# Trial 186: EMA(16,87,230) → Sortino: 1.049
# [I 2025-10-27 23:01:18,680] Trial 185 finished with value: -1.048792077227742 and parameters: {'ema1': 16, 'ema2': 87, 'ema3': 230}. Best is trial 110 with value: -1.275404357536903.
# Trial 187: EMA(20,89,159) → Sortino: 1.065
# [I 2025-10-27 23:01:18,781] Trial 186 finished with value: -1.065328382361191 and parameters: {'ema1': 20, 'ema2': 89, 'ema3': 159}. Best is trial 110 with value: -1.275404357536903.
# Trial 188: EMA(18,88,147) → Sortino: 1.248
# [I 2025-10-27 23:01:18,871] Trial 187 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 88, 'ema3': 147}. Best is trial 110 with value: -1.275404357536903.
# Trial 189: EMA(20,84,169) → Sortino: 1.183
# [I 2025-10-27 23:01:18,954] Trial 188 finished with value: -1.1829774300675677 and parameters: {'ema1': 20, 'ema2': 84, 'ema3': 169}. Best is trial 110 with value: -1.275404357536903.
# Trial 190: EMA(19,86,163) → Sortino: 1.196
# [I 2025-10-27 23:01:19,038] Trial 189 finished with value: -1.1961294015511326 and parameters: {'ema1': 19, 'ema2': 86, 'ema3': 163}. Best is trial 110 with value: -1.275404357536903.
# Trial 191: EMA(6,50,143) → Sortino: 0.933
# [I 2025-10-27 23:01:19,139] Trial 190 finished with value: -0.9332284820044139 and parameters: {'ema1': 6, 'ema2': 50, 'ema3': 143}. Best is trial 110 with value: -1.275404357536903.
# Trial 192: EMA(18,89,155) → Sortino: 1.248
# [I 2025-10-27 23:01:19,228] Trial 191 finished with value: -1.2479656678411766 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 155}. Best is trial 110 with value: -1.275404357536903.
# Trial 193: EMA(17,89,167) → Sortino: 1.248
# [I 2025-10-27 23:01:19,309] Trial 192 finished with value: -1.2479656678411766 and parameters: {'ema1': 17, 'ema2': 89, 'ema3': 167}. Best is trial 110 with value: -1.275404357536903.
# Trial 194: EMA(18,88,221) → Sortino: 1.251
# [I 2025-10-27 23:01:19,397] Trial 193 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 88, 'ema3': 221}. Best is trial 110 with value: -1.275404357536903.
# Trial 195: EMA(19,87,220) → Sortino: 1.215
# [I 2025-10-27 23:01:19,479] Trial 194 finished with value: -1.2148157262774775 and parameters: {'ema1': 19, 'ema2': 87, 'ema3': 220}. Best is trial 110 with value: -1.275404357536903.
# Trial 196: EMA(16,88,229) → Sortino: 1.123
# [I 2025-10-27 23:01:19,577] Trial 195 finished with value: -1.1231142847884723 and parameters: {'ema1': 16, 'ema2': 88, 'ema3': 229}. Best is trial 110 with value: -1.275404357536903.
# Trial 197: EMA(17,88,226) → Sortino: 1.130
# [I 2025-10-27 23:01:19,676] Trial 196 finished with value: -1.1304127359790836 and parameters: {'ema1': 17, 'ema2': 88, 'ema3': 226}. Best is trial 110 with value: -1.275404357536903.
# Trial 198: EMA(13,87,217) → Sortino: 1.031
# [I 2025-10-27 23:01:19,774] Trial 197 finished with value: -1.0311540725982404 and parameters: {'ema1': 13, 'ema2': 87, 'ema3': 217}. Best is trial 110 with value: -1.275404357536903.
# Trial 199: EMA(20,88,215) → Sortino: 1.060
# [I 2025-10-27 23:01:19,857] Trial 198 finished with value: -1.0596589875368543 and parameters: {'ema1': 20, 'ema2': 88, 'ema3': 215}. Best is trial 110 with value: -1.275404357536903.
# Trial 200: EMA(17,85,222) → Sortino: 1.084
# [I 2025-10-27 23:01:19,944] Trial 199 finished with value: -1.0839510312637175 and parameters: {'ema1': 17, 'ema2': 85, 'ema3': 222}. Best is trial 110 with value: -1.275404357536903.
# Trial 201: EMA(18,89,223) → Sortino: 1.251
# [I 2025-10-27 23:01:20,025] Trial 200 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 223}. Best is trial 110 with value: -1.275404357536903.
# Trial 202: EMA(18,89,201) → Sortino: 1.251
# [I 2025-10-27 23:01:20,124] Trial 201 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 89, 'ema3': 201}. Best is trial 110 with value: -1.275404357536903.
# Trial 203: EMA(18,88,200) → Sortino: 1.251
# [I 2025-10-27 23:01:20,221] Trial 202 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 88, 'ema3': 200}. Best is trial 110 with value: -1.275404357536903.
# Trial 204: EMA(19,89,203) → Sortino: 1.175
# [I 2025-10-27 23:01:20,315] Trial 203 finished with value: -1.1748896295760642 and parameters: {'ema1': 19, 'ema2': 89, 'ema3': 203}. Best is trial 110 with value: -1.275404357536903.
# Trial 205: EMA(18,88,188) → Sortino: 1.251
# [I 2025-10-27 23:01:20,395] Trial 204 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 88, 'ema3': 188}. Best is trial 110 with value: -1.275404357536903.
# Trial 206: EMA(17,88,195) → Sortino: 1.128
# [I 2025-10-27 23:01:20,483] Trial 205 finished with value: -1.1276317907938993 and parameters: {'ema1': 17, 'ema2': 88, 'ema3': 195}. Best is trial 110 with value: -1.275404357536903.
# Trial 207: EMA(19,87,187) → Sortino: 1.188
# [I 2025-10-27 23:01:20,567] Trial 206 finished with value: -1.1880427756792868 and parameters: {'ema1': 19, 'ema2': 87, 'ema3': 187}. Best is trial 110 with value: -1.275404357536903.
# Trial 208: EMA(18,88,209) → Sortino: 1.251
# [I 2025-10-27 23:01:20,661] Trial 207 finished with value: -1.2507475449117866 and parameters: {'ema1': 18, 'ema2': 88, 'ema3': 209}. Best is trial 110 with value: -1.275404357536903.
# Trial 209: EMA(12,88,209) → Sortino: 1.275
# [I 2025-10-27 23:01:20,753] Trial 208 finished with value: -1.275404357536903 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 209}. Best is trial 110 with value: -1.275404357536903.
# Trial 210: EMA(11,87,199) → Sortino: 1.120
# [I 2025-10-27 23:01:20,848] Trial 209 finished with value: -1.1201827062828607 and parameters: {'ema1': 11, 'ema2': 87, 'ema3': 199}. Best is trial 110 with value: -1.275404357536903.
# Trial 211: EMA(12,88,202) → Sortino: 1.289
# [I 2025-10-27 23:01:20,932] Trial 210 finished with value: -1.288824302605593 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 202}. Best is trial 210 with value: -1.288824302605593.
# Trial 212: EMA(12,88,207) → Sortino: 1.275
# [I 2025-10-27 23:01:21,023] Trial 211 finished with value: -1.275404357536903 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 207}. Best is trial 210 with value: -1.288824302605593.
# Trial 213: EMA(10,88,207) → Sortino: 1.017
# [I 2025-10-27 23:01:21,107] Trial 212 finished with value: -1.016843963744905 and parameters: {'ema1': 10, 'ema2': 88, 'ema3': 207}. Best is trial 210 with value: -1.288824302605593.
# ...
# Trial 931: EMA(13,86,125) → Sortino: 0.984
# [I 2025-10-27 23:02:25,777] Trial 930 finished with value: -0.9837505627429964 and parameters: {'ema1': 13, 'ema2': 86, 'ema3': 125}. Best is trial 733 with value: -1.3336313303376228.
# Trial 932: EMA(12,85,122) → Sortino: 1.181
# [I 2025-10-27 23:02:25,863] Trial 931 finished with value: -1.1810567004968715 and parameters: {'ema1': 12, 'ema2': 85, 'ema3': 122}. Best is trial 733 with value: -1.3336313303376228.
# Trial 933: EMA(14,87,123) → Sortino: 1.100
# [I 2025-10-27 23:02:25,955] Trial 932 finished with value: -1.0999449019716674 and parameters: {'ema1': 14, 'ema2': 87, 'ema3': 123}. Best is trial 733 with value: -1.3336313303376228.
# Trial 934: EMA(15,87,122) → Sortino: 1.043
# [I 2025-10-27 23:02:26,046] Trial 933 finished with value: -1.0428465051685274 and parameters: {'ema1': 15, 'ema2': 87, 'ema3': 122}. Best is trial 733 with value: -1.3336313303376228.
# Trial 935: EMA(10,88,120) → Sortino: 0.932
# [I 2025-10-27 23:02:26,140] Trial 934 finished with value: -0.9323628045332257 and parameters: {'ema1': 10, 'ema2': 88, 'ema3': 120}. Best is trial 733 with value: -1.3336313303376228.
# Trial 936: EMA(6,87,127) → Sortino: 1.035
# [I 2025-10-27 23:02:26,227] Trial 935 finished with value: -1.0351101660290578 and parameters: {'ema1': 6, 'ema2': 87, 'ema3': 127}. Best is trial 733 with value: -1.3336313303376228.
# Trial 937: EMA(11,88,124) → Sortino: 1.155
# [I 2025-10-27 23:02:26,322] Trial 936 finished with value: -1.1552747750031356 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 124}. Best is trial 733 with value: -1.3336313303376228.
# Trial 938: EMA(12,88,128) → Sortino: 1.292
# [I 2025-10-27 23:02:26,409] Trial 937 finished with value: -1.2915597609580896 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 128}. Best is trial 733 with value: -1.3336313303376228.
# Trial 939: EMA(13,86,125) → Sortino: 0.984
# [I 2025-10-27 23:02:26,504] Trial 938 finished with value: -0.9837505627429964 and parameters: {'ema1': 13, 'ema2': 86, 'ema3': 125}. Best is trial 733 with value: -1.3336313303376228.
# Trial 940: EMA(11,88,131) → Sortino: 1.159
# [I 2025-10-27 23:02:26,595] Trial 939 finished with value: -1.1591833711153559 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 131}. Best is trial 733 with value: -1.3336313303376228.
# Trial 941: EMA(12,87,129) → Sortino: 1.223
# [I 2025-10-27 23:02:26,691] Trial 940 finished with value: -1.2229791347763097 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 129}. Best is trial 733 with value: -1.3336313303376228.
# Trial 942: EMA(9,88,133) → Sortino: 0.884
# [I 2025-10-27 23:02:26,781] Trial 941 finished with value: -0.8838391245726525 and parameters: {'ema1': 9, 'ema2': 88, 'ema3': 133}. Best is trial 733 with value: -1.3336313303376228.
# Trial 943: EMA(12,76,125) → Sortino: 0.983
# [I 2025-10-27 23:02:26,872] Trial 942 finished with value: -0.9827014977484815 and parameters: {'ema1': 12, 'ema2': 76, 'ema3': 125}. Best is trial 733 with value: -1.3336313303376228.
# Trial 944: EMA(13,87,122) → Sortino: 1.099
# [I 2025-10-27 23:02:26,959] Trial 943 finished with value: -1.0991341605069298 and parameters: {'ema1': 13, 'ema2': 87, 'ema3': 122}. Best is trial 733 with value: -1.3336313303376228.
# Trial 945: EMA(11,88,135) → Sortino: 1.163
# [I 2025-10-27 23:02:27,052] Trial 944 finished with value: -1.163456418813155 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 135}. Best is trial 733 with value: -1.3336313303376228.
# Trial 946: EMA(10,86,120) → Sortino: 0.944
# [I 2025-10-27 23:02:27,144] Trial 945 finished with value: -0.9436884547568107 and parameters: {'ema1': 10, 'ema2': 86, 'ema3': 120}. Best is trial 733 with value: -1.3336313303376228.
# Trial 947: EMA(14,88,128) → Sortino: 1.050
# [I 2025-10-27 23:02:27,238] Trial 946 finished with value: -1.0503309676960664 and parameters: {'ema1': 14, 'ema2': 88, 'ema3': 128}. Best is trial 733 with value: -1.3336313303376228.
# Trial 948: EMA(12,88,132) → Sortino: 1.326
# [I 2025-10-27 23:02:27,326] Trial 947 finished with value: -1.325568128912882 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 132}. Best is trial 733 with value: -1.3336313303376228.
# Trial 949: EMA(13,86,131) → Sortino: 1.011
# [I 2025-10-27 23:02:27,422] Trial 948 finished with value: -1.0110760717429779 and parameters: {'ema1': 13, 'ema2': 86, 'ema3': 131}. Best is trial 733 with value: -1.3336313303376228.
# Trial 950: EMA(11,87,127) → Sortino: 1.149
# [I 2025-10-27 23:02:27,509] Trial 949 finished with value: -1.1488069899595335 and parameters: {'ema1': 11, 'ema2': 87, 'ema3': 127}. Best is trial 733 with value: -1.3336313303376228.
# Trial 951: EMA(12,87,132) → Sortino: 1.257
# [I 2025-10-27 23:02:27,605] Trial 950 finished with value: -1.2569778006048766 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 132}. Best is trial 733 with value: -1.3336313303376228.
# [I 2025-10-27 23:02:27,695] Trial 951 finished with value: 999.0 and parameters: {'ema1': 33, 'ema2': 86, 'ema3': 130}. Best is trial 733 with value: -1.3336313303376228.
# Trial 953: EMA(13,88,124) → Sortino: 1.047
# [I 2025-10-27 23:02:27,791] Trial 952 finished with value: -1.046808901339117 and parameters: {'ema1': 13, 'ema2': 88, 'ema3': 124}. Best is trial 733 with value: -1.3336313303376228.
# Trial 954: EMA(21,85,133) → Sortino: 1.065
# [I 2025-10-27 23:02:27,879] Trial 953 finished with value: -1.065328382361191 and parameters: {'ema1': 21, 'ema2': 85, 'ema3': 133}. Best is trial 733 with value: -1.3336313303376228.
# Trial 955: EMA(12,87,128) → Sortino: 1.223
# [I 2025-10-27 23:02:27,976] Trial 954 finished with value: -1.2229791347763097 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 128}. Best is trial 733 with value: -1.3336313303376228.
# Trial 956: EMA(11,88,137) → Sortino: 1.158
# [I 2025-10-27 23:02:28,063] Trial 955 finished with value: -1.1579753094259992 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 137}. Best is trial 733 with value: -1.3336313303376228.
# Trial 957: EMA(14,87,132) → Sortino: 1.127
# [I 2025-10-27 23:02:28,155] Trial 956 finished with value: -1.1272743824412972 and parameters: {'ema1': 14, 'ema2': 87, 'ema3': 132}. Best is trial 733 with value: -1.3336313303376228.
# Trial 958: EMA(10,88,140) → Sortino: 1.074
# [I 2025-10-27 23:02:28,248] Trial 957 finished with value: -1.0742967441141837 and parameters: {'ema1': 10, 'ema2': 88, 'ema3': 140}. Best is trial 733 with value: -1.3336313303376228.
# Trial 959: EMA(13,86,126) → Sortino: 0.984
# [I 2025-10-27 23:02:28,340] Trial 958 finished with value: -0.9837505627429964 and parameters: {'ema1': 13, 'ema2': 86, 'ema3': 126}. Best is trial 733 with value: -1.3336313303376228.
# Trial 960: EMA(11,88,136) → Sortino: 1.163
# [I 2025-10-27 23:02:28,427] Trial 959 finished with value: -1.163456418813155 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 136}. Best is trial 733 with value: -1.3336313303376228.
# Trial 961: EMA(12,87,130) → Sortino: 1.223
# [I 2025-10-27 23:02:28,522] Trial 960 finished with value: -1.2229791347763097 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 130}. Best is trial 733 with value: -1.3336313303376228.
# Trial 962: EMA(12,88,135) → Sortino: 1.320
# [I 2025-10-27 23:02:28,612] Trial 961 finished with value: -1.3200643392608775 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 135}. Best is trial 733 with value: -1.3336313303376228.
# Trial 963: EMA(11,87,133) → Sortino: 1.153
# [I 2025-10-27 23:02:28,707] Trial 962 finished with value: -1.15272380251502 and parameters: {'ema1': 11, 'ema2': 87, 'ema3': 133}. Best is trial 733 with value: -1.3336313303376228.
# Trial 964: EMA(13,86,123) → Sortino: 1.064
# [I 2025-10-27 23:02:28,798] Trial 963 finished with value: -1.0640854509593558 and parameters: {'ema1': 13, 'ema2': 86, 'ema3': 123}. Best is trial 733 with value: -1.3336313303376228.
# Trial 965: EMA(12,85,129) → Sortino: 1.126
# [I 2025-10-27 23:02:28,892] Trial 964 finished with value: -1.125971600478385 and parameters: {'ema1': 12, 'ema2': 85, 'ema3': 129}. Best is trial 733 with value: -1.3336313303376228.
# Trial 966: EMA(10,66,134) → Sortino: 1.035
# [I 2025-10-27 23:02:28,980] Trial 965 finished with value: -1.0351026597041908 and parameters: {'ema1': 10, 'ema2': 66, 'ema3': 134}. Best is trial 733 with value: -1.3336313303376228.
# Trial 967: EMA(14,87,138) → Sortino: 1.085
# [I 2025-10-27 23:02:29,077] Trial 966 finished with value: -1.0850212262594052 and parameters: {'ema1': 14, 'ema2': 87, 'ema3': 138}. Best is trial 733 with value: -1.3336313303376228.
# Trial 968: EMA(12,87,126) → Sortino: 1.278
# [I 2025-10-27 23:02:29,163] Trial 967 finished with value: -1.2777381218496258 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 126}. Best is trial 733 with value: -1.3336313303376228.
# Trial 969: EMA(4,88,145) → Sortino: 0.783
# [I 2025-10-27 23:02:29,256] Trial 968 finished with value: -0.7829777748888149 and parameters: {'ema1': 4, 'ema2': 88, 'ema3': 145}. Best is trial 733 with value: -1.3336313303376228.
# Trial 970: EMA(13,88,132) → Sortino: 1.074
# [I 2025-10-27 23:02:29,348] Trial 969 finished with value: -1.0741366083107853 and parameters: {'ema1': 13, 'ema2': 88, 'ema3': 132}. Best is trial 733 with value: -1.3336313303376228.
# Trial 971: EMA(11,88,141) → Sortino: 1.158
# [I 2025-10-27 23:02:29,442] Trial 970 finished with value: -1.1579753094259992 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 141}. Best is trial 733 with value: -1.3336313303376228.
# Trial 972: EMA(12,87,136) → Sortino: 1.251
# [I 2025-10-27 23:02:29,530] Trial 971 finished with value: -1.251478245676003 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 136}. Best is trial 733 with value: -1.3336313303376228.
# Trial 973: EMA(13,85,120) → Sortino: 1.299
# [I 2025-10-27 23:02:29,627] Trial 972 finished with value: -1.299163391297007 and parameters: {'ema1': 13, 'ema2': 85, 'ema3': 120}. Best is trial 733 with value: -1.3336313303376228.
# Trial 974: EMA(11,88,129) → Sortino: 1.159
# [I 2025-10-27 23:02:29,714] Trial 973 finished with value: -1.1591833711153559 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 129}. Best is trial 733 with value: -1.3336313303376228.
# Trial 975: EMA(14,87,134) → Sortino: 1.085
# [I 2025-10-27 23:02:29,810] Trial 974 finished with value: -1.0850212262594052 and parameters: {'ema1': 14, 'ema2': 87, 'ema3': 134}. Best is trial 733 with value: -1.3336313303376228.
# Trial 976: EMA(10,84,139) → Sortino: 1.047
# [I 2025-10-27 23:02:29,899] Trial 975 finished with value: -1.0469210672291651 and parameters: {'ema1': 10, 'ema2': 84, 'ema3': 139}. Best is trial 733 with value: -1.3336313303376228.
# Trial 977: EMA(12,86,131) → Sortino: 1.170
# [I 2025-10-27 23:02:29,996] Trial 976 finished with value: -1.169944017111985 and parameters: {'ema1': 12, 'ema2': 86, 'ema3': 131}. Best is trial 733 with value: -1.3336313303376228.
# Trial 978: EMA(11,88,127) → Sortino: 1.155
# [I 2025-10-27 23:02:30,083] Trial 977 finished with value: -1.1552747750031356 and parameters: {'ema1': 11, 'ema2': 88, 'ema3': 127}. Best is trial 733 with value: -1.3336313303376228.
# Trial 979: EMA(13,89,123) → Sortino: 1.099
# [I 2025-10-27 23:02:30,175] Trial 978 finished with value: -1.0991341605069298 and parameters: {'ema1': 13, 'ema2': 89, 'ema3': 123}. Best is trial 733 with value: -1.3336313303376228.
# Trial 980: EMA(12,88,135) → Sortino: 1.320
# [I 2025-10-27 23:02:30,263] Trial 979 finished with value: -1.3200643392608775 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 135}. Best is trial 733 with value: -1.3336313303376228.
# Trial 981: EMA(12,86,138) → Sortino: 1.198
# [I 2025-10-27 23:02:30,452] Trial 980 finished with value: -1.1984560677095797 and parameters: {'ema1': 12, 'ema2': 86, 'ema3': 138}. Best is trial 733 with value: -1.3336313303376228.
# Trial 982: EMA(13,87,132) → Sortino: 1.074
# [I 2025-10-27 23:02:30,552] Trial 981 finished with value: -1.0741366083107853 and parameters: {'ema1': 13, 'ema2': 87, 'ema3': 132}. Best is trial 733 with value: -1.3336313303376228.
# Trial 983: EMA(11,53,135) → Sortino: 0.780
# [I 2025-10-27 23:02:30,644] Trial 982 finished with value: -0.7795337238348438 and parameters: {'ema1': 11, 'ema2': 53, 'ema3': 135}. Best is trial 733 with value: -1.3336313303376228.
# Trial 984: EMA(12,87,141) → Sortino: 1.251
# [I 2025-10-27 23:02:30,735] Trial 983 finished with value: -1.251478245676003 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 141}. Best is trial 733 with value: -1.3336313303376228.
# Trial 985: EMA(13,87,125) → Sortino: 1.047
# [I 2025-10-27 23:02:30,830] Trial 984 finished with value: -1.046808901339117 and parameters: {'ema1': 13, 'ema2': 87, 'ema3': 125}. Best is trial 733 with value: -1.3336313303376228.
# [I 2025-10-27 23:02:30,919] Trial 985 finished with value: 999.0 and parameters: {'ema1': 31, 'ema2': 86, 'ema3': 129}. Best is trial 733 with value: -1.3336313303376228.
# Trial 987: EMA(15,88,138) → Sortino: 1.000
# [I 2025-10-27 23:02:31,019] Trial 986 finished with value: -1.000275759435058 and parameters: {'ema1': 15, 'ema2': 88, 'ema3': 138}. Best is trial 733 with value: -1.3336313303376228.
# Trial 988: EMA(9,88,134) → Sortino: 0.884
# [I 2025-10-27 23:02:31,109] Trial 987 finished with value: -0.8838391245726525 and parameters: {'ema1': 9, 'ema2': 88, 'ema3': 134}. Best is trial 733 with value: -1.3336313303376228.
# Trial 989: EMA(11,87,131) → Sortino: 1.153
# [I 2025-10-27 23:02:31,202] Trial 988 finished with value: -1.15272380251502 and parameters: {'ema1': 11, 'ema2': 87, 'ema3': 131}. Best is trial 733 with value: -1.3336313303376228.
# Trial 990: EMA(12,88,143) → Sortino: 1.320
# [I 2025-10-27 23:02:31,294] Trial 989 finished with value: -1.3200643392608775 and parameters: {'ema1': 12, 'ema2': 88, 'ema3': 143}. Best is trial 733 with value: -1.3336313303376228.
# Trial 991: EMA(12,86,127) → Sortino: 1.229
# [I 2025-10-27 23:02:31,389] Trial 990 finished with value: -1.2289240081872304 and parameters: {'ema1': 12, 'ema2': 86, 'ema3': 127}. Best is trial 733 with value: -1.3336313303376228.
# Trial 992: EMA(10,86,145) → Sortino: 1.086
# [I 2025-10-27 23:02:31,479] Trial 991 finished with value: -1.0857451101488107 and parameters: {'ema1': 10, 'ema2': 86, 'ema3': 145}. Best is trial 733 with value: -1.3336313303376228.
# Trial 993: EMA(13,87,141) → Sortino: 1.032
# [I 2025-10-27 23:02:31,575] Trial 992 finished with value: -1.0318431006033786 and parameters: {'ema1': 13, 'ema2': 87, 'ema3': 141}. Best is trial 733 with value: -1.3336313303376228.
# Trial 994: EMA(11,86,123) → Sortino: 1.101
# [I 2025-10-27 23:02:31,664] Trial 993 finished with value: -1.1010006170372173 and parameters: {'ema1': 11, 'ema2': 86, 'ema3': 123}. Best is trial 733 with value: -1.3336313303376228.
# Trial 995: EMA(14,79,130) → Sortino: 1.130
# [I 2025-10-27 23:02:31,758] Trial 994 finished with value: -1.1302346708479385 and parameters: {'ema1': 14, 'ema2': 79, 'ema3': 130}. Best is trial 733 with value: -1.3336313303376228.
# Trial 996: EMA(11,87,133) → Sortino: 1.153
# [I 2025-10-27 23:02:31,851] Trial 995 finished with value: -1.15272380251502 and parameters: {'ema1': 11, 'ema2': 87, 'ema3': 133}. Best is trial 733 with value: -1.3336313303376228.
# Trial 997: EMA(13,88,137) → Sortino: 1.074
# [I 2025-10-27 23:02:31,948] Trial 996 finished with value: -1.0741366083107853 and parameters: {'ema1': 13, 'ema2': 88, 'ema3': 137}. Best is trial 733 with value: -1.3336313303376228.
# Trial 998: EMA(12,87,126) → Sortino: 1.278
# [I 2025-10-27 23:02:32,035] Trial 997 finished with value: -1.2777381218496258 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 126}. Best is trial 733 with value: -1.3336313303376228.
# Trial 999: EMA(13,88,144) → Sortino: 0.984
# [I 2025-10-27 23:02:32,130] Trial 998 finished with value: -0.9841608939596397 and parameters: {'ema1': 13, 'ema2': 88, 'ema3': 144}. Best is trial 733 with value: -1.3336313303376228.
# Trial 1000: EMA(12,87,139) → Sortino: 1.251
# [I 2025-10-27 23:02:32,219] Trial 999 finished with value: -1.251478245676003 and parameters: {'ema1': 12, 'ema2': 87, 'ema3': 139}. Best is trial 733 with value: -1.3336313303376228.
#
# ✅ Optimization complete!
# Best Parameters: EMA(12,89,125)
# Sortino Ratio: 1.334

# %%
# Display Results

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    
    print("OPTIMIZATION RESULTS:")
    print("=" * 50)
    print(f"Best Parameters:")
    print(f"  EMA1 (Fast): {int(best['ema1_period'])}")
    print(f"  EMA2 (Medium): {int(best['ema2_period'])}")
    print(f"  EMA3 (Slow): {int(best['ema3_period'])}")
    
    print("\nPerformance Metrics:")
    print(f"  Total Return: {best['total_return']:.2%}")
    print(f"  Sharpe Ratio: {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio: {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown: {best['max_drawdown']:.2%}")
    print(f"  Total Trades: {int(best['total_trades'])}")
    print(f"  Win Rate: {best['win_rate']:.1f}%")
    print(f"  Profit Factor: {best['profit_factor']:.2f}")
else:
    print("⚠️ No results found. Run optimization first.")
# Out:
# OPTIMIZATION RESULTS:
# ==================================================
# Best Parameters:
#   EMA1 (Fast): 12
#   EMA2 (Medium): 89
#   EMA3 (Slow): 125
#
# Performance Metrics:
#   Total Return: 243.36%
#   Sharpe Ratio: 0.974
#   Sortino Ratio: 1.334
#   Max Drawdown: -37.50%
#   Total Trades: 8
#   Win Rate: 50.0%
#   Profit Factor: 9.09

# %%
# BENCHMARK ANALYSIS: Best Strategy vs Market (Buy & Hold) - ENHANCED

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"BENCHMARK ANALYSIS: Best EMA({ema1},{ema2},{ema3}) vs Buy & Hold")
    print("=" * 70)

    # Recreate the BEST strategy portfolio to get returns
    ema1_ma = vbt.MA.run(train_close, ema1, ewm=True)
    ema2_ma = vbt.MA.run(train_close, ema2, ewm=True)
    ema3_ma = vbt.MA.run(train_close, ema3, ewm=True)

    # Triple EMA crossover signals
    entries = (
        ema1_ma.ma_crossed_above(ema2_ma.ma) |
        ema1_ma.ma_crossed_above(ema3_ma.ma) |
        ema2_ma.ma_crossed_above(ema3_ma.ma)
    )
    exits = (
        ema1_ma.ma_crossed_below(ema2_ma.ma) |
        ema1_ma.ma_crossed_below(ema3_ma.ma) |
        ema2_ma.ma_crossed_below(ema3_ma.ma)
    )

    best_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Create buy & hold benchmark
    benchmark_entries = np.zeros(len(train_close), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(train_close), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Get returns for comparison
    strategy_returns = best_pf.returns().dropna()
    benchmark_returns = benchmark_pf.returns().dropna()

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy annualized return
    strategy_annualized_return = best['annualized_return']

    # Performance comparison
    print("\nPERFORMANCE COMPARISON:")
    print(f"Strategy (EMA {ema1},{ema2},{ema3}):")
    print(f"  Total Return:      {best['total_return']:.2%}")
    print(f"  Annualized Return: {strategy_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio:     {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown:      {best['max_drawdown']:.2%}")
    print(f"  Volatility:        {best['volatility']:.2%}")
    print(f"  Total Trades:      {best['total_trades']}")
    print(f"  Win Rate:          {best['win_rate']:.1f}%")
    print(f"  Profit Factor:     {best['profit_factor']:.2f}")

    print(f"\nBenchmark (Buy & Hold {TICKER}):")
    print(f"  Total Return:      {bench_total_return:.2%}")
    print(f"  Annualized Return: {bench_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {bench_sharpe:.3f}")
    print(f"  Sortino Ratio:     {bench_sortino:.3f}")
    print(f"  Max Drawdown:      {bench_max_drawdown:.2%}")
    print(f"  Volatility:        {bench_volatility:.2%}")

    # Outperformance metrics
    excess_return = best['total_return'] - bench_total_return
    excess_annualized_return = strategy_annualized_return - bench_annualized_return
    sharpe_diff = best['sharpe_ratio'] - bench_sharpe
    sortino_diff = best['sortino_ratio'] - bench_sortino
    excess_max_drawdown = best['max_drawdown'] - bench_max_drawdown

    print(f"\nOUTPERFORMANCE METRICS:")
    print(f"  Excess Return:           {excess_return:.2%}")
    print(f"  Excess Annualized Return: {excess_annualized_return:.2%}")
    print(f"  Sharpe Difference:       {sharpe_diff:.3f}")
    print(f"  Sortino Difference:      {sortino_diff:.3f}")
    print(f"  Excess Max Drawdown:      {excess_max_drawdown:.2%} ({'Better' if excess_max_drawdown > 0 else '❌ Worse'})")
    
    # Calculate beta
    market_beta = best['volatility'] / bench_volatility if bench_volatility != 0 else np.nan
    print(f"  Market Beta (approx):     {market_beta:.3f} ({'Lower risk' if market_beta < 1 else '⚠️ Higher risk'})")
else:
    print("⚠️ No results available for benchmark analysis.")
# Out:
# BENCHMARK ANALYSIS: Best EMA(12,89,125) vs Buy & Hold
# ======================================================================
#
# PERFORMANCE COMPARISON:
# Strategy (EMA 12,89,125):
#   Total Return:      243.36%
#   Annualized Return: 30.17%
#   Sharpe Ratio:      0.974
#   Sortino Ratio:     1.334
#   Max Drawdown:      -37.50%
#   Volatility:        54.99%
#   Total Trades:      8.0
#   Win Rate:          50.0%
#   Profit Factor:     9.09
#
# Benchmark (Buy & Hold TQQQ):
#   Total Return:      127.54%
#   Annualized Return: 28.98%
#   Sharpe Ratio:      0.746
#   Sortino Ratio:     1.028
#   Max Drawdown:      -75.32%
#   Volatility:        91.50%
#
# OUTPERFORMANCE METRICS:
#   Excess Return:           115.82%
#   Excess Annualized Return: 1.18%
#   Sharpe Difference:       0.228
#   Sortino Difference:      0.306
#   Excess Max Drawdown:      37.81% (Better)
#   Market Beta (approx):     0.601 (Lower risk)

# %%
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON

FREQ = "1D"

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Out-of-sample validation
    ema1_val = vbt.MA.run(val_close, ema1, ewm=True).ma
    ema2_val = vbt.MA.run(val_close, ema2, ewm=True).ma
    ema3_val = vbt.MA.run(val_close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_val = (
        ema1_val.vbt.crossed_above(ema2_val) |
        ema1_val.vbt.crossed_above(ema3_val) |
        ema2_val.vbt.crossed_above(ema3_val)
    )
    exits_val = (
        ema1_val.vbt.crossed_below(ema2_val) |
        ema1_val.vbt.crossed_below(ema3_val) |
        ema2_val.vbt.crossed_below(ema3_val)
    )

    pf_val = vbt.Portfolio.from_signals(
        close=val_close,
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Out-of-sample metrics
    val_total_return = pf_val.total_return()
    val_annualized_return = pf_val.annualized_return(freq=FREQ)
    val_sharpe = pf_val.sharpe_ratio(freq=FREQ)
    val_sortino = pf_val.sortino_ratio(freq=FREQ)
    val_max_drawdown = pf_val.max_drawdown()
    val_volatility = pf_val.annualized_volatility(freq=FREQ)

    trades_val = pf_val.trades
    val_total_trades = len(trades_val)
    years = max((val_close.index[-1] - val_close.index[0]).days / 365.25, 1e-9)
    val_trades_per_year = val_total_trades / years

    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    def chg(before, after):
        if pd.isna(before) or pd.isna(after) or before == 0:
            return "N/A"
        return f"{((after - before) / abs(before)) * 100:+.1f}%"

    print(f"IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best EMA({ema1},{ema2},{ema3})")
    print("=" * 80)

    print(f"{'METRIC':<25} {'IN-SAMPLE':<15} {'OUT-OF-SAMPLE':<15} {'DEGRADATION':<15}")

    print("\nRETURN METRICS:")
    print(f"{'Total Return':<25} {best['total_return']:<15.2%} {val_total_return:<15.2%} {chg(best['total_return'], val_total_return)}")
    print(f"{'Annualized Return':<25} {best['annualized_return']:<15.2%} {val_annualized_return:<15.2%} {chg(best['annualized_return'], val_annualized_return)}")

    print("\nRISK-ADJUSTED METRICS:")
    print(f"{'Sharpe Ratio':<25} {best['sharpe_ratio']:<15.3f} {val_sharpe:<15.3f} {chg(best['sharpe_ratio'], val_sharpe)}")
    print(f"{'Sortino Ratio':<25} {best['sortino_ratio']:<15.3f} {val_sortino:<15.3f} {chg(best['sortino_ratio'], val_sortino)}")

    print("\nRISK METRICS:")
    print(f"{'Max Drawdown':<25} {best['max_drawdown']:<15.2%} {val_max_drawdown:<15.2%} {chg(best['max_drawdown'], val_max_drawdown)}")
    print(f"{'Volatility':<25} {best['volatility']:<15.2%} {val_volatility:<15.2%} {chg(best['volatility'], val_volatility)}")

    print("\nTRADE METRICS:")
    print(f"{'Total Trades':<25} {best['total_trades']:<15.0f} {val_total_trades:<15.0f} {chg(best['total_trades'], val_total_trades)}")
    print(f"{'Trades per Year':<25} {best['trades_per_year']:<15.1f} {val_trades_per_year:<15.1f} {chg(best['trades_per_year'], val_trades_per_year)}")
    print(f"{'Win Rate %':<25} {best['win_rate']:<15.1f} {val_win_rate_pct:<15.1f} {chg(best['win_rate'], val_win_rate_pct)}")
    print(f"{'Profit Factor':<25} {best['profit_factor']:<15.2f} {val_profit_factor:<15.2f} {chg(best['profit_factor'], val_profit_factor)}")
    print(f"{'Expectancy':<25} {best['expectancy']:<15.4f} {val_expectancy:<15.4f} {chg(best['expectancy'], val_expectancy)}")
else:
    print("⚠️ No results for comparison.")
# Out:
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best EMA(12,89,125)
# ================================================================================
# METRIC                    IN-SAMPLE       OUT-OF-SAMPLE   DEGRADATION
#
# RETURN METRICS:
# Total Return              243.36%         156.77%         -35.6%
# Annualized Return         30.17%          54.86%          +81.9%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio              0.974           1.103           +13.3%
# Sortino Ratio             1.334           1.586           +18.9%
#
# RISK METRICS:
# Max Drawdown              -37.50%         -45.02%         -20.0%
# Volatility                54.99%          51.94%          -5.5%
#
# TRADE METRICS:
# Total Trades              8               8               +0.0%
# Trades per Year           1.7             2.6             +49.3%
# Win Rate %                50.0            50.0            +0.0%
# Profit Factor             9.09            5.05            -44.4%
# Expectancy                0.3120          0.1568          -49.7%

# %%
# OUT-OF-SAMPLE BENCHMARK COMPARISON

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"OUT-OF-SAMPLE BENCHMARK: Best EMA({ema1},{ema2},{ema3}) vs Buy & Hold")
    print("=" * 70)

    # Use validation data
    close_data = val_close
    
    # Recreate the BEST strategy portfolio
    ema1_ma = vbt.MA.run(close_data, ema1, ewm=True)
    ema2_ma = vbt.MA.run(close_data, ema2, ewm=True)
    ema3_ma = vbt.MA.run(close_data, ema3, ewm=True)

    entries_raw = (
        ema1_ma.ma_crossed_above(ema2_ma.ma) |
        ema1_ma.ma_crossed_above(ema3_ma.ma) |
        ema2_ma.ma_crossed_above(ema3_ma.ma)
    )
    exits_raw = (
        ema1_ma.ma_crossed_below(ema2_ma.ma) |
        ema1_ma.ma_crossed_below(ema3_ma.ma) |
        ema2_ma.ma_crossed_below(ema3_ma.ma)
    )
    
    entries = pd.Series(np.asarray(entries_raw).ravel(), index=close_data.index, dtype=bool)
    exits = pd.Series(np.asarray(exits_raw).ravel(), index=close_data.index, dtype=bool)

    strategy_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Buy & hold benchmark
    benchmark_entries = np.zeros(len(close_data), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(close_data), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy metrics
    trades_val = strategy_pf.trades
    val_total_trades = len(trades_val)
    years = max((close_data.index[-1] - close_data.index[0]).days / 365.25, 1e-9)
    
    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    strategy_total_return = strategy_pf.total_return()
    strategy_annualized_return = strategy_pf.annualized_return(freq='D')
    strategy_sharpe = strategy_pf.sharpe_ratio(freq='D')
    strategy_sortino = strategy_pf.sortino_ratio(freq='D')
    strategy_max_drawdown = strategy_pf.max_drawdown()
    strategy_volatility = strategy_pf.annualized_volatility(freq='D')

    # Performance comparison
    print(f"\n{'METRIC':<30} {'STRATEGY':<20} {'BUY & HOLD':<15} {'OUTPERFORMANCE':<15}")
    print("=" * 80)
    
    print(f"\nRETURN METRICS:")
    excess_return = strategy_total_return - bench_total_return
    print(f"{'Total Return':<30} {strategy_total_return:>20.2%} {bench_total_return:>15.2%} {excess_return:>+15.2%}")
    
    excess_annual = strategy_annualized_return - bench_annualized_return
    print(f"{'Annualized Return':<30} {strategy_annualized_return:>20.2%} {bench_annualized_return:>15.2%} {excess_annual:>+15.2%}")

    print(f"\nRISK-ADJUSTED METRICS:")
    excess_sharpe = strategy_sharpe - bench_sharpe
    print(f"{'Sharpe Ratio':<30} {strategy_sharpe:>20.3f} {bench_sharpe:>15.3f} {excess_sharpe:>+15.3f}")
    
    excess_sortino = strategy_sortino - bench_sortino
    print(f"{'Sortino Ratio':<30} {strategy_sortino:>20.3f} {bench_sortino:>15.3f} {excess_sortino:>+15.3f}")

    print(f"\nRISK METRICS:")
    excess_dd = strategy_max_drawdown - bench_max_drawdown
    print(f"{'Max Drawdown':<30} {strategy_max_drawdown:>20.2%} {bench_max_drawdown:>15.2%} {excess_dd:>+15.2%}")
    
    excess_vol = strategy_volatility - bench_volatility
    print(f"{'Volatility':<30} {strategy_volatility:>20.2%} {bench_volatility:>15.2%} {excess_vol:>+15.2%}")

    print(f"\nTRADE METRICS:")
    print(f"{'Total Trades':<30} {val_total_trades:>20.0f}")
    print(f"{'Win Rate %':<30} {val_win_rate_pct:>20.1f}")
    print(f"{'Profit Factor':<30} {val_profit_factor:>20.2f}")
    print(f"{'Expectancy':<30} {val_expectancy:>20.4f}")

    print(f"\n✅ Out-of-sample evaluation complete!")
    print(f"📊 Period: {close_data.index[0].date()} → {close_data.index[-1].date()}")
    
    # Summary verdict
    if strategy_total_return > bench_total_return and strategy_sharpe > bench_sharpe:
        print(f"🏆 Strategy OUTPERFORMS Buy & Hold on validation set!")
    elif strategy_total_return > bench_total_return:
        print(f"📈 Strategy has higher returns but Buy & Hold has better Sharpe")
    elif strategy_sharpe > bench_sharpe:
        print(f"💪 Strategy has better risk-adjusted returns despite lower total return")
    else:
        print(f"⚠️ Strategy underperforms Buy & Hold on validation set")
else:
    print("⚠️ No results available.")
# Out:
# OUT-OF-SAMPLE BENCHMARK: Best EMA(12,89,125) vs Buy & Hold
# ======================================================================
#
# METRIC                         STRATEGY             BUY & HOLD      OUTPERFORMANCE
# ================================================================================
#
# RETURN METRICS:
# Total Return                                156.77%         332.81%        -176.04%
# Annualized Return                            54.86%          97.29%         -42.43%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio                                  1.103           1.262          -0.159
# Sortino Ratio                                 1.586           1.882          -0.296
#
# RISK METRICS:
# Max Drawdown                                -45.02%         -58.04%         +13.02%
# Volatility                                   51.94%          77.31%         -25.36%
#
# TRADE METRICS:
# Total Trades                                      8
# Win Rate %                                     50.0
# Profit Factor                                  5.05
# Expectancy                                   0.1568
#
# ✅ Out-of-sample evaluation complete!
# 📊 Period: 2022-09-08 → 2025-10-27
# ⚠️ Strategy underperforms Buy & Hold on validation set

# %%
# ROLLING SHARPE + DRAWDOWNS - BEST STRATEGY (FULL SAMPLE)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Build full-sample Triple EMA signals
    ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
    ema2_full = vbt.MA.run(close, ema2, ewm=True).ma
    ema3_full = vbt.MA.run(close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_full = (
        ema1_full.vbt.crossed_above(ema2_full) |
        ema1_full.vbt.crossed_above(ema3_full) |
        ema2_full.vbt.crossed_above(ema3_full)
    )
    exits_full = (
        ema1_full.vbt.crossed_below(ema2_full) |
        ema1_full.vbt.crossed_below(ema3_full) |
        ema2_full.vbt.crossed_below(ema3_full)
    )

    entries_full = entries_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)
    exits_full = exits_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)

    pf_full = vbt.Portfolio.from_signals(
        close=close.to_numpy(dtype=float),
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Compute returns
    ret = pf_full.returns()

    # 1) Rolling Sharpe (252-day window)
    rolling_window = max(20, min(252, max(1, len(ret) // 4)))
    if len(ret) > rolling_window:
        rolling_sharpe = ret.rolling(window=rolling_window).apply(
            lambda x: (x.mean() * 252) / (x.std() * np.sqrt(252)) if x.std() and x.std() != 0 else np.nan,
            raw=False
        )

        plt.figure(figsize=(12, 5))
        plt.plot(rolling_sharpe.index, rolling_sharpe.values, linewidth=2, color='blue', alpha=0.85)
        plt.axhline(y=1.0, color='green', linestyle='--', alpha=0.6, label='Sharpe = 1.0')
        plt.axhline(y=0.5, color='orange', linestyle='--', alpha=0.6, label='Sharpe = 0.5')
        plt.axhline(y=0.0, color='red', linestyle='--', alpha=0.6, label='Sharpe = 0.0')
        plt.title(f'Rolling Sharpe (window={rolling_window}) - Best EMA({ema1},{ema2},{ema3}) Full Sample', fontsize=14, fontweight='bold')
        plt.xlabel('Date', fontsize=12)
        plt.ylabel('Rolling Sharpe Ratio', fontsize=12)
        plt.grid(True, alpha=0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()
    else:
        print("⚠️ Not enough data for rolling Sharpe calculation.")

    # 2) Drawdowns (underwater)
    eq = (1 + ret).cumprod()
    peak = eq.cummax()
    dd = (eq - peak) / peak

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    ax1.plot(eq.index, (eq - 1) * 100, color='black', linewidth=1.5, label='Cumulative Return %')
    ax1.plot(peak.index, (peak - 1) * 100, color='green', linewidth=1.0, alpha=0.7, label='Peak %')
    ax1.fill_between(eq.index, (eq - 1) * 100, (peak - 1) * 100, color='red', alpha=0.25, label='Drawdown Area')
    ax1.set_title(f'Cumulative Returns & Drawdowns - Best EMA({ema1},{ema2},{ema3}) Full Sample', fontsize=14, fontweight='bold')
    ax1.set_ylabel('Return (%)', fontsize=12)
    ax1.grid(True, alpha=0.3)
    ax1.legend()

    ax2.fill_between(dd.index, dd * 100, 0, color='red', alpha=0.7, label='Drawdown %')
    ax2.plot(dd.index, dd * 100, color='darkred', linewidth=1)
    ax2.set_title('Underwater Chart (Drawdown from Peak)', fontsize=13)
    ax2.set_xlabel('Date', fontsize=12)
    ax2.set_ylabel('Drawdown (%)', fontsize=12)
    ax2.grid(True, alpha=0.3)
    ax2.legend()

    plt.tight_layout()
    plt.show()

    print(f"✅ Rolling Sharpe and Drawdown analysis complete for best strategy: EMA({ema1},{ema2},{ema3})")
else:
    print("⚠️ No results to visualize.")
# Out:
# ✅ Rolling Sharpe and Drawdown analysis complete for best strategy: EMA(12,89,125)

# %%
# VISUALS: Signals + Equity Curves - BEST STRATEGY

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Build full sample EMAs and signals
    ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
    ema2_full = vbt.MA.run(close, ema2, ewm=True).ma
    ema3_full = vbt.MA.run(close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_1 = ema1_full.vbt.crossed_above(ema2_full)
    entries_2 = ema1_full.vbt.crossed_above(ema3_full)
    entries_3 = ema2_full.vbt.crossed_above(ema3_full)
    entries_full = (entries_1 | entries_2 | entries_3)
    
    exits_1 = ema1_full.vbt.crossed_below(ema2_full)
    exits_2 = ema1_full.vbt.crossed_below(ema3_full)
    exits_3 = ema2_full.vbt.crossed_below(ema3_full)
    exits_full = (exits_1 | exits_2 | exits_3)

    entries_full = entries_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)
    exits_full = exits_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)

    # 1) Price + Triple EMAs + signals (full sample)
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, close.values, label='Close', color='black', linewidth=1.5, alpha=0.7)
    ax.plot(close.index, ema1_full.values, label=f'Fast EMA ({ema1})', color='blue', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema2_full.values, label=f'Medium EMA ({ema2})', color='orange', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema3_full.values, label=f'Slow EMA ({ema3})', color='purple', alpha=0.8, linewidth=1.2)

    buy_idx = close.index[entries_full]
    sell_idx = close.index[exits_full]
    ax.scatter(buy_idx, close.reindex(buy_idx).values, marker='^', color='green', s=80, label='Buy', zorder=5)
    ax.scatter(sell_idx, close.reindex(sell_idx).values, marker='v', color='red', s=80, label='Sell', zorder=5)

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Full Sample Signals', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Price', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    # 2) Equity curves: train / val / full
    price_full = close.to_numpy(dtype=float)
    entries_train = entries_full[:split_idx]
    exits_train = exits_full[:split_idx]
    entries_val = entries_full[split_idx:]
    exits_val = exits_full[split_idx:]

    pf_full = vbt.Portfolio.from_signals(
        close=price_full,
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_train = vbt.Portfolio.from_signals(
        close=train_close.to_numpy(dtype=float),
        entries=entries_train,
        exits=exits_train,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_val2 = vbt.Portfolio.from_signals(
        close=val_close.to_numpy(dtype=float),
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    eq_full = (1 + pf_full.returns()).cumprod()
    eq_train = (1 + pf_train.returns()).cumprod()
    eq_val = (1 + pf_val2.returns()).cumprod()

    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, eq_full.values, label='Full Sample', color='black', linewidth=2)
    ax.plot(train_close.index, eq_train.values, label='Train (In-Sample)', color='blue', linewidth=1.5, alpha=0.8)
    ax.plot(val_close.index, eq_val.values, label='Validation (Out-of-Sample)', color='orange', linewidth=1.5, alpha=0.8)

    # Add vertical line to show train/val split
    ax.axvline(x=train_close.index[-1], color='red', linestyle='--', alpha=0.5, label='Train/Val Split')

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Equity Curves', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Cumulative Returns (normalized to 1)', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    print(f"✅ Visualizations complete for best strategy: EMA({ema1},{ema2},{ema3})")
else:
    print("⚠️ No results to visualize.")
# Out:
# ✅ Visualizations complete for best strategy: EMA(12,89,125)

# %%
# TRADE-BY-TRADE RETURNS (BAR) + CUMULATIVE PER-TRADE EQUITY

if 'results_df' not in globals() or results_df.empty:
    print("⚠️ No results available.")
else:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Resolve full close series
    full_close = close.astype(float)

    # Indicators
    ema1_full = vbt.MA.run(full_close, ema1, ewm=True)
    ema2_full = vbt.MA.run(full_close, ema2, ewm=True)
    ema3_full = vbt.MA.run(full_close, ema3, ewm=True)

    # Signals
    entries_raw = (
        ema1_full.ma_crossed_above(ema2_full.ma) |
        ema1_full.ma_crossed_above(ema3_full.ma) |
        ema2_full.ma_crossed_above(ema3_full.ma)
    )
    exits_raw = (
        ema1_full.ma_crossed_below(ema2_full.ma) |
        ema1_full.ma_crossed_below(ema3_full.ma) |
        ema2_full.ma_crossed_below(ema3_full.ma)
    )

    entries_full = pd.Series(np.asarray(entries_raw).ravel(), index=full_close.index, dtype=bool)
    exits_full = pd.Series(np.asarray(exits_raw).ravel(), index=full_close.index, dtype=bool)

    # Backtest
    pf_full = vbt.Portfolio.from_signals(
        close=full_close.to_numpy(dtype=float),
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='1D'
    )

    # Trade-by-trade returns
    trades = pf_full.trades
    trade_returns = trades.returns.values if hasattr(trades.returns, 'values') else np.asarray(trades.returns)
    trade_returns = np.asarray(trade_returns).ravel()

    if trade_returns.size == 0:
        print("No trades to plot.")
    else:
        # Calculate statistics
        winning_trades = trade_returns[trade_returns > 0]
        losing_trades = trade_returns[trade_returns < 0]

        total_trades = len(trade_returns)
        win_count = len(winning_trades)
        loss_count = len(losing_trades)
        win_rate = (win_count / total_trades * 100) if total_trades > 0 else 0

        avg_win_pct = (winning_trades.mean() * 100) if len(winning_trades) > 0 else 0
        avg_loss_pct = (losing_trades.mean() * 100) if len(losing_trades) > 0 else 0
        max_win_pct = (winning_trades.max() * 100) if len(winning_trades) > 0 else 0
        max_loss_pct = (losing_trades.min() * 100) if len(losing_trades) > 0 else 0

        print(f"Total trades plotted: {total_trades}")
        print(f"Win Rate: {win_rate:.1f}% ({win_count}W / {loss_count}L)")
        print(f"Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%")
        print(f"Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%")

        equity_per_trade = np.cumprod(1.0 + trade_returns)

        fig, axes = plt.subplots(2, 1, figsize=(14, 9), sharex=False)

        # Per-trade returns (%)
        x = np.arange(1, trade_returns.size + 1)
        colors = np.where(trade_returns >= 0, 'green', 'red')
        axes[0].bar(x, trade_returns * 100.0, color=colors, alpha=0.85, width=0.8)
        axes[0].axhline(0, color='black', linewidth=1, alpha=0.6)

        # Add statistics text box
        stats_text = (
            f'Win Rate: {win_rate:.1f}% ({win_count}W/{loss_count}L)\n'
            f'Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%\n'
            f'Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%'
        )
        axes[0].text(0.02, 0.98, stats_text, transform=axes[0].transAxes,
                    fontsize=10, verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

        axes[0].set_title(f'Per-Trade Returns (%) - Triple EMA({ema1},{ema2},{ema3}) Full Sample',
                         fontsize=13, fontweight='bold')
        axes[0].set_ylabel('Return (%)')
        axes[0].grid(True, alpha=0.3)

        # Cumulative equity per trade
        axes[1].plot(x, equity_per_trade, color='black', linewidth=2)
        axes[1].set_title('Cumulative Equity per Trade (Trade Domain)', fontsize=13)
        axes[1].set_xlabel('Trade #')
        axes[1].set_ylabel('Equity (x)')
        axes[1].grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()
# Out:
# Total trades plotted: 16
# Win Rate: 50.0% (8W / 8L)
# Avg Win: 53.23% | Avg Loss: -8.16%
# Max Win: 245.25% | Max Loss: -16.17%

# %%
# PARAMETER SENSITIVITY TABLE (±15 lookbacks around BEST ema1, ema2, ema3)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"🔬 Parameter Sensitivity Analysis for Best EMA({ema1},{ema2},{ema3})")
    print("=" * 80)

    # Create sensitivity ranges (±15 around each parameter)
    fast_candidates = list(range(max(2, ema1 - 15), ema1 + 16))
    medium_candidates = list(range(max(3, ema2 - 15), ema2 + 16))
    slow_candidates = list(range(max(4, ema3 - 15), ema3 + 16))

    # Test variations: vary one parameter at a time
    combos = ([(f, ema2, ema3) for f in fast_candidates] +
              [(ema1, m, ema3) for m in medium_candidates if m != ema2] +
              [(ema1, ema2, s) for s in slow_candidates if s != ema3])

    price_np = train_close.to_numpy(dtype=float)
    idx = train_close.index

    def series_to_np_bool(s: pd.Series) -> np.ndarray:
        return s.reindex(idx).fillna(False).astype(bool).to_numpy(dtype=bool)

    def eval_combo(e1: int, e2: int, e3: int) -> dict:
        fma = vbt.MA.run(train_close, e1, ewm=True).ma
        mma = vbt.MA.run(train_close, e2, ewm=True).ma
        sma = vbt.MA.run(train_close, e3, ewm=True).ma

        # Triple EMA crossover
        e = series_to_np_bool(
            (fma.vbt.crossed_above(mma) & (fma > sma)) |
            (mma.vbt.crossed_above(sma) & (fma > mma))
        )
        x = series_to_np_bool(
            (fma.vbt.crossed_below(mma) & (fma < sma)) |
            (mma.vbt.crossed_below(sma) & (fma < mma))
        )

        pf = vbt.Portfolio.from_signals(
            close=price_np, entries=e, exits=x,
            init_cash=100_000, fees=0.0005, slippage=0.0005, freq='1D'
        )

        total_return = float(pf.total_return())
        sharpe = float(pf.sharpe_ratio(freq='1D'))
        sortino = float(pf.sortino_ratio(freq='1D'))
        mdd = float(pf.max_drawdown())
        vol = float(pf.annualized_volatility(freq='1D'))

        trades = pf.trades
        ntr = len(trades)
        win_rate_pct = np.nan
        profit_factor = np.nan
        expectancy = 0.0
        if ntr > 0:
            tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
            if tr.size > 0:
                pos = tr[tr > 0]
                neg = tr[tr < 0]
                win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) else np.nan
                gains = pos.sum() if len(pos) else 0.0
                losses = abs(neg.sum()) if len(neg) else 0.0
                profit_factor = gains / losses if losses > 0 else np.inf
                expectancy = float(tr.mean())

        return {
            'ema1': e1, 'ema2': e2, 'ema3': e3,
            'sharpe': sharpe, 'sortino': sortino,
            'total_return': total_return, 'max_drawdown': mdd, 'volatility': vol,
            'total_trades': ntr, 'win_rate_pct': win_rate_pct,
            'profit_factor': profit_factor, 'expectancy': expectancy
        }

    rows = []
    for combo in combos:
        try:
            rows.append(eval_combo(*combo))
        except Exception:
            pass

    if not rows:
        print("⚠️ No sensitivity results computed.")
    else:
        sens = pd.DataFrame(rows)

        # Show as a table
        cols = ['ema1','ema2','ema3','sharpe','sortino','total_return','max_drawdown','volatility',
                'total_trades','win_rate_pct','profit_factor','expectancy']
        sens_table = sens[cols].sort_values(['ema1','ema2','ema3'])

        print(f"\n📊 Sensitivity Results ({len(sens_table)} variations tested):\n")
        print(sens_table.to_string())

        # Compact variation summary
        metric_cols = ['sharpe','sortino','total_return','max_drawdown','volatility',
                       'win_rate_pct','profit_factor','expectancy']
        summary = sens_table[metric_cols].agg(['mean','std','min','max']).T

        print("\n📈 Sensitivity Summary (mean / std / min / max):")
        print(summary.round(4).to_string())

        # Highlight best performer in sensitivity test
        best_sens_idx = sens_table['sharpe'].idxmax()
        best_sens = sens_table.loc[best_sens_idx]
        print(f"\n🏆 Best in Sensitivity Test: EMA({int(best_sens['ema1'])},{int(best_sens['ema2'])},{int(best_sens['ema3'])}) → Sharpe: {best_sens['sharpe']:.3f}")
else:
    print("⚠️ No results available for sensitivity analysis.")
# Out:
# 🔬 Parameter Sensitivity Analysis for Best EMA(12,89,125)
# ================================================================================
#
# 📊 Sensitivity Results (86 variations tested):
#
#     ema1  ema2  ema3    sharpe   sortino  total_return  max_drawdown  volatility  total_trades  win_rate_pct  profit_factor  expectancy
# 0      2    89   125  0.699226  0.938599      1.088492     -0.431076    0.532355             7     42.857143       4.537898    0.190960
# 1      3    89   125  0.438057  0.588184      0.218842     -0.699221    0.667880             5     20.000000       2.255594    0.138124
# 2      4    89   125  0.529346  0.714035      0.476986     -0.699221    0.678195             3     33.333333       3.367494    0.290745
# 3      5    89   125  0.613796  0.830528      0.775188     -0.699221    0.682987             3     33.333333       4.595670    0.441574
# 4      6    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 5      7    89   125  0.547374  0.739338      0.536334     -0.699221    0.678559             3     33.333333       3.698458    0.301735
# 6      8    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 7      9    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 8     10    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 9     11    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 26    12    74   125  0.636110  0.860272      0.867793     -0.699221    0.671653             2     50.000000       6.763993    0.563208
# 27    12    75   125  0.668334  0.905379      1.003080     -0.699221    0.672787             2     50.000000       7.624742    0.647313
# 28    12    76   125  0.668334  0.905379      1.003080     -0.699221    0.672787             2     50.000000       7.624742    0.647313
# 29    12    77   125  0.614632  0.830217      0.781073     -0.699221    0.675443             2     50.000000       5.234638    0.602698
# 30    12    78   125  0.614553  0.830153      0.780762     -0.699221    0.675479             2     50.000000       5.233111    0.602481
# 31    12    79   125  0.614553  0.830153      0.780762     -0.699221    0.675479             2     50.000000       5.233111    0.602481
# 32    12    80   125  0.614553  0.830153      0.780762     -0.699221    0.675479             2     50.000000       5.233111    0.602481
# 33    12    81   125  0.572358  0.771488      0.622859     -0.699221    0.677362             2     50.000000       4.457417    0.492080
# 34    12    82   125  0.572358  0.771488      0.622859     -0.699221    0.677362             2     50.000000       4.457417    0.492080
# 35    12    83   125  0.623167  0.843035      0.813347     -0.699221    0.679702             2     50.000000       6.324234    0.534092
# 36    12    84   125  0.633207  0.856744      0.853693     -0.699221    0.679803             2     50.000000       6.575900    0.559337
# 37    12    85   125  0.617509  0.835282      0.790850     -0.699221    0.680061             2     50.000000       6.183904    0.520015
# 38    12    86   125  0.617509  0.835282      0.790850     -0.699221    0.680061             2     50.000000       6.183904    0.520015
# 39    12    87   125  0.617509  0.835282      0.790850     -0.699221    0.680061             2     50.000000       6.183904    0.520015
# 40    12    88   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 56    12    89   110  0.614553  0.830153      0.780762     -0.699221    0.675479             2     50.000000       5.233111    0.602481
# 57    12    89   111  0.614553  0.830153      0.780762     -0.699221    0.675479             2     50.000000       5.233111    0.602481
# 58    12    89   112  0.614553  0.830153      0.780762     -0.699221    0.675479             2     50.000000       5.233111    0.602481
# 59    12    89   113  0.614553  0.830153      0.780762     -0.699221    0.675479             2     50.000000       5.233111    0.602481
# 60    12    89   114  0.577410  0.778316      0.640894     -0.699221    0.677329             2     50.000000       4.585570    0.496057
# 61    12    89   115  0.623167  0.843035      0.813347     -0.699221    0.679702             2     50.000000       6.324234    0.534092
# 62    12    89   116  0.623167  0.843035      0.813347     -0.699221    0.679702             2     50.000000       6.324234    0.534092
# 63    12    89   117  0.623167  0.843035      0.813347     -0.699221    0.679702             2     50.000000       6.324234    0.534092
# 64    12    89   118  0.623167  0.843035      0.813347     -0.699221    0.679702             2     50.000000       6.324234    0.534092
# 65    12    89   119  0.607471  0.821581      0.751872     -0.699221    0.679959             2     50.000000       5.940771    0.495625
# 66    12    89   120  0.607471  0.821581      0.751872     -0.699221    0.679959             2     50.000000       5.940771    0.495625
# 67    12    89   121  0.607471  0.821581      0.751872     -0.699221    0.679959             2     50.000000       5.940771    0.495625
# 68    12    89   122  0.617509  0.835282      0.790850     -0.699221    0.680061             2     50.000000       6.183904    0.520015
# 69    12    89   123  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 70    12    89   124  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 10    12    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 71    12    89   126  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 72    12    89   127  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 73    12    89   128  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 74    12    89   129  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 75    12    89   130  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 76    12    89   131  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 77    12    89   132  0.488369  0.656557      0.343160     -0.699221    0.685462             2     50.000000       3.044597    0.337509
# 78    12    89   133  0.488369  0.656557      0.343160     -0.699221    0.685462             2     50.000000       3.044597    0.337509
# 79    12    89   134  0.488369  0.656557      0.343160     -0.699221    0.685462             2     50.000000       3.044597    0.337509
# 80    12    89   135  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 81    12    89   136  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 82    12    89   137  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 83    12    89   138  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 84    12    89   139  0.517985  0.697161      0.433611     -0.699221    0.686214             2     50.000000       3.458170    0.399504
# 85    12    89   140  0.560419  0.756575      0.573986     -0.699221    0.688250             2     50.000000       4.098181    0.503519
# 41    12    90   125  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 42    12    91   125  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 43    12    92   125  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 44    12    93   125  0.583115  0.788407      0.660430     -0.699221    0.680496             2     50.000000       4.980005    0.468067
# 45    12    94   125  0.523957  0.705485      0.454445     -0.699221    0.684086             2     50.000000       3.547935    0.420597
# 46    12    95   125  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 47    12    96   125  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 48    12    97   125  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 49    12    98   125  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 50    12    99   125  0.491795  0.661169      0.353390     -0.699221    0.685446             2     50.000000       3.092420    0.340062
# 51    12   100   125  0.534350  0.720580      0.485910     -0.699221    0.687487             2     50.000000       3.696619    0.438257
# 52    12   101   125  0.554846  0.749031      0.554714     -0.699221    0.688143             2     50.000000       4.090188    0.453895
# 53    12   102   125  0.554846  0.749031      0.554714     -0.699221    0.688143             2     50.000000       4.090188    0.453895
# 54    12   103   125  0.513152  0.691226      0.420490     -0.699221    0.683821             3     33.333333       3.068233    0.269981
# 55    12   104   125  0.539381  0.727373      0.504688     -0.699221    0.684591             3     33.333333       3.401534    0.313490
# 11    13    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 12    14    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 13    15    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 14    16    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 15    17    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 16    18    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 17    19    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 18    20    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 19    21    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 20    22    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 21    23    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 22    24    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 23    25    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 24    26    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
# 25    27    89   125  0.597390  0.807902      0.713423     -0.699221    0.680264             2     50.000000       5.274698    0.502724
#
# 📈 Sensitivity Summary (mean / std / min / max):
#                   mean     std      min      max
# sharpe          0.5795  0.0493   0.4381   0.6992
# sortino         0.7827  0.0679   0.5882   0.9386
# total_return    0.6554  0.1727   0.2188   1.0885
# max_drawdown   -0.6961  0.0289  -0.6992  -0.4311
# volatility      0.6788  0.0164   0.5324   0.6883
# win_rate_pct   48.5991  5.0540  20.0000  50.0000
# profit_factor   4.8767  1.1352   2.2556   7.6247
# expectancy      0.4697  0.0975   0.1381   0.6473
#
# 🏆 Best in Sensitivity Test: EMA(2,89,125) → Sharpe: 0.699
