# %%
# !pip install yfinance
# !pip install TA-Lib
# !pip install numpy
# !pip install pandas
# !pip install vectorbt
# !pip install scipy
# %pip install scikit-optimize
# %pip install optuna

# %%
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import vectorbt as vbt
import warnings
from scipy import stats
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", message="Degrees of freedom <= 0 for slice", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="invalid value encountered in scalar divide", category=RuntimeWarning)

# %%
# DOWNLOAD STOCK DATA FROM 2015 USING YFINANCE

TICKER = 'TQQQ'
START_DATE = '2018-01-01'
TRAIN_RATIO = 0.6

# Download data
stock_data = yf.download(TICKER, start=START_DATE, interval='1d')

if not stock_data.empty:
    print(f"Successfully downloaded {len(stock_data)} records for {TICKER}")
    print(f"Data range: {stock_data.index.min().date()} to {stock_data.index.max().date()}")
else:
    print(f"Failed to download {TICKER} data")

stock_data
# Out:
# C:\Users\harka\AppData\Local\Temp\ipykernel_13800\3709481360.py:8: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Successfully downloaded 3952 records for TQQQ
# Data range: 2010-02-11 to 2025-10-27
# Price            Close        High         Low        Open    Volume
# Ticker            TQQQ        TQQQ        TQQQ        TQQQ      TQQQ
# Date
# 2010-02-11    0.413438    0.415679    0.387652    0.388896   3456000
# 2010-02-12    0.415131    0.418715    0.399848    0.402187   8601600
# 2010-02-16    0.431211    0.432207    0.418217    0.424888   9619200
# 2010-02-17    0.438528    0.438628    0.430414    0.436986  19180800
# 2010-02-18    0.446842    0.449480    0.435442    0.438080  38860800
# ...                ...         ...         ...         ...       ...
# 2025-10-21  107.769997  108.480003  106.669998  107.900002  39905700
# 2025-10-22  104.599998  107.739998  101.580002  107.449997  67190400
# 2025-10-23  107.220001  107.629997  104.080002  104.269997  45622500
# 2025-10-24  110.559998  111.260002  109.529999  109.989998  42044500
# 2025-10-27  116.430000  116.690002  114.270103  114.514000  38256099
#
# [3952 rows x 5 columns]

# %%
# PREPARE PRICE SERIES

def select_close_series(df, ticker):
    if isinstance(df.columns, pd.MultiIndex):
        if ('Close', ticker) in df.columns:
            s = df[('Close', ticker)]
        else:
            cols = [c for c in df.columns if 'Close' in str(c)]
            if not cols:
                raise KeyError("Close not found")
            s = df[cols[0]]
    else:
        s = df['Close']
    return s.astype(float).squeeze()

close = select_close_series(stock_data, TICKER)
close.name = 'price'

# Simple split
split_idx = int(len(close) * TRAIN_RATIO)
train_close = close.iloc[:split_idx].copy()
val_close = close.iloc[split_idx:].copy()

print(f"Data ready: train={train_close.index[0].date()} → {train_close.index[-1].date()} | val={val_close.index[0].date()} → {val_close.index[-1].date()}")
# Out:
# Data ready: train=2010-02-11 → 2019-07-15 | val=2019-07-16 → 2025-10-27

# %% [markdown]
# # Aroon Indicator Strategy
#
# This notebook optimizes an **Aroon indicator crossover strategy** for TQQQ trend following.
#
# **Strategy Logic**:
# - BUY when Aroon Up crosses above Aroon Down
# - SELL when Aroon Up crosses below Aroon Down
#
# **Aroon Indicator**:
# - Aroon Up: Measures time since highest high (0-100)
# - Aroon Down: Measures time since lowest low (0-100)
# - Length parameter: Lookback period for calculation

# %%
# Define Parameter Range for Aroon Optimization

param_bounds = {
    'aroon_length': (5, 100),  # Aroon period (lookback window)
}

print("Parameter Bounds for Optimization:")
print(f"  Aroon Length: {param_bounds['aroon_length'][0]} - {param_bounds['aroon_length'][1]} periods")
print("\n✅ Ready for optimization!")
# Out:
# Parameter Bounds for Optimization:
#   Aroon Length: 5 - 100 periods
#
# ✅ Ready for optimization!

# %%
# Core Optimization Function for Aroon Strategy

def evaluate_aroon_strategy(aroon_length, data=train_close, return_metrics=False):
    """
    Evaluate Aroon crossover strategy.
    
    Args:
        aroon_length: Aroon lookback period
        data: price data to test on
        return_metrics: if True, return full metrics dict; if False, return negative Sortino ratio
    
    Returns:
        Negative Sortino ratio (for minimization) or full metrics dict
    """
    
    try:
        # Calculate Aroon using TA-Lib
        close_array = data.values
        aroon_up, aroon_down = talib.AROON(close_array, close_array, timeperiod=aroon_length)
        
        # Convert to Series
        aroon_up_series = pd.Series(aroon_up, index=data.index)
        aroon_down_series = pd.Series(aroon_down, index=data.index)
        
        # Generate crossover signals
        # BUY: Aroon Up crosses above Aroon Down
        entries = aroon_up_series.vbt.crossed_above(aroon_down_series)
        
        # SELL: Aroon Up crosses below Aroon Down  
        exits = aroon_up_series.vbt.crossed_below(aroon_down_series)
        
        # Convert to arrays
        entries_array = pd.Series(np.asarray(entries).ravel(), index=data.index, dtype=bool)
        exits_array = pd.Series(np.asarray(exits).ravel(), index=data.index, dtype=bool)
        
        # Backtest
        portfolio = vbt.Portfolio.from_signals(
            close=data,
            entries=entries_array,
            exits=exits_array,
            init_cash=100_000,
            fees=0.0005,
            slippage=0.0005,
            freq='D'
        )
        
        # Calculate key metrics
        sharpe_ratio = float(portfolio.sharpe_ratio(freq='D'))
        sortino_ratio = float(portfolio.sortino_ratio(freq='D'))
        total_return = float(portfolio.total_return())
        max_drawdown = float(portfolio.max_drawdown())
        volatility = float(portfolio.annualized_volatility(freq='D'))
        
        # Trade metrics
        trades = portfolio.trades
        total_trades = len(trades)
        
        # Check for sufficient trading activity
        years = max((data.index[-1] - data.index[0]).days / 365.25, 1e-9)
        trades_per_year = total_trades / years
        
        if trades_per_year < 1:  # Too few trades
            if return_metrics:
                return {
                    'aroon_length': aroon_length,
                    'sharpe_ratio': np.nan,
                    'sortino_ratio': np.nan,
                    'total_return': np.nan,
                    'annualized_return': np.nan,
                    'max_drawdown': np.nan,
                    'volatility': np.nan,
                    'total_trades': total_trades,
                    'win_rate': np.nan,
                    'profit_factor': np.nan,
                    'expectancy': np.nan,
                    'trades_per_year': trades_per_year
                }
            return 999.0
        
        if return_metrics:
            # Calculate additional metrics
            win_rate_pct = np.nan
            profit_factor = np.nan
            expectancy = 0.0
            annualized_return = (1.0 + total_return) ** (1.0 / years) - 1.0 if years > 0 else np.nan
            
            if total_trades > 0:
                tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
                if tr.size > 0:
                    pos = tr[tr > 0]
                    neg = tr[tr < 0]
                    win_rate_pct = (len(pos) / len(tr)) * 100.0
                    gains = pos.sum() if len(pos) else 0.0
                    losses = abs(neg.sum()) if len(neg) else 0.0
                    profit_factor = (gains / losses) if losses > 0 else np.inf
                    expectancy = float(tr.mean())
            
            return {
                'aroon_length': aroon_length,
                'sharpe_ratio': sharpe_ratio,
                'sortino_ratio': sortino_ratio,
                'total_return': total_return,
                'annualized_return': annualized_return,
                'max_drawdown': max_drawdown,
                'volatility': volatility,
                'total_trades': total_trades,
                'win_rate': win_rate_pct,
                'profit_factor': profit_factor,
                'expectancy': expectancy,
                'trades_per_year': trades_per_year
            }
        else:
            # Return negative Sortino for minimization
            return -sortino_ratio
            
    except Exception as e:
        return 999.0  # Large penalty for errors

print("✅ Core optimization function created for Aroon strategy!")
print("Function evaluates Aroon Up/Down crossover signals.")
# Out:
# ✅ Core optimization function created for Aroon strategy!
# Function evaluates Aroon Up/Down crossover signals.

# %%
# Import optimization libraries
try:
    from skopt import gp_minimize
    from skopt.space import Real
    from skopt.utils import use_named_args
    SKOPT_AVAILABLE = True
except ImportError:
    SKOPT_AVAILABLE = False

try:
    import optuna
    OPTUNA_AVAILABLE = True
except ImportError:
    OPTUNA_AVAILABLE = False

print(f"scikit-optimize: {'✅' if SKOPT_AVAILABLE else '❌'}")
print(f"Optuna: {'✅' if OPTUNA_AVAILABLE else '❌'}")
# Out:
# scikit-optimize: ✅
# Optuna: ✅

# %%
# OPTUNA OPTIMIZATION - Aroon Strategy

print("=" * 70)
print("OPTUNA OPTIMIZATION: Aroon Indicator Strategy")
print(f"Training Period: {train_close.index[0].date()} → {train_close.index[-1].date()}")
print("=" * 70)

optimization_results = []
evaluation_count = 0

def objective(trial):
    """Optuna objective function."""
    global evaluation_count
    evaluation_count += 1
    
    # Suggest parameter
    aroon_length = trial.suggest_int('aroon_length', param_bounds['aroon_length'][0], param_bounds['aroon_length'][1])
    
    # Evaluate strategy
    result = evaluate_aroon_strategy(aroon_length)
    
    # Debug output
    if result == 999.0 and evaluation_count <= 5:
        print(f"Trial {evaluation_count}: Aroon({aroon_length}) → No valid trades")
    elif evaluation_count % 10 == 0 or result != 999.0:
        print(f"Trial {evaluation_count}: Aroon({aroon_length}) → Sortino: {-result:.3f}")
    
    return result

if OPTUNA_AVAILABLE:
    # Create study
    study = optuna.create_study(
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
    )
    
    print("\nStarting Optuna optimization...\n")
    
    study.optimize(objective, n_trials=1000, show_progress_bar=True)
    
    # Get best parameters
    best_params = study.best_params
    best_aroon_length = best_params['aroon_length']
    best_sortino = -study.best_value
    
    # Evaluate best parameters to get full metrics
    best_result = evaluate_aroon_strategy(
        best_aroon_length, 
        return_metrics=True
    )
    
    # Create results dataframe
    results_df = pd.DataFrame([best_result])
    
    print("\n✅ Optimization complete!")
    print(f"Best Parameters: Aroon({best_aroon_length})")
    print(f"Sortino Ratio: {best_sortino:.3f}")
    
else:
    print("❌ Optuna not available")
# Out:
# [I 2025-10-27 23:09:23,298] A new study created in memory with name: no-name-1db6be91-01de-4fb9-84a1-d074a7c0a1d4
# ======================================================================
# OPTUNA OPTIMIZATION: Aroon Indicator Strategy
# Training Period: 2010-02-11 → 2019-07-15
# ======================================================================
#
# Starting Optuna optimization...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Trial 1: Aroon(40) → Sortino: 1.372
# [I 2025-10-27 23:09:23,360] Trial 0 finished with value: -1.371693709167557 and parameters: {'aroon_length': 40}. Best is trial 0 with value: -1.371693709167557.
# Trial 2: Aroon(96) → Sortino: 1.369
# [I 2025-10-27 23:09:23,393] Trial 1 finished with value: -1.3685178025889926 and parameters: {'aroon_length': 96}. Best is trial 0 with value: -1.371693709167557.
# Trial 3: Aroon(75) → Sortino: 2.016
# [I 2025-10-27 23:09:23,426] Trial 2 finished with value: -2.0159801719317407 and parameters: {'aroon_length': 75}. Best is trial 2 with value: -2.0159801719317407.
# Trial 4: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:23,460] Trial 3 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 3 with value: -2.1074612030454927.
# Trial 5: Aroon(19) → Sortino: 1.008
# [I 2025-10-27 23:09:23,489] Trial 4 finished with value: -1.0084250861370634 and parameters: {'aroon_length': 19}. Best is trial 3 with value: -2.1074612030454927.
# Trial 6: Aroon(19) → Sortino: 1.008
# [I 2025-10-27 23:09:23,524] Trial 5 finished with value: -1.0084250861370634 and parameters: {'aroon_length': 19}. Best is trial 3 with value: -2.1074612030454927.
# Trial 7: Aroon(10) → Sortino: 1.561
# [I 2025-10-27 23:09:23,554] Trial 6 finished with value: -1.5608764633375998 and parameters: {'aroon_length': 10}. Best is trial 3 with value: -2.1074612030454927.
# Trial 8: Aroon(88) → Sortino: 1.747
# [I 2025-10-27 23:09:23,588] Trial 7 finished with value: -1.7468050140279763 and parameters: {'aroon_length': 88}. Best is trial 3 with value: -2.1074612030454927.
# Trial 9: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:23,617] Trial 8 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 3 with value: -2.1074612030454927.
# Trial 10: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:23,649] Trial 9 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 3 with value: -2.1074612030454927.
# Trial 11: Aroon(45) → Sortino: 1.231
# [I 2025-10-27 23:09:23,683] Trial 10 finished with value: -1.2306228096612863 and parameters: {'aroon_length': 45}. Best is trial 3 with value: -2.1074612030454927.
# Trial 12: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:23,718] Trial 11 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 3 with value: -2.1074612030454927.
# Trial 13: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:23,750] Trial 12 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 3 with value: -2.1074612030454927.
# Trial 14: Aroon(36) → Sortino: 1.492
# [I 2025-10-27 23:09:23,779] Trial 13 finished with value: -1.4916863780997183 and parameters: {'aroon_length': 36}. Best is trial 3 with value: -2.1074612030454927.
# Trial 15: Aroon(75) → Sortino: 2.016
# [I 2025-10-27 23:09:24,020] Trial 14 finished with value: -2.0159801719317407 and parameters: {'aroon_length': 75}. Best is trial 3 with value: -2.1074612030454927.
# Trial 16: Aroon(53) → Sortino: 1.669
# [I 2025-10-27 23:09:24,065] Trial 15 finished with value: -1.669127998943594 and parameters: {'aroon_length': 53}. Best is trial 3 with value: -2.1074612030454927.
# Trial 17: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:24,101] Trial 16 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 3 with value: -2.1074612030454927.
# Trial 18: Aroon(85) → Sortino: 1.748
# [I 2025-10-27 23:09:24,137] Trial 17 finished with value: -1.7479553726411385 and parameters: {'aroon_length': 85}. Best is trial 3 with value: -2.1074612030454927.
# Trial 19: Aroon(50) → Sortino: 1.690
# [I 2025-10-27 23:09:24,173] Trial 18 finished with value: -1.6896787898603567 and parameters: {'aroon_length': 50}. Best is trial 3 with value: -2.1074612030454927.
# Trial 20: Aroon(34) → Sortino: 1.583
# [I 2025-10-27 23:09:24,204] Trial 19 finished with value: -1.5830067550352964 and parameters: {'aroon_length': 34}. Best is trial 3 with value: -2.1074612030454927.
# Trial 21: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:24,241] Trial 20 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 20 with value: -2.140808926526235.
# Trial 22: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:24,277] Trial 21 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 20 with value: -2.140808926526235.
# Trial 23: Aroon(82) → Sortino: 1.671
# [I 2025-10-27 23:09:24,310] Trial 22 finished with value: -1.6710141954799511 and parameters: {'aroon_length': 82}. Best is trial 20 with value: -2.140808926526235.
# Trial 24: Aroon(55) → Sortino: 1.798
# [I 2025-10-27 23:09:24,341] Trial 23 finished with value: -1.7979872186168997 and parameters: {'aroon_length': 55}. Best is trial 20 with value: -2.140808926526235.
# Trial 25: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:24,375] Trial 24 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 26: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:24,410] Trial 25 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 27: Aroon(98) → Sortino: 1.333
# [I 2025-10-27 23:09:24,441] Trial 26 finished with value: -1.3334011952901688 and parameters: {'aroon_length': 98}. Best is trial 24 with value: -2.192554221209042.
# Trial 28: Aroon(78) → Sortino: 1.842
# [I 2025-10-27 23:09:24,476] Trial 27 finished with value: -1.8419124055135634 and parameters: {'aroon_length': 78}. Best is trial 24 with value: -2.192554221209042.
# Trial 29: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:24,510] Trial 28 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 30: Aroon(90) → Sortino: 1.668
# [I 2025-10-27 23:09:24,540] Trial 29 finished with value: -1.668216341139192 and parameters: {'aroon_length': 90}. Best is trial 24 with value: -2.192554221209042.
# Trial 31: Aroon(46) → Sortino: 1.277
# [I 2025-10-27 23:09:24,573] Trial 30 finished with value: -1.277336324129965 and parameters: {'aroon_length': 46}. Best is trial 24 with value: -2.192554221209042.
# Trial 32: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:24,604] Trial 31 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 33: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:24,638] Trial 32 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 34: Aroon(80) → Sortino: 1.670
# [I 2025-10-27 23:09:24,667] Trial 33 finished with value: -1.6701370394749802 and parameters: {'aroon_length': 80}. Best is trial 24 with value: -2.192554221209042.
# Trial 35: Aroon(58) → Sortino: 2.060
# [I 2025-10-27 23:09:24,701] Trial 34 finished with value: -2.0595577125119027 and parameters: {'aroon_length': 58}. Best is trial 24 with value: -2.192554221209042.
# Trial 36: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:24,732] Trial 35 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 37: Aroon(48) → Sortino: 1.576
# [I 2025-10-27 23:09:24,764] Trial 36 finished with value: -1.5761895877019574 and parameters: {'aroon_length': 48}. Best is trial 24 with value: -2.192554221209042.
# Trial 38: Aroon(76) → Sortino: 1.904
# [I 2025-10-27 23:09:24,793] Trial 37 finished with value: -1.9044218022093722 and parameters: {'aroon_length': 76}. Best is trial 24 with value: -2.192554221209042.
# Trial 39: Aroon(92) → Sortino: 1.683
# [I 2025-10-27 23:09:24,825] Trial 38 finished with value: -1.68283794007351 and parameters: {'aroon_length': 92}. Best is trial 24 with value: -2.192554221209042.
# Trial 40: Aroon(39) → Sortino: 1.344
# [I 2025-10-27 23:09:24,855] Trial 39 finished with value: -1.3436299382366415 and parameters: {'aroon_length': 39}. Best is trial 24 with value: -2.192554221209042.
# Trial 41: Aroon(25) → Sortino: 0.866
# [I 2025-10-27 23:09:24,888] Trial 40 finished with value: -0.8662781258621632 and parameters: {'aroon_length': 25}. Best is trial 24 with value: -2.192554221209042.
# Trial 42: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:24,920] Trial 41 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 43: Aroon(57) → Sortino: 1.986
# [I 2025-10-27 23:09:24,952] Trial 42 finished with value: -1.9859771561449764 and parameters: {'aroon_length': 57}. Best is trial 24 with value: -2.192554221209042.
# Trial 44: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:24,983] Trial 43 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 45: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:25,016] Trial 44 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 46: Aroon(73) → Sortino: 2.044
# [I 2025-10-27 23:09:25,046] Trial 45 finished with value: -2.044156910177559 and parameters: {'aroon_length': 73}. Best is trial 24 with value: -2.192554221209042.
# Trial 47: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:25,078] Trial 46 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 48: Aroon(52) → Sortino: 1.660
# [I 2025-10-27 23:09:25,110] Trial 47 finished with value: -1.6602064811877302 and parameters: {'aroon_length': 52}. Best is trial 24 with value: -2.192554221209042.
# Trial 49: Aroon(58) → Sortino: 2.060
# [I 2025-10-27 23:09:25,144] Trial 48 finished with value: -2.0595577125119027 and parameters: {'aroon_length': 58}. Best is trial 24 with value: -2.192554221209042.
# Trial 50: Aroon(73) → Sortino: 2.044
# [I 2025-10-27 23:09:25,174] Trial 49 finished with value: -2.044156910177559 and parameters: {'aroon_length': 73}. Best is trial 24 with value: -2.192554221209042.
# Trial 51: Aroon(85) → Sortino: 1.748
# [I 2025-10-27 23:09:25,206] Trial 50 finished with value: -1.7479553726411385 and parameters: {'aroon_length': 85}. Best is trial 24 with value: -2.192554221209042.
# Trial 52: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:25,237] Trial 51 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 53: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:25,271] Trial 52 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 54: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:25,299] Trial 53 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 55: Aroon(54) → Sortino: 1.697
# [I 2025-10-27 23:09:25,332] Trial 54 finished with value: -1.696651919495869 and parameters: {'aroon_length': 54}. Best is trial 24 with value: -2.192554221209042.
# Trial 56: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:25,365] Trial 55 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 57: Aroon(77) → Sortino: 1.868
# [I 2025-10-27 23:09:25,427] Trial 56 finished with value: -1.8678912700042027 and parameters: {'aroon_length': 77}. Best is trial 24 with value: -2.192554221209042.
# Trial 58: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:25,517] Trial 57 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 59: Aroon(6) → Sortino: 1.226
# [I 2025-10-27 23:09:25,560] Trial 58 finished with value: -1.2258168942557794 and parameters: {'aroon_length': 6}. Best is trial 24 with value: -2.192554221209042.
# Trial 60: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:25,602] Trial 59 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 61: Aroon(81) → Sortino: 1.637
# [I 2025-10-27 23:09:25,637] Trial 60 finished with value: -1.6372534323332644 and parameters: {'aroon_length': 81}. Best is trial 24 with value: -2.192554221209042.
# Trial 62: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:25,666] Trial 61 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 63: Aroon(73) → Sortino: 2.044
# [I 2025-10-27 23:09:25,697] Trial 62 finished with value: -2.044156910177559 and parameters: {'aroon_length': 73}. Best is trial 24 with value: -2.192554221209042.
# Trial 64: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:25,730] Trial 63 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 65: Aroon(56) → Sortino: 1.877
# [I 2025-10-27 23:09:25,762] Trial 64 finished with value: -1.876819323264867 and parameters: {'aroon_length': 56}. Best is trial 24 with value: -2.192554221209042.
# Trial 66: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:25,791] Trial 65 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 67: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:25,824] Trial 66 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 68: Aroon(50) → Sortino: 1.690
# [I 2025-10-27 23:09:25,857] Trial 67 finished with value: -1.6896787898603567 and parameters: {'aroon_length': 50}. Best is trial 24 with value: -2.192554221209042.
# Trial 69: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:25,890] Trial 68 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 70: Aroon(43) → Sortino: 1.156
# [I 2025-10-27 23:09:25,919] Trial 69 finished with value: -1.1563664907353646 and parameters: {'aroon_length': 43}. Best is trial 24 with value: -2.192554221209042.
# Trial 71: Aroon(75) → Sortino: 2.016
# [I 2025-10-27 23:09:25,950] Trial 70 finished with value: -2.0159801719317407 and parameters: {'aroon_length': 75}. Best is trial 24 with value: -2.192554221209042.
# Trial 72: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:25,982] Trial 71 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 73: Aroon(59) → Sortino: 1.997
# [I 2025-10-27 23:09:26,016] Trial 72 finished with value: -1.9972604453245484 and parameters: {'aroon_length': 59}. Best is trial 24 with value: -2.192554221209042.
# Trial 74: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,049] Trial 73 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 75: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:26,079] Trial 74 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 76: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,112] Trial 75 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 77: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:26,145] Trial 76 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 78: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:26,173] Trial 77 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 79: Aroon(78) → Sortino: 1.842
# [I 2025-10-27 23:09:26,203] Trial 78 finished with value: -1.8419124055135634 and parameters: {'aroon_length': 78}. Best is trial 24 with value: -2.192554221209042.
# Trial 80: Aroon(52) → Sortino: 1.660
# [I 2025-10-27 23:09:26,236] Trial 79 finished with value: -1.6602064811877302 and parameters: {'aroon_length': 52}. Best is trial 24 with value: -2.192554221209042.
# Trial 81: Aroon(74) → Sortino: 2.142
# [I 2025-10-27 23:09:26,272] Trial 80 finished with value: -2.1419742211635575 and parameters: {'aroon_length': 74}. Best is trial 24 with value: -2.192554221209042.
# Trial 82: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,301] Trial 81 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 83: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:26,332] Trial 82 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 84: Aroon(56) → Sortino: 1.877
# [I 2025-10-27 23:09:26,365] Trial 83 finished with value: -1.876819323264867 and parameters: {'aroon_length': 56}. Best is trial 24 with value: -2.192554221209042.
# Trial 85: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:26,398] Trial 84 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 86: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:26,426] Trial 85 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 87: Aroon(59) → Sortino: 1.997
# [I 2025-10-27 23:09:26,457] Trial 86 finished with value: -1.9972604453245484 and parameters: {'aroon_length': 59}. Best is trial 24 with value: -2.192554221209042.
# Trial 88: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:26,492] Trial 87 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 24 with value: -2.192554221209042.
# Trial 89: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:26,525] Trial 88 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 90: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,554] Trial 89 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 91: Aroon(79) → Sortino: 1.784
# [I 2025-10-27 23:09:26,586] Trial 90 finished with value: -1.78421305133993 and parameters: {'aroon_length': 79}. Best is trial 24 with value: -2.192554221209042.
# Trial 92: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,619] Trial 91 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 93: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:26,652] Trial 92 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 94: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:26,680] Trial 93 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 95: Aroon(76) → Sortino: 1.904
# [I 2025-10-27 23:09:26,713] Trial 94 finished with value: -1.9044218022093722 and parameters: {'aroon_length': 76}. Best is trial 24 with value: -2.192554221209042.
# Trial 96: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,746] Trial 95 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 97: Aroon(84) → Sortino: 1.729
# [I 2025-10-27 23:09:26,780] Trial 96 finished with value: -1.729241824229052 and parameters: {'aroon_length': 84}. Best is trial 24 with value: -2.192554221209042.
# Trial 98: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:26,809] Trial 97 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 99: Aroon(58) → Sortino: 2.060
# [I 2025-10-27 23:09:26,840] Trial 98 finished with value: -2.0595577125119027 and parameters: {'aroon_length': 58}. Best is trial 24 with value: -2.192554221209042.
# Trial 100: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,873] Trial 99 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 101: Aroon(54) → Sortino: 1.697
# [I 2025-10-27 23:09:26,906] Trial 100 finished with value: -1.696651919495869 and parameters: {'aroon_length': 54}. Best is trial 24 with value: -2.192554221209042.
# Trial 102: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,939] Trial 101 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 103: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:26,970] Trial 102 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 104: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:27,005] Trial 103 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 105: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:27,039] Trial 104 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 106: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:27,069] Trial 105 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 107: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:27,099] Trial 106 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 108: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:27,133] Trial 107 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 24 with value: -2.192554221209042.
# Trial 109: Aroon(16) → Sortino: 1.593
# [I 2025-10-27 23:09:27,169] Trial 108 finished with value: -1.5929807393503626 and parameters: {'aroon_length': 16}. Best is trial 24 with value: -2.192554221209042.
# Trial 110: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:27,198] Trial 109 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 111: Aroon(75) → Sortino: 2.016
# [I 2025-10-27 23:09:27,230] Trial 110 finished with value: -2.0159801719317407 and parameters: {'aroon_length': 75}. Best is trial 24 with value: -2.192554221209042.
# Trial 112: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:27,264] Trial 111 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 113: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:27,297] Trial 112 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 114: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:27,325] Trial 113 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 115: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:27,357] Trial 114 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 116: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:27,392] Trial 115 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 117: Aroon(57) → Sortino: 1.986
# [I 2025-10-27 23:09:27,427] Trial 116 finished with value: -1.9859771561449764 and parameters: {'aroon_length': 57}. Best is trial 24 with value: -2.192554221209042.
# Trial 118: Aroon(73) → Sortino: 2.044
# [I 2025-10-27 23:09:27,457] Trial 117 finished with value: -2.044156910177559 and parameters: {'aroon_length': 73}. Best is trial 24 with value: -2.192554221209042.
# Trial 119: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:27,490] Trial 118 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 120: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:27,521] Trial 119 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 121: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:27,559] Trial 120 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 122: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:27,589] Trial 121 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 123: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:27,623] Trial 122 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 124: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:27,654] Trial 123 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 125: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:27,687] Trial 124 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 126: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:27,717] Trial 125 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 127: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:27,747] Trial 126 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 128: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:27,779] Trial 127 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 129: Aroon(74) → Sortino: 2.142
# [I 2025-10-27 23:09:27,813] Trial 128 finished with value: -2.1419742211635575 and parameters: {'aroon_length': 74}. Best is trial 24 with value: -2.192554221209042.
# Trial 130: Aroon(31) → Sortino: 1.356
# [I 2025-10-27 23:09:27,845] Trial 129 finished with value: -1.3555912424869567 and parameters: {'aroon_length': 31}. Best is trial 24 with value: -2.192554221209042.
# Trial 131: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:27,876] Trial 130 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 132: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:27,907] Trial 131 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 133: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:27,941] Trial 132 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 134: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:27,971] Trial 133 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 135: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:28,001] Trial 134 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 136: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:28,033] Trial 135 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 137: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:28,072] Trial 136 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 138: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:28,101] Trial 137 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 139: Aroon(59) → Sortino: 1.997
# [I 2025-10-27 23:09:28,133] Trial 138 finished with value: -1.9972604453245484 and parameters: {'aroon_length': 59}. Best is trial 24 with value: -2.192554221209042.
# Trial 140: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:28,163] Trial 139 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 141: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:28,199] Trial 140 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 24 with value: -2.192554221209042.
# Trial 142: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:28,230] Trial 141 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 143: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:28,261] Trial 142 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 144: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:28,294] Trial 143 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 145: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:28,331] Trial 144 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 146: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:28,362] Trial 145 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 147: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:28,393] Trial 146 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 148: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:28,426] Trial 147 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 149: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:28,461] Trial 148 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 150: Aroon(58) → Sortino: 2.060
# [I 2025-10-27 23:09:28,490] Trial 149 finished with value: -2.0595577125119027 and parameters: {'aroon_length': 58}. Best is trial 24 with value: -2.192554221209042.
# Trial 151: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:28,525] Trial 150 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 152: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:28,556] Trial 151 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 153: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:28,592] Trial 152 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 154: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:28,622] Trial 153 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 155: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:28,660] Trial 154 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 156: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:28,696] Trial 155 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 157: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:28,768] Trial 156 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 158: Aroon(73) → Sortino: 2.044
# [I 2025-10-27 23:09:28,811] Trial 157 finished with value: -2.044156910177559 and parameters: {'aroon_length': 73}. Best is trial 24 with value: -2.192554221209042.
# Trial 159: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:28,862] Trial 158 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 160: Aroon(100) → Sortino: 1.185
# [I 2025-10-27 23:09:28,922] Trial 159 finished with value: -1.1854469739745987 and parameters: {'aroon_length': 100}. Best is trial 24 with value: -2.192554221209042.
# Trial 161: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:28,969] Trial 160 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 162: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:29,001] Trial 161 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 163: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:29,033] Trial 162 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 164: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:29,065] Trial 163 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 165: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:29,097] Trial 164 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 166: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:29,128] Trial 165 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 167: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:29,159] Trial 166 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 168: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:29,194] Trial 167 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 169: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:29,227] Trial 168 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 170: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:29,261] Trial 169 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 171: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:29,295] Trial 170 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 172: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:29,324] Trial 171 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 173: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:29,355] Trial 172 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 174: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:29,388] Trial 173 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 175: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:29,423] Trial 174 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 176: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:29,455] Trial 175 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 24 with value: -2.192554221209042.
# Trial 177: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:29,487] Trial 176 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 178: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:29,520] Trial 177 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 179: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:29,554] Trial 178 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 180: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:29,583] Trial 179 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 181: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:29,614] Trial 180 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 182: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:29,649] Trial 181 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 183: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:29,686] Trial 182 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 184: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:29,716] Trial 183 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 185: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:29,748] Trial 184 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 186: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:29,782] Trial 185 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 187: Aroon(93) → Sortino: 1.609
# [I 2025-10-27 23:09:29,818] Trial 186 finished with value: -1.608860234567063 and parameters: {'aroon_length': 93}. Best is trial 24 with value: -2.192554221209042.
# Trial 188: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:29,846] Trial 187 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 189: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:29,876] Trial 188 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 190: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:29,913] Trial 189 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 191: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:29,947] Trial 190 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 192: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:29,979] Trial 191 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 193: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:30,010] Trial 192 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 194: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:30,045] Trial 193 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 195: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:30,079] Trial 194 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 196: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:30,107] Trial 195 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 197: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:30,142] Trial 196 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 198: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:30,175] Trial 197 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 199: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:30,208] Trial 198 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 200: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:30,238] Trial 199 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 201: Aroon(74) → Sortino: 2.142
# [I 2025-10-27 23:09:30,269] Trial 200 finished with value: -2.1419742211635575 and parameters: {'aroon_length': 74}. Best is trial 24 with value: -2.192554221209042.
# Trial 202: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:30,302] Trial 201 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 203: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:30,336] Trial 202 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 204: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:30,368] Trial 203 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 205: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:30,400] Trial 204 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 206: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:30,432] Trial 205 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 207: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:30,468] Trial 206 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 208: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:30,497] Trial 207 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 209: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:30,530] Trial 208 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 210: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:30,564] Trial 209 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 211: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:30,601] Trial 210 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 24 with value: -2.192554221209042.
# Trial 212: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:30,630] Trial 211 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 213: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:30,662] Trial 212 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 214: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:30,696] Trial 213 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 215: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:30,730] Trial 214 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 216: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:30,760] Trial 215 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 217: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:30,794] Trial 216 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 218: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:30,830] Trial 217 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 219: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:30,865] Trial 218 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 220: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:30,895] Trial 219 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 221: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:30,928] Trial 220 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 222: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:30,963] Trial 221 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 223: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:30,997] Trial 222 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 224: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:31,028] Trial 223 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 225: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:31,061] Trial 224 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 226: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:31,095] Trial 225 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 227: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:31,130] Trial 226 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 228: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:31,160] Trial 227 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 229: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:31,191] Trial 228 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 230: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:31,226] Trial 229 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 231: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:31,260] Trial 230 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 232: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:31,293] Trial 231 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 233: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:31,324] Trial 232 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 234: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:31,358] Trial 233 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 235: Aroon(64) → Sortino: 2.031
# ...
# Trial 923: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:56,274] Trial 922 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 924: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:56,313] Trial 923 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 925: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:56,349] Trial 924 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 926: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:56,384] Trial 925 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 927: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:56,421] Trial 926 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 928: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:56,454] Trial 927 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 929: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:56,490] Trial 928 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 930: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:56,549] Trial 929 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 931: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:56,592] Trial 930 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 932: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:56,652] Trial 931 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 933: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:56,702] Trial 932 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 934: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:56,749] Trial 933 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 935: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:56,787] Trial 934 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 936: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:56,824] Trial 935 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 937: Aroon(73) → Sortino: 2.044
# [I 2025-10-27 23:09:56,858] Trial 936 finished with value: -2.044156910177559 and parameters: {'aroon_length': 73}. Best is trial 24 with value: -2.192554221209042.
# Trial 938: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:56,892] Trial 937 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 939: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:56,928] Trial 938 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 940: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:56,961] Trial 939 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 941: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:56,999] Trial 940 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 942: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:57,038] Trial 941 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 943: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:57,070] Trial 942 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 944: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:57,105] Trial 943 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 945: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:57,144] Trial 944 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 946: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:57,176] Trial 945 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 947: Aroon(56) → Sortino: 1.877
# [I 2025-10-27 23:09:57,211] Trial 946 finished with value: -1.876819323264867 and parameters: {'aroon_length': 56}. Best is trial 24 with value: -2.192554221209042.
# Trial 948: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:57,251] Trial 947 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 949: Aroon(76) → Sortino: 1.904
# [I 2025-10-27 23:09:57,286] Trial 948 finished with value: -1.9044218022093722 and parameters: {'aroon_length': 76}. Best is trial 24 with value: -2.192554221209042.
# Trial 950: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:57,321] Trial 949 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 951: Aroon(71) → Sortino: 1.989
# [I 2025-10-27 23:09:57,356] Trial 950 finished with value: -1.9886310358643045 and parameters: {'aroon_length': 71}. Best is trial 24 with value: -2.192554221209042.
# Trial 952: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:57,389] Trial 951 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 953: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:57,424] Trial 952 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 954: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:57,463] Trial 953 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 955: Aroon(59) → Sortino: 1.997
# [I 2025-10-27 23:09:57,501] Trial 954 finished with value: -1.9972604453245484 and parameters: {'aroon_length': 59}. Best is trial 24 with value: -2.192554221209042.
# Trial 956: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:57,535] Trial 955 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 957: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:57,576] Trial 956 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 958: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:57,608] Trial 957 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 959: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:57,642] Trial 958 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 960: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:57,680] Trial 959 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 961: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:57,715] Trial 960 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 962: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:57,752] Trial 961 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 963: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:57,789] Trial 962 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 24 with value: -2.192554221209042.
# Trial 964: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:57,821] Trial 963 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 965: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:57,857] Trial 964 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 966: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:57,894] Trial 965 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 967: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:57,928] Trial 966 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 968: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:57,963] Trial 967 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 969: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:58,004] Trial 968 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 970: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:58,041] Trial 969 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 971: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:58,076] Trial 970 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 972: Aroon(74) → Sortino: 2.142
# [I 2025-10-27 23:09:58,113] Trial 971 finished with value: -2.1419742211635575 and parameters: {'aroon_length': 74}. Best is trial 24 with value: -2.192554221209042.
# Trial 973: Aroon(94) → Sortino: 1.490
# [I 2025-10-27 23:09:58,145] Trial 972 finished with value: -1.4898104640074574 and parameters: {'aroon_length': 94}. Best is trial 24 with value: -2.192554221209042.
# Trial 974: Aroon(69) → Sortino: 2.084
# [I 2025-10-27 23:09:58,182] Trial 973 finished with value: -2.0842586030894537 and parameters: {'aroon_length': 69}. Best is trial 24 with value: -2.192554221209042.
# Trial 975: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:58,221] Trial 974 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 976: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:58,255] Trial 975 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 977: Aroon(53) → Sortino: 1.669
# [I 2025-10-27 23:09:58,291] Trial 976 finished with value: -1.669127998943594 and parameters: {'aroon_length': 53}. Best is trial 24 with value: -2.192554221209042.
# Trial 978: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:58,329] Trial 977 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 979: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:58,365] Trial 978 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 980: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:58,399] Trial 979 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 981: Aroon(67) → Sortino: 2.141
# [I 2025-10-27 23:09:58,439] Trial 980 finished with value: -2.140808926526235 and parameters: {'aroon_length': 67}. Best is trial 24 with value: -2.192554221209042.
# Trial 982: Aroon(60) → Sortino: 2.009
# [I 2025-10-27 23:09:58,475] Trial 981 finished with value: -2.0086431925093753 and parameters: {'aroon_length': 60}. Best is trial 24 with value: -2.192554221209042.
# Trial 983: Aroon(86) → Sortino: 1.756
# [I 2025-10-27 23:09:58,510] Trial 982 finished with value: -1.756407125558534 and parameters: {'aroon_length': 86}. Best is trial 24 with value: -2.192554221209042.
# Trial 984: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:58,548] Trial 983 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 985: Aroon(72) → Sortino: 1.975
# [I 2025-10-27 23:09:58,581] Trial 984 finished with value: -1.9747512371071316 and parameters: {'aroon_length': 72}. Best is trial 24 with value: -2.192554221209042.
# Trial 986: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:58,617] Trial 985 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 987: Aroon(62) → Sortino: 2.107
# [I 2025-10-27 23:09:58,658] Trial 986 finished with value: -2.1074612030454927 and parameters: {'aroon_length': 62}. Best is trial 24 with value: -2.192554221209042.
# Trial 988: Aroon(65) → Sortino: 2.150
# [I 2025-10-27 23:09:58,690] Trial 987 finished with value: -2.1501344987647864 and parameters: {'aroon_length': 65}. Best is trial 24 with value: -2.192554221209042.
# Trial 989: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:58,725] Trial 988 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 990: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:58,761] Trial 989 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 991: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:58,794] Trial 990 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 992: Aroon(58) → Sortino: 2.060
# [I 2025-10-27 23:09:58,829] Trial 991 finished with value: -2.0595577125119027 and parameters: {'aroon_length': 58}. Best is trial 24 with value: -2.192554221209042.
# Trial 993: Aroon(63) → Sortino: 2.075
# [I 2025-10-27 23:09:58,865] Trial 992 finished with value: -2.074697041021395 and parameters: {'aroon_length': 63}. Best is trial 24 with value: -2.192554221209042.
# Trial 994: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:58,902] Trial 993 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
# Trial 995: Aroon(97) → Sortino: 1.355
# [I 2025-10-27 23:09:58,938] Trial 994 finished with value: -1.3552874686470018 and parameters: {'aroon_length': 97}. Best is trial 24 with value: -2.192554221209042.
# Trial 996: Aroon(68) → Sortino: 2.125
# [I 2025-10-27 23:09:58,978] Trial 995 finished with value: -2.1247639248375143 and parameters: {'aroon_length': 68}. Best is trial 24 with value: -2.192554221209042.
# Trial 997: Aroon(64) → Sortino: 2.031
# [I 2025-10-27 23:09:59,010] Trial 996 finished with value: -2.0314680280310276 and parameters: {'aroon_length': 64}. Best is trial 24 with value: -2.192554221209042.
# Trial 998: Aroon(70) → Sortino: 2.037
# [I 2025-10-27 23:09:59,048] Trial 997 finished with value: -2.0368503237065507 and parameters: {'aroon_length': 70}. Best is trial 24 with value: -2.192554221209042.
# Trial 999: Aroon(61) → Sortino: 2.029
# [I 2025-10-27 23:09:59,085] Trial 998 finished with value: -2.028728010659985 and parameters: {'aroon_length': 61}. Best is trial 24 with value: -2.192554221209042.
# Trial 1000: Aroon(66) → Sortino: 2.193
# [I 2025-10-27 23:09:59,119] Trial 999 finished with value: -2.192554221209042 and parameters: {'aroon_length': 66}. Best is trial 24 with value: -2.192554221209042.
#
# ✅ Optimization complete!
# Best Parameters: Aroon(66)
# Sortino Ratio: 2.193

# %%
# Display Results

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    
    print("OPTIMIZATION RESULTS:")
    print("=" * 50)
    print(f"Best Parameters:")
    print(f"  Aroon Length: {int(best['aroon_length'])}")
    
    print("\nPerformance Metrics:")
    print(f"  Total Return: {best['total_return']:.2%}")
    print(f"  Sharpe Ratio: {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio: {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown: {best['max_drawdown']:.2%}")
    print(f"  Total Trades: {int(best['total_trades'])}")
    print(f"  Win Rate: {best['win_rate']:.1f}%")
    print(f"  Profit Factor: {best['profit_factor']:.2f}")
else:
    print("⚠️ No results found. Run optimization first.")
# Out:
# OPTIMIZATION RESULTS:
# ==================================================
# Best Parameters:
#   Aroon Length: 66
#
# Performance Metrics:
#   Total Return: 2905.28%
#   Sharpe Ratio: 1.435
#   Sortino Ratio: 2.193
#   Max Drawdown: -50.06%
#   Total Trades: 19
#   Win Rate: 94.7%
#   Profit Factor: 135.59

# %%
# BENCHMARK ANALYSIS: Best Strategy vs Market (Buy & Hold)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    print(f"BENCHMARK ANALYSIS: Best Aroon({aroon_length}) vs Buy & Hold")
    print("=" * 70)

    # Recreate the BEST strategy portfolio
    close_array = train_close.values
    aroon_up, aroon_down = talib.AROON(close_array, close_array, timeperiod=aroon_length)
    aroon_up_series = pd.Series(aroon_up, index=train_close.index)
    aroon_down_series = pd.Series(aroon_down, index=train_close.index)

    entries = aroon_up_series.vbt.crossed_above(aroon_down_series)
    exits = aroon_up_series.vbt.crossed_below(aroon_down_series)

    best_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Create buy & hold benchmark
    benchmark_entries = np.zeros(len(train_close), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(train_close), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Strategy annualized return
    strategy_annualized_return = best['annualized_return']

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    print("\nPERFORMANCE COMPARISON:")
    print(f"Strategy (Aroon {aroon_length}):")
    print(f"  Total Return:      {best['total_return']:.2%}")
    print(f"  Annualized Return: {strategy_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio:     {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown:      {best['max_drawdown']:.2%}")
    print(f"  Volatility:        {best['volatility']:.2%}")
    print(f"  Total Trades:      {best['total_trades']}")
    print(f"  Win Rate:          {best['win_rate']:.1f}%")
    print(f"  Profit Factor:     {best['profit_factor']:.2f}")

    print(f"\nBenchmark (Buy & Hold {TICKER}):")
    print(f"  Total Return:      {bench_total_return:.2%}")
    print(f"  Annualized Return: {bench_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {bench_sharpe:.3f}")
    print(f"  Sortino Ratio:     {bench_sortino:.3f}")
    print(f"  Max Drawdown:      {bench_max_drawdown:.2%}")
    print(f"  Volatility:        {bench_volatility:.2%}")

    # Outperformance metrics
    excess_return = best['total_return'] - bench_total_return
    excess_annualized_return = strategy_annualized_return - bench_annualized_return
    sharpe_diff = best['sharpe_ratio'] - bench_sharpe
    sortino_diff = best['sortino_ratio'] - bench_sortino
    excess_max_drawdown = best['max_drawdown'] - bench_max_drawdown

    print(f"\nOUTPERFORMANCE METRICS:")
    print(f"  Excess Return:           {excess_return:.2%}")
    print(f"  Excess Annualized Return: {excess_annualized_return:.2%}")
    print(f"  Sharpe Difference:       {sharpe_diff:.3f}")
    print(f"  Sortino Difference:      {sortino_diff:.3f}")
    print(f"  Excess Max Drawdown:      {excess_max_drawdown:.2%} ({'Better' if excess_max_drawdown > 0 else '❌ Worse'})")
    
    # Calculate beta
    market_beta = best['volatility'] / bench_volatility if bench_volatility != 0 else np.nan
    print(f"  Market Beta (approx):     {market_beta:.3f} ({'Lower risk' if market_beta < 1 else '⚠️ Higher risk'})")
else:
    print("⚠️ No results available for benchmark analysis.")
# Out:
# BENCHMARK ANALYSIS: Best Aroon(66) vs Buy & Hold
# ======================================================================
#
# PERFORMANCE COMPARISON:
# Strategy (Aroon 66):
#   Total Return:      2905.28%
#   Annualized Return: 43.51%
#   Sharpe Ratio:      1.435
#   Sortino Ratio:     2.193
#   Max Drawdown:      -50.06%
#   Volatility:        42.95%
#   Total Trades:      19.0
#   Win Rate:          94.7%
#   Profit Factor:     135.59
#
# Benchmark (Buy & Hold TQQQ):
#   Total Return:      3898.56%
#   Annualized Return: 76.44%
#   Sharpe Ratio:      1.232
#   Sortino Ratio:     1.750
#   Max Drawdown:      -58.08%
#   Volatility:        61.63%
#
# OUTPERFORMANCE METRICS:
#   Excess Return:           -993.28%
#   Excess Annualized Return: -32.94%
#   Sharpe Difference:       0.203
#   Sortino Difference:      0.442
#   Excess Max Drawdown:      8.03% (Better)
#   Market Beta (approx):     0.697 (Lower risk)

# %%
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON

FREQ = "1D"

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    # Out-of-sample validation
    close_array_val = val_close.values
    aroon_up_val, aroon_down_val = talib.AROON(close_array_val, close_array_val, timeperiod=aroon_length)
    aroon_up_series_val = pd.Series(aroon_up_val, index=val_close.index)
    aroon_down_series_val = pd.Series(aroon_down_val, index=val_close.index)

    entries_val = aroon_up_series_val.vbt.crossed_above(aroon_down_series_val)
    exits_val = aroon_up_series_val.vbt.crossed_below(aroon_down_series_val)

    pf_val = vbt.Portfolio.from_signals(
        close=val_close,
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Out-of-sample metrics
    val_total_return = pf_val.total_return()
    val_annualized_return = pf_val.annualized_return(freq=FREQ)
    val_sharpe = pf_val.sharpe_ratio(freq=FREQ)
    val_sortino = pf_val.sortino_ratio(freq=FREQ)
    val_max_drawdown = pf_val.max_drawdown()
    val_volatility = pf_val.annualized_volatility(freq=FREQ)

    trades_val = pf_val.trades
    val_total_trades = len(trades_val)
    years = max((val_close.index[-1] - val_close.index[0]).days / 365.25, 1e-9)
    val_trades_per_year = val_total_trades / years

    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    def chg(before, after):
        if pd.isna(before) or pd.isna(after) or before == 0:
            return "N/A"
        return f"{((after - before) / abs(before)) * 100:+.1f}%"

    print(f"IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best Aroon({aroon_length})")
    print("=" * 80)

    print(f"{'METRIC':<25} {'IN-SAMPLE':<15} {'OUT-OF-SAMPLE':<15} {'DEGRADATION':<15}")

    print("\nRETURN METRICS:")
    print(f"{'Total Return':<25} {best['total_return']:<15.2%} {val_total_return:<15.2%} {chg(best['total_return'], val_total_return)}")
    print(f"{'Annualized Return':<25} {best['annualized_return']:<15.2%} {val_annualized_return:<15.2%} {chg(best['annualized_return'], val_annualized_return)}")

    print("\nRISK-ADJUSTED METRICS:")
    print(f"{'Sharpe Ratio':<25} {best['sharpe_ratio']:<15.3f} {val_sharpe:<15.3f} {chg(best['sharpe_ratio'], val_sharpe)}")
    print(f"{'Sortino Ratio':<25} {best['sortino_ratio']:<15.3f} {val_sortino:<15.3f} {chg(best['sortino_ratio'], val_sortino)}")

    print("\nRISK METRICS:")
    print(f"{'Max Drawdown':<25} {best['max_drawdown']:<15.2%} {val_max_drawdown:<15.2%} {chg(best['max_drawdown'], val_max_drawdown)}")
    print(f"{'Volatility':<25} {best['volatility']:<15.2%} {val_volatility:<15.2%} {chg(best['volatility'], val_volatility)}")

    print("\nTRADE METRICS:")
    print(f"{'Total Trades':<25} {best['total_trades']:<15.0f} {val_total_trades:<15.0f} {chg(best['total_trades'], val_total_trades)}")
    print(f"{'Trades per Year':<25} {best['trades_per_year']:<15.1f} {val_trades_per_year:<15.1f} {chg(best['trades_per_year'], val_trades_per_year)}")
    print(f"{'Win Rate %':<25} {best['win_rate']:<15.1f} {val_win_rate_pct:<15.1f} {chg(best['win_rate'], val_win_rate_pct)}")
    print(f"{'Profit Factor':<25} {best['profit_factor']:<15.2f} {val_profit_factor:<15.2f} {chg(best['profit_factor'], val_profit_factor)}")
    print(f"{'Expectancy':<25} {best['expectancy']:<15.4f} {val_expectancy:<15.4f} {chg(best['expectancy'], val_expectancy)}")
else:
    print("⚠️ No results for comparison.")
# Out:
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best Aroon(66)
# ================================================================================
# METRIC                    IN-SAMPLE       OUT-OF-SAMPLE   DEGRADATION
#
# RETURN METRICS:
# Total Return              2905.28%        341.09%         -88.3%
# Annualized Return         43.51%          40.86%          -6.1%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio              1.435           0.846           -41.1%
# Sortino Ratio             2.193           1.254           -42.8%
#
# RISK METRICS:
# Max Drawdown              -50.06%         -66.11%         -32.1%
# Volatility                42.95%          68.41%          +59.3%
#
# TRADE METRICS:
# Total Trades              19              11              -42.1%
# Trades per Year           2.0             1.8             -13.2%
# Win Rate %                94.7            81.8            -13.6%
# Profit Factor             135.59          4.22            -96.9%
# Expectancy                0.2014          0.1890          -6.2%

# %%
# COMPREHENSIVE VISUALIZATION

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    # Calculate Aroon for full sample
    close_array_full = close.values
    aroon_up_full, aroon_down_full = talib.AROON(close_array_full, close_array_full, timeperiod=aroon_length)
    aroon_up_series_full = pd.Series(aroon_up_full, index=close.index)
    aroon_down_series_full = pd.Series(aroon_down_full, index=close.index)

    # Generate signals
    entries_full = aroon_up_series_full.vbt.crossed_above(aroon_down_series_full)
    exits_full = aroon_up_series_full.vbt.crossed_below(aroon_down_series_full)

    # Create portfolio
    pf_full = vbt.Portfolio.from_signals(
        close=close,
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Get returns
    ret = pf_full.returns()

    # Create comprehensive figure
    fig = plt.figure(figsize=(18, 12))
    gs = fig.add_gridspec(4, 2, hspace=0.5, wspace=0.3, 
                          height_ratios=[2.5, 1.5, 1.5, 1],
                          left=0.05, right=0.95, top=0.95, bottom=0.05)

    fig.suptitle(f'Aroon({aroon_length}) Trading Strategy - Comprehensive Analysis', 
                 fontsize=16, fontweight='bold', y=0.98)

    # 1. Price + Aroon lines + Signals
    ax1 = fig.add_subplot(gs[0, :])
    ax1_twin = ax1.twinx()

    ax1.plot(close.index, close.values, label='Close Price', color='black', linewidth=1.5, alpha=0.7)
    ax1_twin.plot(close.index, aroon_up_series_full.values, label='Aroon Up', color='green', linewidth=1.2, alpha=0.8)
    ax1_twin.plot(close.index, aroon_down_series_full.values, label='Aroon Down', color='red', linewidth=1.2, alpha=0.8)
    
    # Mark buy/sell signals
    buy_indices = entries_full[entries_full].index
    sell_indices = exits_full[exits_full].index
    if len(buy_indices) > 0:
        ax1.scatter(buy_indices, close.reindex(buy_indices).values, marker='^', color='green', s=100, label='Buy', zorder=5)
    if len(sell_indices) > 0:
        ax1.scatter(sell_indices, close.reindex(sell_indices).values, marker='v', color='red', s=100, label='Sell', zorder=5)

    ax1.set_title('Price, Aroon Indicator, and Trading Signals', fontsize=13, fontweight='bold')
    ax1.set_ylabel('Price ($)', fontsize=10)
    ax1_twin.set_ylabel('Aroon (0-100)', fontsize=10)
    ax1.legend(loc='upper left', fontsize=9)
    ax1_twin.legend(loc='upper right', fontsize=9)
    ax1.grid(True, alpha=0.3)

    # 2. Equity Curve
    ax2 = fig.add_subplot(gs[1, :])
    equity = (1 + ret).cumprod()
    ax2.plot(close.index, equity.values, color='black', linewidth=2, label='Equity Curve')
    ax2.axvline(x=train_close.index[-1], color='red', linestyle='--', linewidth=2, alpha=0.6, label='Train/Val Split')
    ax2.set_title('Equity Curve', fontsize=13, fontweight='bold')
    ax2.set_ylabel('Cumulative Returns', fontsize=10)
    ax2.legend(loc='best', fontsize=9)
    ax2.grid(True, alpha=0.3)

    # 3. Drawdown
    ax3 = fig.add_subplot(gs[2, :])
    peak = equity.cummax()
    drawdown = (equity - peak) / peak
    ax3.fill_between(close.index, drawdown * 100, 0, color='red', alpha=0.5)
    ax3.plot(close.index, drawdown * 100, color='darkred', linewidth=1.5)
    ax3.set_title('Drawdown Chart', fontsize=13, fontweight='bold')
    ax3.set_ylabel('Drawdown (%)', fontsize=10)
    ax3.set_xlabel('Date', fontsize=10)
    ax3.grid(True, alpha=0.3)

    # 4. Rolling Sharpe
    ax4 = fig.add_subplot(gs[3, :])
    rolling_window = max(20, min(252, max(1, len(ret) // 4)))
    if len(ret) > rolling_window:
        rolling_sharpe = ret.rolling(window=rolling_window).apply(
            lambda x: (x.mean() * 252) / (x.std() * np.sqrt(252)) if x.std() and x.std() != 0 else np.nan,
            raw=False
        )
        ax4.plot(rolling_sharpe.index, rolling_sharpe.values, linewidth=2, color='blue', alpha=0.85)
        ax4.axhline(y=1.0, color='green', linestyle='--', alpha=0.6, label='Sharpe = 1.0')
        ax4.axhline(y=0.5, color='orange', linestyle='--', alpha=0.6, label='Sharpe = 0.5')
        ax4.axvline(x=train_close.index[-1], color='purple', linestyle='--', linewidth=2, alpha=0.6)

    ax4.set_title(f'Rolling Sharpe Ratio (window={rolling_window})', fontsize=12, fontweight='bold')
    ax4.set_ylabel('Sharpe Ratio', fontsize=10)
    ax4.set_xlabel('Date', fontsize=10)
    ax4.legend(loc='upper left', fontsize=9)
    ax4.grid(True, alpha=0.3)
    ax4.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m'))

    plt.savefig('Aroon_Comprehensive_Analysis.png', dpi=300, bbox_inches='tight')
    print("✅ Comprehensive visualization saved as 'Aroon_Comprehensive_Analysis.png'")
    plt.close(fig)

    print(f"\nTraining Period: {train_close.index[0].date()} to {train_close.index[-1].date()} ({len(train_close)} days)")
    print(f"Validation Period: {val_close.index[0].date()} to {val_close.index[-1].date()} ({len(val_close)} days)")
    print(f"\nBest Parameters: Aroon({aroon_length})")
else:
    print("⚠️ No results available for comprehensive visualization.")
# Out:
# ✅ Comprehensive visualization saved as 'Aroon_Comprehensive_Analysis.png'
#
# Training Period: 2010-02-11 to 2019-07-15 (2371 days)
# Validation Period: 2019-07-16 to 2025-10-27 (1581 days)
#
# Best Parameters: Aroon(66)

# %%
# METRICS TABLE - In-Sample vs Out-of-Sample

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    # Get train and validation results
    train_result = evaluate_aroon_strategy(aroon_length, data=train_close, return_metrics=True)
    
    val_result = evaluate_aroon_strategy(aroon_length, data=val_close, return_metrics=True)
    
    # Calculate trades per year
    train_trades_per_year = train_result['total_trades'] / (len(train_close) / 252)
    val_trades_per_year = val_result['total_trades'] / (len(val_close) / 252)
    
    # Create separate figure for metrics table
    fig2 = plt.figure(figsize=(14, 10))
    ax = fig2.add_subplot(111)
    ax.axis('off')
    
    # Create metrics table
    table_data = [
        ['Metric', 'In-Sample (Training)', 'Out-of-Sample (Validation)'],
        ['Period', f'{train_close.index[0].date()} to {train_close.index[-1].date()}', 
         f'{val_close.index[0].date()} to {val_close.index[-1].date()}'],
        ['Annualized Return', f"{train_result['annualized_return']:.2%}", f"{val_result['annualized_return']:.2%}"],
        ['Sharpe Ratio', f"{train_result['sharpe_ratio']:.3f}", f"{val_result['sharpe_ratio']:.3f}"],
        ['Sortino Ratio', f"{train_result['sortino_ratio']:.3f}", f"{val_result['sortino_ratio']:.3f}"],
        ['Max Drawdown', f"{train_result['max_drawdown']:.2%}", f"{val_result['max_drawdown']:.2%}"],
        ['Trades per Year', f"{train_trades_per_year:.2f}", f"{val_trades_per_year:.2f}"],
        ['Win Rate', f"{train_result['win_rate']:.1f}%", f"{val_result['win_rate']:.1f}%"],
        ['Profit Factor', f"{train_result['profit_factor']:.2f}", f"{val_result['profit_factor']:.2f}"]
    ]
    
    table = ax.table(cellText=table_data, cellLoc='left', loc='center',
                     colWidths=[0.4, 0.3, 0.3], bbox=[0, 0, 1, 1])
    table.auto_set_font_size(False)
    table.set_fontsize(11)
    table.scale(1, 2.5)
    
    # Style the table
    for i in range(len(table_data)):
        for j in range(len(table_data[0])):
            cell = table[(i, j)]
            if i == 0:
                cell.set_facecolor('#4CAF50')
                cell.set_text_props(weight='bold', color='white')
            else:
                if j == 0:
                    cell.set_facecolor('#F0F0F0')
                else:
                    cell.set_facecolor('#FFFFFF')
    
    fig2.suptitle(f'Performance Metrics Summary - Aroon({aroon_length})', fontsize=16, fontweight='bold', y=0.95)
    plt.savefig('Aroon_Metrics_Table.png', dpi=300, bbox_inches='tight')
    print("✅ Metrics table saved as 'Aroon_Metrics_Table.png'")
    plt.close(fig2)
    
    print(f"\n📊 Metrics Summary:")
    print(f"Training: {train_result['total_return']:.2%} return, {train_result['sharpe_ratio']:.3f} Sharpe")
    print(f"Validation: {val_result['total_return']:.2%} return, {val_result['sharpe_ratio']:.3f} Sharpe")
else:
    print("⚠️ No results available for metrics table.")
# Out:
# ✅ Metrics table saved as 'Aroon_Metrics_Table.png'
#
# 📊 Metrics Summary:
# Training: 2905.28% return, 1.435 Sharpe
# Validation: 341.09% return, 0.846 Sharpe

# %%
# PARAMETER SENSITIVITY ANALYSIS (±15 around best aroon_length)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    aroon_length = int(best['aroon_length'])

    print(f"🔬 Parameter Sensitivity Analysis for Best Aroon({aroon_length})")
    print("=" * 80)

    # Create sensitivity ranges (±15 around best length)
    candidates = list(range(max(5, aroon_length - 15), min(101, aroon_length + 16)))

    price_np = train_close.to_numpy(dtype=float)
    idx = train_close.index

    def eval_combo(length: int) -> dict:
        aroon_up, aroon_down = talib.AROON(price_np, price_np, timeperiod=length)
        aroon_up_series = pd.Series(aroon_up, index=idx)
        aroon_down_series = pd.Series(aroon_down, index=idx)

        entries = aroon_up_series.vbt.crossed_above(aroon_down_series)
        exits = aroon_up_series.vbt.crossed_below(aroon_down_series)

        pf = vbt.Portfolio.from_signals(
            close=price_np, entries=entries, exits=exits,
            init_cash=100_000, fees=0.0005, slippage=0.0005, freq='1D'
        )

        total_return = float(pf.total_return())
        sharpe = float(pf.sharpe_ratio(freq='D'))
        sortino = float(pf.sortino_ratio(freq='D'))
        mdd = float(pf.max_drawdown())
        vol = float(pf.annualized_volatility(freq='D'))

        trades = pf.trades
        ntr = len(trades)
        win_rate_pct = np.nan
        profit_factor = np.nan
        expectancy = 0.0
        if ntr > 0:
            tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
            if tr.size > 0:
                pos = tr[tr > 0]
                neg = tr[tr < 0]
                win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) else np.nan
                gains = pos.sum() if len(pos) else 0.0
                losses = abs(neg.sum()) if len(neg) else 0.0
                profit_factor = gains / losses if losses > 0 else np.inf
                expectancy = float(tr.mean())

        return {
            'aroon_length': length,
            'sharpe': sharpe, 'sortino': sortino,
            'total_return': total_return, 'max_drawdown': mdd, 'volatility': vol,
            'total_trades': ntr, 'win_rate_pct': win_rate_pct,
            'profit_factor': profit_factor, 'expectancy': expectancy
        }

    rows = []
    for length in candidates:
        try:
            rows.append(eval_combo(length))
        except Exception:
            pass

    if not rows:
        print("⚠️ No sensitivity results computed.")
    else:
        sens = pd.DataFrame(rows)

        # Show as a table
        cols = ['aroon_length','sharpe','sortino','total_return','max_drawdown','volatility',
                'total_trades','win_rate_pct','profit_factor','expectancy']
        sens_table = sens[cols].sort_values('aroon_length')

        print(f"\n📊 Sensitivity Results ({len(sens_table)} variations tested):\n")
        print(sens_table.to_string())

        # Compact variation summary
        metric_cols = ['sharpe','sortino','total_return','max_drawdown','volatility',
                       'win_rate_pct','profit_factor','expectancy']
        summary = sens_table[metric_cols].agg(['mean','std','min','max']).T

        print("\n📈 Sensitivity Summary (mean / std / min / max):")
        print(summary.round(4).to_string())

        # Highlight best performer in sensitivity test
        best_sens_idx = sens_table['sharpe'].idxmax()
        best_sens = sens_table.loc[best_sens_idx]
        print(f"\n🏆 Best in Sensitivity Test: Aroon({int(best_sens['aroon_length'])}) → Sharpe: {best_sens['sharpe']:.3f}")
else:
    print("⚠️ No results available for sensitivity analysis.")
# Out:
# 🔬 Parameter Sensitivity Analysis for Best Aroon(66)
# ================================================================================
#
# 📊 Sensitivity Results (31 variations tested):
#
#     aroon_length    sharpe   sortino  total_return  max_drawdown  volatility  total_trades  win_rate_pct  profit_factor  expectancy
# 0             51  1.067436  1.585114     10.038776     -0.500575    0.435493            21     85.714286       7.994250    0.132313
# 1             52  1.112617  1.660206     11.449403     -0.500575    0.433742            21     85.714286       9.720421    0.137610
# 2             53  1.120280  1.669128     11.652048     -0.500575    0.432561            20     85.000000      13.097240    0.144013
# 3             54  1.137128  1.696652     12.244641     -0.500575    0.432221            20     85.000000      11.446414    0.147774
# 4             55  1.200985  1.797987     14.829122     -0.500575    0.432041            20     85.000000      18.626312    0.156333
# 5             56  1.248461  1.876819     17.193396     -0.500575    0.433165            19     89.473684      30.381850    0.171799
# 6             57  1.311357  1.985977     20.393577     -0.500575    0.430512            19     94.736842      41.414212    0.181757
# 7             58  1.357739  2.059558     23.131869     -0.500575    0.429000            19     94.736842      54.613442    0.189518
# 8             59  1.319161  1.997260     20.753857     -0.500575    0.429635            19     94.736842      53.020200    0.183396
# 9             60  1.326507  2.008643     21.227652     -0.500575    0.429819            19     94.736842      55.238185    0.184562
# 10            61  1.335017  2.028728     21.691675     -0.500575    0.429253            19     94.736842      44.612879    0.185444
# 11            62  1.383279  2.107461     24.880370     -0.500575    0.428774            19     94.736842      33.241933    0.193985
# 12            63  1.363374  2.074697     23.496472     -0.500575    0.428846            19     94.736842      31.373915    0.190771
# 13            64  1.338625  2.031468     22.178918     -0.500575    0.431169            19     94.736842      56.318494    0.187195
# 14            65  1.411026  2.150134     27.214858     -0.500575    0.430222            19     94.736842      77.852382    0.198425
# 15            66  1.435286  2.192554     29.052833     -0.500575    0.429502            19     94.736842     135.587900    0.201447
# 16            67  1.404107  2.140809     26.415736     -0.500575    0.428724            19     94.736842     131.609585    0.195493
# 17            68  1.393859  2.124764     25.532392     -0.500575    0.428047            19     94.736842     130.252705    0.193462
# 18            69  1.369291  2.084259     23.656982     -0.500575    0.427222            19     94.736842     127.178209    0.188860
# 19            70  1.340495  2.036850     21.613246     -0.500575    0.426099            19     94.736842     123.807753    0.183815
# 20            71  1.311251  1.988631     19.765499     -0.500575    0.425340            18     94.444444     121.031066    0.189640
# 21            72  1.305494  1.974751     19.186777     -0.500575    0.423225            17     94.117647     120.224095    0.199445
# 22            73  1.341967  2.044157     20.728050     -0.500575    0.418681            17    100.000000            inf    0.204731
# 23            74  1.398434  2.141974     24.054144     -0.500575    0.416921            16    100.000000            inf    0.228271
# 24            75  1.324980  2.015980     19.297112     -0.500575    0.414951            16    100.000000            inf    0.213834
# 25            76  1.257317  1.904422     15.959655     -0.500575    0.415436            16     93.750000     309.222551    0.202054
# 26            77  1.231672  1.867891     14.538957     -0.500575    0.411946            16     93.750000      91.804879    0.194300
# 27            78  1.217156  1.841912     13.795926     -0.500575    0.410025            16     93.750000      34.905636    0.191490
# 28            79  1.177674  1.784213     10.978852     -0.500575    0.388993            15     93.333333      35.041904    0.187114
# 29            80  1.107226  1.670137      9.057383     -0.500575    0.389658            15     93.333333      19.270103    0.174746
# 30            81  1.085660  1.637253      8.480104     -0.500575    0.388635            15     93.333333      16.670469    0.170180
#
# 📈 Sensitivity Summary (mean / std / min / max):
#                   mean     std      min       max
# sharpe          1.2818  0.1078   1.0674    1.4353
# sortino         1.9413  0.1757   1.5851    2.1926
# total_return   18.8545  5.8029   8.4801   29.0528
# max_drawdown   -0.5006  0.0000  -0.5006   -0.5006
# volatility      0.4229  0.0130   0.3886    0.4355
# win_rate_pct   93.2913  4.0929  85.0000  100.0000
# profit_factor      inf     NaN   7.9942       inf
# expectancy      0.1840  0.0215   0.1323    0.2283
#
# 🏆 Best in Sensitivity Test: Aroon(66) → Sharpe: 1.435
# c:\Users\harka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning:
#
# invalid value encountered in subtract
