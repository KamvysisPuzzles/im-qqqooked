# %% [markdown]
# # MACD Standalone Optimization
#
# ## Purpose
# Optimize MACD parameters independently for later ensemble with 3EMA.
#
# ## Configuration
# - `USE_VOLUME_FILTER`: Toggle volume confirmation on/off
# - `VOLUME_THRESHOLD`: Volume multiplier (only if filter enabled)
#
# ## Strategy
# - Entries: MACD bullish crossover (+ optional volume filter)
# - Exits: MACD bearish crossover (+ optional volume filter)
#
# ## Data Split
# - Training: 70% (2015-2022)
# - Validation: 30% (2022-2025)

# %%
# !pip install yfinance
# !pip install TA-Lib
# !pip install numpy
# !pip install pandas
# !pip install vectorbt
# !pip install scipy
# %pip install scikit-optimize
# %pip install optuna

# %%
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import vectorbt as vbt
import warnings
from scipy import stats
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore", message="Degrees of freedom <= 0 for slice", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="invalid value encountered in scalar divide", category=RuntimeWarning)

# %%
# DOWNLOAD STOCK DATA FROM 2018 USING YFINANCE

TICKER = 'TQQQ'
START_DATE = '2010-01-01'
TRAIN_RATIO = 0.6
# Download data
stock_data = yf.download(TICKER, start=START_DATE, interval='1d')

if not stock_data.empty:
    print(f"Successfully downloaded {len(stock_data)} records for {TICKER}")
    print(f"Data range: {stock_data.index.min().date()} to {stock_data.index.max().date()}")
else:
    print(f"Failed to download {TICKER} data")

stock_data
# Out:
# C:\Users\harka\AppData\Local\Temp\ipykernel_6508\1714875129.py:7: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  1 of 1 completed
# Successfully downloaded 1966 records for TQQQ
# Data range: 2018-01-02 to 2025-10-27
# Price            Close        High         Low        Open    Volume
# Ticker            TQQQ        TQQQ        TQQQ        TQQQ      TQQQ
# Date
# 2018-01-02   11.621358   11.645264   11.147229   11.227711  45867600
# 2018-01-03   11.961618   12.005446   11.666781   11.668375  42612000
# 2018-01-04   12.031741   12.144894   11.989507   12.101864  35012400
# 2018-01-05   12.395109   12.421406   12.136928   12.199879  41190000
# 2018-01-08   12.532964   12.558463   12.381561   12.393513  36126000
# ...                ...         ...         ...         ...       ...
# 2025-10-21  107.769997  108.480003  106.669998  107.900002  39905700
# 2025-10-22  104.599998  107.739998  101.580002  107.449997  67190400
# 2025-10-23  107.220001  107.629997  104.080002  104.269997  45622500
# 2025-10-24  110.559998  111.260002  109.529999  109.989998  42044500
# 2025-10-27  116.430000  116.690002  114.270103  114.514000  38256099
#
# [1966 rows x 5 columns]

# %%
# PREPARE PRICE SERIES

def select_close_series(df, ticker):
    if isinstance(df.columns, pd.MultiIndex):
        if ('Close', ticker) in df.columns:
            s = df[('Close', ticker)]
        else:
            cols = [c for c in df.columns if 'Close' in str(c)]
            if not cols:
                raise KeyError("Close not found")
            s = df[cols[0]]
    else:
        s = df['Close']
    return s.astype(float).squeeze()

close = select_close_series(stock_data, TICKER)
close.name = 'price'

# Simple split

split_idx = int(len(close) * TRAIN_RATIO)
train_close = close.iloc[:split_idx].copy()
val_close = close.iloc[split_idx:].copy()

print(f"Data ready: train={train_close.index[0].date()} → {train_close.index[-1].date()} | val={val_close.index[0].date()} → {val_close.index[-1].date()}")
# Out:
# Data ready: train=2018-01-02 → 2022-09-07 | val=2022-09-08 → 2025-10-27

# %% [markdown]
# # MACD Strategy Configuration
#
# This notebook optimizes **MACD parameters independently** for later ensemble with 3EMA.
#
# **Strategy Logic**:
# - Entries: MACD bullish crossover (+ optional volume filter)
# - Exits: MACD bearish crossover (+ optional volume filter)
#
# **Modular Optimization**: Find best MACD params separately, then combine with best 3EMA params.

# %%
# CONFIGURATION & Parameter Ranges for MACD Optimization

# CONFIGURATION
USE_VOLUME_FILTER = False # Toggle volume filter
VOLUME_THRESHOLD = 1.2   # Only used if USE_VOLUME_FILTER = True

param_bounds = {
    'macd_fast': (12, 40),
    'macd_slow': (26, 60),
    'macd_signal': (9, 100),
}

print("Parameter Bounds for Optimization:")
print(f"  MACD Fast: {param_bounds['macd_fast'][0]} - {param_bounds['macd_fast'][1]} periods")
print(f"  MACD Slow: {param_bounds['macd_slow'][0]} - {param_bounds['macd_slow'][1]} periods")
print(f"  MACD Signal: {param_bounds['macd_signal'][0]} - {param_bounds['macd_signal'][1]} periods")
print(f"\nVolume Filter: {'ENABLED' if USE_VOLUME_FILTER else 'DISABLED'}")
if USE_VOLUME_FILTER:
    print(f"Volume Threshold: {VOLUME_THRESHOLD}x")
print("\nConstraint: MACD Fast < MACD Slow")
print("✅ Ready for optimization!")
# Out:
# Parameter Bounds for Optimization:
#   MACD Fast: 12 - 40 periods
#   MACD Slow: 26 - 60 periods
#   MACD Signal: 9 - 100 periods
#
# Volume Filter: DISABLED
#
# Constraint: MACD Fast < MACD Slow
# ✅ Ready for optimization!

# %%
# Core Optimization Function for MACD Strategy

def evaluate_macd_strategy(params, data=train_close, stock_data_for_volume=None, return_metrics=False):
    """
    Evaluate standalone MACD strategy.
    
    Args:
        params: tuple of (macd_fast, macd_slow, macd_signal)
        data: price data to test on
        stock_data_for_volume: full stock data with volume (required if USE_VOLUME_FILTER=True)
        return_metrics: if True, return full metrics dict; if False, return negative Sortino ratio
    
    Returns:
        Negative Sortino ratio (for minimization) or full metrics dict
    """
    macd_fast, macd_slow, macd_signal = params
    
    # Validate parameter constraints
    if macd_fast >= macd_slow:
        return 999.0  # Large penalty for invalid parameters
    
    try:
        # Calculate MACD
        close_array = data.values
        macd, macd_signal_line, macd_hist = talib.MACD(
            close_array,
            fastperiod=int(macd_fast),
            slowperiod=int(macd_slow),
            signalperiod=int(macd_signal)
        )
        
        macd_series = pd.Series(macd, index=data.index)
        signal_series = pd.Series(macd_signal_line, index=data.index)
        
        # MACD crossovers
        macd_bullish = (macd_series > signal_series) & (macd_series.shift(1) <= signal_series.shift(1))
        macd_bearish = (macd_series < signal_series) & (macd_series.shift(1) >= signal_series.shift(1))
        
        if USE_VOLUME_FILTER:
            # Apply volume confirmation
            if stock_data_for_volume is None:
                return 999.0
            
            volume_data = stock_data_for_volume['Volume']
            volume_aligned = volume_data.reindex(data.index)
            volume_sma = volume_aligned.rolling(window=20).mean()
            volume_ratio = volume_aligned / volume_sma
            volume_confirm = volume_ratio > VOLUME_THRESHOLD
            
            entries = pd.Series(macd_bullish & volume_confirm, index=data.index).fillna(False)
            exits = pd.Series(macd_bearish & volume_confirm, index=data.index).fillna(False)
        else:
            # Pure MACD crossovers (no volume filter)
            entries = pd.Series(macd_bullish, index=data.index).fillna(False)
            exits = pd.Series(macd_bearish, index=data.index).fillna(False)
        
        # Backtest
        portfolio = vbt.Portfolio.from_signals(
            close=data,
            entries=entries,
            exits=exits,
            init_cash=100_000,
            fees=0.0005,
            slippage=0.0005,
            freq='D'
        )
        
        # Calculate key metrics
        sharpe_ratio = float(portfolio.sharpe_ratio(freq='D'))
        sortino_ratio = float(portfolio.sortino_ratio(freq='D'))
        total_return = float(portfolio.total_return())
        max_drawdown = float(portfolio.max_drawdown())
        volatility = float(portfolio.annualized_volatility(freq='D'))
        
        # Trade metrics
        trades = portfolio.trades
        total_trades = len(trades)
        
        # Check for sufficient trading activity
        years = max((data.index[-1] - data.index[0]).days / 365.25, 1e-9)
        trades_per_year = total_trades / years
        
        if trades_per_year < 1:  # Too few trades
            if return_metrics:
                return {
                    'macd_fast': macd_fast,
                    'macd_slow': macd_slow,
                    'macd_signal': macd_signal,
                    'sharpe_ratio': np.nan,
                    'sortino_ratio': np.nan,
                    'total_return': np.nan,
                    'annualized_return': np.nan,
                    'max_drawdown': np.nan,
                    'volatility': np.nan,
                    'total_trades': total_trades,
                    'win_rate': np.nan,
                    'profit_factor': np.nan,
                    'expectancy': np.nan,
                    'trades_per_year': trades_per_year
                }
            return 999.0
        
        if return_metrics:
            # Calculate additional metrics
            win_rate_pct = np.nan
            profit_factor = np.nan
            expectancy = 0.0
            annualized_return = (1.0 + total_return) ** (1.0 / years) - 1.0 if years > 0 else np.nan
            
            if total_trades > 0:
                tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
                if tr.size > 0:
                    pos = tr[tr > 0]
                    neg = tr[tr < 0]
                    win_rate_pct = (len(pos) / len(tr)) * 100.0
                    gains = pos.sum() if len(pos) else 0.0
                    losses = abs(neg.sum()) if len(neg) else 0.0
                    profit_factor = (gains / losses) if losses > 0 else np.inf
                    expectancy = float(tr.mean())
            
            return {
                'macd_fast': macd_fast,
                'macd_slow': macd_slow,
                'macd_signal': macd_signal,
                'sharpe_ratio': sharpe_ratio,
                'sortino_ratio': sortino_ratio,
                'total_return': total_return,
                'annualized_return': annualized_return,
                'max_drawdown': max_drawdown,
                'volatility': volatility,
                'total_trades': total_trades,
                'win_rate': win_rate_pct,
                'profit_factor': profit_factor,
                'expectancy': expectancy,
                'trades_per_year': trades_per_year
            }
        else:
            # Return negative Sortino for minimization
            return -sortino_ratio
            
    except Exception as e:
        return 999.0  # Large penalty for errors

print("✅ MACD evaluation function created!")
print(f"Volume filter: {'ENABLED' if USE_VOLUME_FILTER else 'DISABLED'}")
# Out:
# ✅ MACD evaluation function created!
# Volume filter: DISABLED

# %%
# OPTUNA OPTIMIZATION - MACD Strategy

print("=" * 70)
print(f"OPTUNA OPTIMIZATION: MACD Strategy")
print(f"Volume Filter: {'ENABLED' if USE_VOLUME_FILTER else 'DISABLED'}")
print(f"Training Period: {train_close.index[0].date()} → {train_close.index[-1].date()}")
print("=" * 70)

import optuna

evaluation_count = 0

def objective(trial):
    """Optuna objective function for MACD."""
    global evaluation_count
    evaluation_count += 1
    
    # Suggest MACD parameters
    macd_fast = trial.suggest_int('macd_fast', param_bounds['macd_fast'][0], param_bounds['macd_fast'][1])
    macd_slow = trial.suggest_int('macd_slow', param_bounds['macd_slow'][0], param_bounds['macd_slow'][1])
    macd_signal = trial.suggest_int('macd_signal', param_bounds['macd_signal'][0], param_bounds['macd_signal'][1])
    
    # Validate constraints
    if macd_fast >= macd_slow:
        return 999.0
    
    # Evaluate strategy
    result = evaluate_macd_strategy(
        (macd_fast, macd_slow, macd_signal),
        stock_data_for_volume=stock_data.iloc[:split_idx] if USE_VOLUME_FILTER else None
    )
    
    # Debug output
    if result == 999.0 and evaluation_count <= 5:
        print(f"Trial {evaluation_count}: MACD({macd_fast},{macd_slow},{macd_signal}) → No valid trades")
    elif evaluation_count % 20 == 0 or result != 999.0:
        print(f"Trial {evaluation_count}: MACD({macd_fast},{macd_slow},{macd_signal}) → Sortino: {-result:.3f}")
    
    return result

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=1000, show_progress_bar=True)

# Get best parameters
best_params = study.best_params
best_macd_fast = best_params['macd_fast']
best_macd_slow = best_params['macd_slow']
best_macd_signal = best_params['macd_signal']
best_sortino = -study.best_value

# Evaluate with full metrics
best_result = evaluate_macd_strategy(
    (best_macd_fast, best_macd_slow, best_macd_signal),
    stock_data_for_volume=stock_data.iloc[:split_idx] if USE_VOLUME_FILTER else None,
    return_metrics=True
)

results_df = pd.DataFrame([best_result])

print("\n✅ Optimization complete!")
print(f"Best Parameters: MACD({best_macd_fast},{best_macd_slow},{best_macd_signal})")
print(f"Sortino Ratio: {best_sortino:.3f}")
# Out:
# ======================================================================
# OPTUNA OPTIMIZATION: MACD Strategy
# Volume Filter: DISABLED
# Training Period: 2018-01-02 → 2022-09-07
# ======================================================================
# [I 2025-10-27 22:57:09,304] A new study created in memory with name: no-name-bc5386ee-4a3e-4ef5-a38d-ce7a55725d67
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Trial 1: MACD(22,59,76) → Sortino: 0.970
# [I 2025-10-27 22:57:16,704] Trial 0 finished with value: -0.9700413107335495 and parameters: {'macd_fast': 22, 'macd_slow': 59, 'macd_signal': 76}. Best is trial 0 with value: -0.9700413107335495.
# Trial 2: MACD(29,31,23) → Sortino: 0.877
# [I 2025-10-27 22:57:16,745] Trial 1 finished with value: -0.8773964269043566 and parameters: {'macd_fast': 29, 'macd_slow': 31, 'macd_signal': 23}. Best is trial 0 with value: -0.9700413107335495.
# Trial 3: MACD(13,56,64) → Sortino: 0.885
# [I 2025-10-27 22:57:16,768] Trial 2 finished with value: -0.8854978217044576 and parameters: {'macd_fast': 13, 'macd_slow': 56, 'macd_signal': 64}. Best is trial 0 with value: -0.9700413107335495.
# [I 2025-10-27 22:57:16,772] Trial 3 finished with value: 999.0 and parameters: {'macd_fast': 32, 'macd_slow': 26, 'macd_signal': 98}. Best is trial 0 with value: -0.9700413107335495.
# [I 2025-10-27 22:57:16,775] Trial 4 finished with value: 999.0 and parameters: {'macd_fast': 36, 'macd_slow': 33, 'macd_signal': 25}. Best is trial 0 with value: -0.9700413107335495.
# Trial 6: MACD(17,36,57) → Sortino: 0.998
# [I 2025-10-27 22:57:16,801] Trial 5 finished with value: -0.9978449663492812 and parameters: {'macd_fast': 17, 'macd_slow': 36, 'macd_signal': 57}. Best is trial 5 with value: -0.9978449663492812.
# Trial 7: MACD(24,36,65) → Sortino: 0.888
# [I 2025-10-27 22:57:16,831] Trial 6 finished with value: -0.8881004854090192 and parameters: {'macd_fast': 24, 'macd_slow': 36, 'macd_signal': 65}. Best is trial 5 with value: -0.9978449663492812.
# Trial 8: MACD(16,36,42) → Sortino: 1.084
# [I 2025-10-27 22:57:16,864] Trial 7 finished with value: -1.0841369082201358 and parameters: {'macd_fast': 16, 'macd_slow': 36, 'macd_signal': 42}. Best is trial 7 with value: -1.0841369082201358.
# Trial 9: MACD(25,53,27) → Sortino: 1.020
# [I 2025-10-27 22:57:16,889] Trial 8 finished with value: -1.0200213110132004 and parameters: {'macd_fast': 25, 'macd_slow': 53, 'macd_signal': 27}. Best is trial 7 with value: -1.0841369082201358.
# Trial 10: MACD(26,46,13) → Sortino: 0.905
# [I 2025-10-27 22:57:16,923] Trial 9 finished with value: -0.9050454646952882 and parameters: {'macd_fast': 26, 'macd_slow': 46, 'macd_signal': 13}. Best is trial 7 with value: -1.0841369082201358.
# Trial 11: MACD(12,45,42) → Sortino: 1.264
# [I 2025-10-27 22:57:16,962] Trial 10 finished with value: -1.264281288622568 and parameters: {'macd_fast': 12, 'macd_slow': 45, 'macd_signal': 42}. Best is trial 10 with value: -1.264281288622568.
# Trial 12: MACD(12,44,42) → Sortino: 1.022
# [I 2025-10-27 22:57:17,009] Trial 11 finished with value: -1.0218181885779367 and parameters: {'macd_fast': 12, 'macd_slow': 44, 'macd_signal': 42}. Best is trial 10 with value: -1.264281288622568.
# Trial 13: MACD(18,49,41) → Sortino: 0.869
# [I 2025-10-27 22:57:17,057] Trial 12 finished with value: -0.8692855343897866 and parameters: {'macd_fast': 18, 'macd_slow': 49, 'macd_signal': 41}. Best is trial 10 with value: -1.264281288622568.
# Trial 14: MACD(17,40,41) → Sortino: 1.022
# [I 2025-10-27 22:57:17,114] Trial 13 finished with value: -1.021957063129157 and parameters: {'macd_fast': 17, 'macd_slow': 40, 'macd_signal': 41}. Best is trial 10 with value: -1.264281288622568.
# Trial 15: MACD(12,40,48) → Sortino: 1.209
# [I 2025-10-27 22:57:17,174] Trial 14 finished with value: -1.209370756553546 and parameters: {'macd_fast': 12, 'macd_slow': 40, 'macd_signal': 48}. Best is trial 10 with value: -1.264281288622568.
# Trial 16: MACD(21,41,79) → Sortino: 1.352
# [I 2025-10-27 22:57:17,224] Trial 15 finished with value: -1.3522763603678742 and parameters: {'macd_fast': 21, 'macd_slow': 41, 'macd_signal': 79}. Best is trial 15 with value: -1.3522763603678742.
# Trial 17: MACD(22,50,85) → Sortino: 0.881
# [I 2025-10-27 22:57:17,278] Trial 16 finished with value: -0.8810751363964877 and parameters: {'macd_fast': 22, 'macd_slow': 50, 'macd_signal': 85}. Best is trial 15 with value: -1.3522763603678742.
# Trial 18: MACD(20,42,81) → Sortino: 1.335
# [I 2025-10-27 22:57:17,326] Trial 17 finished with value: -1.3349752880285954 and parameters: {'macd_fast': 20, 'macd_slow': 42, 'macd_signal': 81}. Best is trial 15 with value: -1.3522763603678742.
# Trial 19: MACD(30,40,100) → Sortino: 1.012
# [I 2025-10-27 22:57:17,357] Trial 18 finished with value: -1.0120088394524835 and parameters: {'macd_fast': 30, 'macd_slow': 40, 'macd_signal': 100}. Best is trial 15 with value: -1.3522763603678742.
# Trial 20: MACD(40,48,83) → Sortino: 0.899
# [I 2025-10-27 22:57:17,390] Trial 19 finished with value: -0.8993347680050888 and parameters: {'macd_fast': 40, 'macd_slow': 48, 'macd_signal': 83}. Best is trial 15 with value: -1.3522763603678742.
# Trial 21: MACD(20,42,76) → Sortino: 1.372
# [I 2025-10-27 22:57:17,424] Trial 20 finished with value: -1.3718157350559905 and parameters: {'macd_fast': 20, 'macd_slow': 42, 'macd_signal': 76}. Best is trial 20 with value: -1.3718157350559905.
# Trial 22: MACD(20,41,75) → Sortino: 1.206
# [I 2025-10-27 22:57:17,456] Trial 21 finished with value: -1.2062518652531518 and parameters: {'macd_fast': 20, 'macd_slow': 41, 'macd_signal': 75}. Best is trial 20 with value: -1.3718157350559905.
# Trial 23: MACD(21,43,90) → Sortino: 1.065
# [I 2025-10-27 22:57:17,507] Trial 22 finished with value: -1.0648379450712107 and parameters: {'macd_fast': 21, 'macd_slow': 43, 'macd_signal': 90}. Best is trial 20 with value: -1.3718157350559905.
# Trial 24: MACD(19,37,72) → Sortino: 1.043
# [I 2025-10-27 22:57:17,569] Trial 23 finished with value: -1.0427163734012368 and parameters: {'macd_fast': 19, 'macd_slow': 37, 'macd_signal': 72}. Best is trial 20 with value: -1.3718157350559905.
# Trial 25: MACD(15,31,91) → Sortino: 0.983
# [I 2025-10-27 22:57:17,618] Trial 24 finished with value: -0.9833101894812898 and parameters: {'macd_fast': 15, 'macd_slow': 31, 'macd_signal': 91}. Best is trial 20 with value: -1.3718157350559905.
# Trial 26: MACD(27,42,67) → Sortino: 1.083
# [I 2025-10-27 22:57:17,673] Trial 25 finished with value: -1.0825304828137243 and parameters: {'macd_fast': 27, 'macd_slow': 42, 'macd_signal': 67}. Best is trial 20 with value: -1.3718157350559905.
# Trial 27: MACD(23,52,82) → Sortino: 1.039
# [I 2025-10-27 22:57:17,722] Trial 26 finished with value: -1.0390139838110037 and parameters: {'macd_fast': 23, 'macd_slow': 52, 'macd_signal': 82}. Best is trial 20 with value: -1.3718157350559905.
# Trial 28: MACD(20,47,90) → Sortino: 1.065
# [I 2025-10-27 22:57:17,768] Trial 27 finished with value: -1.064963796873545 and parameters: {'macd_fast': 20, 'macd_slow': 47, 'macd_signal': 90}. Best is trial 20 with value: -1.3718157350559905.
# Trial 29: MACD(27,38,53) → Sortino: 1.029
# [I 2025-10-27 22:57:17,818] Trial 28 finished with value: -1.0294514655767468 and parameters: {'macd_fast': 27, 'macd_slow': 38, 'macd_signal': 53}. Best is trial 20 with value: -1.3718157350559905.
# Trial 30: MACD(15,34,78) → Sortino: 0.928
# [I 2025-10-27 22:57:17,865] Trial 29 finished with value: -0.928355696396045 and parameters: {'macd_fast': 15, 'macd_slow': 34, 'macd_signal': 78}. Best is trial 20 with value: -1.3718157350559905.
# Trial 31: MACD(23,59,70) → Sortino: 0.870
# [I 2025-10-27 22:57:17,904] Trial 30 finished with value: -0.8698930888013794 and parameters: {'macd_fast': 23, 'macd_slow': 59, 'macd_signal': 70}. Best is trial 20 with value: -1.3718157350559905.
# Trial 32: MACD(14,45,57) → Sortino: 0.974
# [I 2025-10-27 22:57:17,937] Trial 31 finished with value: -0.9742785067045667 and parameters: {'macd_fast': 14, 'macd_slow': 45, 'macd_signal': 57}. Best is trial 20 with value: -1.3718157350559905.
# Trial 33: MACD(19,44,30) → Sortino: 1.068
# [I 2025-10-27 22:57:17,971] Trial 32 finished with value: -1.0682274723230982 and parameters: {'macd_fast': 19, 'macd_slow': 44, 'macd_signal': 30}. Best is trial 20 with value: -1.3718157350559905.
# Trial 34: MACD(21,39,77) → Sortino: 1.258
# [I 2025-10-27 22:57:18,002] Trial 33 finished with value: -1.2579782739825396 and parameters: {'macd_fast': 21, 'macd_slow': 39, 'macd_signal': 77}. Best is trial 20 with value: -1.3718157350559905.
# Trial 35: MACD(18,42,62) → Sortino: 0.975
# [I 2025-10-27 22:57:18,036] Trial 34 finished with value: -0.97511130012423 and parameters: {'macd_fast': 18, 'macd_slow': 42, 'macd_signal': 62}. Best is trial 20 with value: -1.3718157350559905.
# Trial 36: MACD(33,46,32) → Sortino: 1.024
# [I 2025-10-27 22:57:18,073] Trial 35 finished with value: -1.0236579732268012 and parameters: {'macd_fast': 33, 'macd_slow': 46, 'macd_signal': 32}. Best is trial 20 with value: -1.3718157350559905.
# Trial 37: MACD(14,50,95) → Sortino: 1.349
# [I 2025-10-27 22:57:18,109] Trial 36 finished with value: -1.3486737271916407 and parameters: {'macd_fast': 14, 'macd_slow': 50, 'macd_signal': 95}. Best is trial 20 with value: -1.3718157350559905.
# Trial 38: MACD(16,54,93) → Sortino: 1.067
# [I 2025-10-27 22:57:18,144] Trial 37 finished with value: -1.0674249149111712 and parameters: {'macd_fast': 16, 'macd_slow': 54, 'macd_signal': 93}. Best is trial 20 with value: -1.3718157350559905.
# Trial 39: MACD(24,51,97) → Sortino: 1.048
# [I 2025-10-27 22:57:18,176] Trial 38 finished with value: -1.0481994979334799 and parameters: {'macd_fast': 24, 'macd_slow': 51, 'macd_signal': 97}. Best is trial 20 with value: -1.3718157350559905.
# Trial 40: MACD(14,57,86) → Sortino: 1.230
# [I 2025-10-27 22:57:18,212] Trial 39 finished with value: -1.2298692375577363 and parameters: {'macd_fast': 14, 'macd_slow': 57, 'macd_signal': 86}. Best is trial 20 with value: -1.3718157350559905.
# [I 2025-10-27 22:57:18,219] Trial 40 finished with value: 999.0 and parameters: {'macd_fast': 29, 'macd_slow': 27, 'macd_signal': 80}. Best is trial 20 with value: -1.3718157350559905.
# Trial 42: MACD(13,47,97) → Sortino: 1.109
# [I 2025-10-27 22:57:18,250] Trial 41 finished with value: -1.1089322634898775 and parameters: {'macd_fast': 13, 'macd_slow': 47, 'macd_signal': 97}. Best is trial 20 with value: -1.3718157350559905.
# Trial 43: MACD(17,43,50) → Sortino: 0.903
# [I 2025-10-27 22:57:18,282] Trial 42 finished with value: -0.9034127052740959 and parameters: {'macd_fast': 17, 'macd_slow': 43, 'macd_signal': 50}. Best is trial 20 with value: -1.3718157350559905.
# Trial 44: MACD(12,49,73) → Sortino: 0.953
# [I 2025-10-27 22:57:18,322] Trial 43 finished with value: -0.9533518048790345 and parameters: {'macd_fast': 12, 'macd_slow': 49, 'macd_signal': 73}. Best is trial 20 with value: -1.3718157350559905.
# Trial 45: MACD(14,45,87) → Sortino: 1.089
# [I 2025-10-27 22:57:18,357] Trial 44 finished with value: -1.0888348101719045 and parameters: {'macd_fast': 14, 'macd_slow': 45, 'macd_signal': 87}. Best is trial 20 with value: -1.3718157350559905.
# Trial 46: MACD(17,34,60) → Sortino: 0.992
# [I 2025-10-27 22:57:18,392] Trial 45 finished with value: -0.99178184105384 and parameters: {'macd_fast': 17, 'macd_slow': 34, 'macd_signal': 60}. Best is trial 20 with value: -1.3718157350559905.
# Trial 47: MACD(19,55,34) → Sortino: 0.959
# [I 2025-10-27 22:57:18,429] Trial 46 finished with value: -0.9589567991302047 and parameters: {'macd_fast': 19, 'macd_slow': 55, 'macd_signal': 34}. Best is trial 20 with value: -1.3718157350559905.
# Trial 48: MACD(22,38,69) → Sortino: 1.053
# [I 2025-10-27 22:57:18,462] Trial 47 finished with value: -1.053281461973355 and parameters: {'macd_fast': 22, 'macd_slow': 38, 'macd_signal': 69}. Best is trial 20 with value: -1.3718157350559905.
# Trial 49: MACD(25,42,20) → Sortino: 0.930
# [I 2025-10-27 22:57:18,494] Trial 48 finished with value: -0.9298932325960242 and parameters: {'macd_fast': 25, 'macd_slow': 42, 'macd_signal': 20}. Best is trial 20 with value: -1.3718157350559905.
# Trial 50: MACD(16,48,93) → Sortino: 1.144
# [I 2025-10-27 22:57:18,528] Trial 49 finished with value: -1.1439158326116128 and parameters: {'macd_fast': 16, 'macd_slow': 48, 'macd_signal': 93}. Best is trial 20 with value: -1.3718157350559905.
# Trial 51: MACD(12,44,37) → Sortino: 0.968
# [I 2025-10-27 22:57:18,563] Trial 50 finished with value: -0.9680510199679381 and parameters: {'macd_fast': 12, 'macd_slow': 44, 'macd_signal': 37}. Best is trial 20 with value: -1.3718157350559905.
# Trial 52: MACD(21,40,78) → Sortino: 1.352
# [I 2025-10-27 22:57:18,594] Trial 51 finished with value: -1.3517627607925482 and parameters: {'macd_fast': 21, 'macd_slow': 40, 'macd_signal': 78}. Best is trial 20 with value: -1.3718157350559905.
# Trial 53: MACD(20,41,80) → Sortino: 1.372
# [I 2025-10-27 22:57:18,662] Trial 52 finished with value: -1.3723909509378933 and parameters: {'macd_fast': 20, 'macd_slow': 41, 'macd_signal': 80}. Best is trial 52 with value: -1.3723909509378933.
# Trial 54: MACD(21,41,80) → Sortino: 1.352
# [I 2025-10-27 22:57:18,718] Trial 53 finished with value: -1.3522763603678742 and parameters: {'macd_fast': 21, 'macd_slow': 41, 'macd_signal': 80}. Best is trial 52 with value: -1.3723909509378933.
# Trial 55: MACD(21,40,75) → Sortino: 1.247
# [I 2025-10-27 22:57:18,752] Trial 54 finished with value: -1.246576577987734 and parameters: {'macd_fast': 21, 'macd_slow': 40, 'macd_signal': 75}. Best is trial 52 with value: -1.3723909509378933.
# Trial 56: MACD(23,36,65) → Sortino: 0.870
# [I 2025-10-27 22:57:18,787] Trial 55 finished with value: -0.8695036157674834 and parameters: {'macd_fast': 23, 'macd_slow': 36, 'macd_signal': 65}. Best is trial 52 with value: -1.3723909509378933.
# Trial 57: MACD(25,38,85) → Sortino: 1.032
# [I 2025-10-27 22:57:18,822] Trial 56 finished with value: -1.0315400743614296 and parameters: {'macd_fast': 25, 'macd_slow': 38, 'macd_signal': 85}. Best is trial 52 with value: -1.3723909509378933.
# Trial 58: MACD(18,41,79) → Sortino: 0.927
# [I 2025-10-27 22:57:18,858] Trial 57 finished with value: -0.9267773724581606 and parameters: {'macd_fast': 18, 'macd_slow': 41, 'macd_signal': 79}. Best is trial 52 with value: -1.3723909509378933.
# Trial 59: MACD(22,39,72) → Sortino: 1.437
# [I 2025-10-27 22:57:18,899] Trial 58 finished with value: -1.4368201878483404 and parameters: {'macd_fast': 22, 'macd_slow': 39, 'macd_signal': 72}. Best is trial 58 with value: -1.4368201878483404.
# Trial 60: MACD(22,39,71) → Sortino: 1.278
# [I 2025-10-27 22:57:18,936] Trial 59 finished with value: -1.2776888265414126 and parameters: {'macd_fast': 22, 'macd_slow': 39, 'macd_signal': 71}. Best is trial 58 with value: -1.4368201878483404.
# Trial 61: MACD(20,34,67) → Sortino: 1.050
# [I 2025-10-27 22:57:18,973] Trial 60 finished with value: -1.049523340482789 and parameters: {'macd_fast': 20, 'macd_slow': 34, 'macd_signal': 67}. Best is trial 58 with value: -1.4368201878483404.
# Trial 62: MACD(24,36,75) → Sortino: 1.418
# [I 2025-10-27 22:57:19,015] Trial 61 finished with value: -1.418244946872165 and parameters: {'macd_fast': 24, 'macd_slow': 36, 'macd_signal': 75}. Best is trial 58 with value: -1.4368201878483404.
# Trial 63: MACD(24,36,75) → Sortino: 1.418
# [I 2025-10-27 22:57:19,046] Trial 62 finished with value: -1.418244946872165 and parameters: {'macd_fast': 24, 'macd_slow': 36, 'macd_signal': 75}. Best is trial 58 with value: -1.4368201878483404.
# Trial 64: MACD(24,31,83) → Sortino: 1.374
# [I 2025-10-27 22:57:19,078] Trial 63 finished with value: -1.3738756141954866 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 83}. Best is trial 58 with value: -1.4368201878483404.
# Trial 65: MACD(24,30,73) → Sortino: 1.027
# [I 2025-10-27 22:57:19,118] Trial 64 finished with value: -1.0274739717001546 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 73}. Best is trial 58 with value: -1.4368201878483404.
# Trial 66: MACD(28,31,83) → Sortino: 1.375
# [I 2025-10-27 22:57:19,151] Trial 65 finished with value: -1.3749206506016838 and parameters: {'macd_fast': 28, 'macd_slow': 31, 'macd_signal': 83}. Best is trial 58 with value: -1.4368201878483404.
# Trial 67: MACD(27,31,84) → Sortino: 1.409
# [I 2025-10-27 22:57:19,183] Trial 66 finished with value: -1.4094999300983795 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 84}. Best is trial 58 with value: -1.4368201878483404.
# Trial 68: MACD(27,31,83) → Sortino: 1.380
# [I 2025-10-27 22:57:19,219] Trial 67 finished with value: -1.3804574455390493 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 83}. Best is trial 58 with value: -1.4368201878483404.
# Trial 69: MACD(27,31,83) → Sortino: 1.380
# [I 2025-10-27 22:57:19,249] Trial 68 finished with value: -1.3804574455390493 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 83}. Best is trial 58 with value: -1.4368201878483404.
# Trial 70: MACD(27,29,87) → Sortino: 1.390
# [I 2025-10-27 22:57:19,285] Trial 69 finished with value: -1.389625930555156 and parameters: {'macd_fast': 27, 'macd_slow': 29, 'macd_signal': 87}. Best is trial 58 with value: -1.4368201878483404.
# [I 2025-10-27 22:57:19,298] Trial 70 finished with value: 999.0 and parameters: {'macd_fast': 32, 'macd_slow': 29, 'macd_signal': 87}. Best is trial 58 with value: -1.4368201878483404.
# Trial 72: MACD(27,28,89) → Sortino: 1.435
# [I 2025-10-27 22:57:19,331] Trial 71 finished with value: -1.435448278640213 and parameters: {'macd_fast': 27, 'macd_slow': 28, 'macd_signal': 89}. Best is trial 58 with value: -1.4368201878483404.
# [I 2025-10-27 22:57:19,342] Trial 72 finished with value: 999.0 and parameters: {'macd_fast': 26, 'macd_slow': 26, 'macd_signal': 89}. Best is trial 58 with value: -1.4368201878483404.
# [I 2025-10-27 22:57:19,355] Trial 73 finished with value: 999.0 and parameters: {'macd_fast': 30, 'macd_slow': 28, 'macd_signal': 89}. Best is trial 58 with value: -1.4368201878483404.
# Trial 75: MACD(27,32,100) → Sortino: 1.016
# [I 2025-10-27 22:57:19,391] Trial 74 finished with value: -1.0156130790229383 and parameters: {'macd_fast': 27, 'macd_slow': 32, 'macd_signal': 100}. Best is trial 58 with value: -1.4368201878483404.
# Trial 76: MACD(28,33,93) → Sortino: 0.966
# [I 2025-10-27 22:57:19,428] Trial 75 finished with value: -0.9658902865951767 and parameters: {'macd_fast': 28, 'macd_slow': 33, 'macd_signal': 93}. Best is trial 58 with value: -1.4368201878483404.
# [I 2025-10-27 22:57:19,436] Trial 76 finished with value: 999.0 and parameters: {'macd_fast': 29, 'macd_slow': 29, 'macd_signal': 84}. Best is trial 58 with value: -1.4368201878483404.
# Trial 78: MACD(26,35,87) → Sortino: 1.164
# [I 2025-10-27 22:57:19,470] Trial 77 finished with value: -1.1640562359102586 and parameters: {'macd_fast': 26, 'macd_slow': 35, 'macd_signal': 87}. Best is trial 58 with value: -1.4368201878483404.
# Trial 79: MACD(28,32,76) → Sortino: 1.203
# [I 2025-10-27 22:57:19,505] Trial 78 finished with value: -1.2033740797916241 and parameters: {'macd_fast': 28, 'macd_slow': 32, 'macd_signal': 76}. Best is trial 58 with value: -1.4368201878483404.
# [I 2025-10-27 22:57:19,519] Trial 79 finished with value: 999.0 and parameters: {'macd_fast': 30, 'macd_slow': 28, 'macd_signal': 82}. Best is trial 58 with value: -1.4368201878483404.
# [I 2025-10-27 22:57:19,530] Trial 80 finished with value: 999.0 and parameters: {'macd_fast': 26, 'macd_slow': 26, 'macd_signal': 75}. Best is trial 58 with value: -1.4368201878483404.
# Trial 82: MACD(28,32,83) → Sortino: 1.169
# [I 2025-10-27 22:57:19,562] Trial 81 finished with value: -1.1693547668693176 and parameters: {'macd_fast': 28, 'macd_slow': 32, 'macd_signal': 83}. Best is trial 58 with value: -1.4368201878483404.
# Trial 83: MACD(27,30,89) → Sortino: 1.362
# [I 2025-10-27 22:57:19,595] Trial 82 finished with value: -1.362454290281569 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 89}. Best is trial 58 with value: -1.4368201878483404.
# Trial 84: MACD(25,30,85) → Sortino: 1.504
# [I 2025-10-27 22:57:19,629] Trial 83 finished with value: -1.5037387049117852 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 85: MACD(25,35,92) → Sortino: 1.126
# [I 2025-10-27 22:57:19,696] Trial 84 finished with value: -1.125620915021556 and parameters: {'macd_fast': 25, 'macd_slow': 35, 'macd_signal': 92}. Best is trial 83 with value: -1.5037387049117852.
# Trial 86: MACD(25,28,95) → Sortino: 1.267
# [I 2025-10-27 22:57:19,738] Trial 85 finished with value: -1.266614872225786 and parameters: {'macd_fast': 25, 'macd_slow': 28, 'macd_signal': 95}. Best is trial 83 with value: -1.5037387049117852.
# Trial 87: MACD(27,30,86) → Sortino: 1.408
# [I 2025-10-27 22:57:19,779] Trial 86 finished with value: -1.408317989061805 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 88: MACD(23,29,95) → Sortino: 1.112
# [I 2025-10-27 22:57:19,838] Trial 87 finished with value: -1.1122624163477408 and parameters: {'macd_fast': 23, 'macd_slow': 29, 'macd_signal': 95}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:19,851] Trial 88 finished with value: 999.0 and parameters: {'macd_fast': 29, 'macd_slow': 27, 'macd_signal': 69}. Best is trial 83 with value: -1.5037387049117852.
# Trial 90: MACD(31,33,87) → Sortino: 0.977
# [I 2025-10-27 22:57:19,900] Trial 89 finished with value: -0.9765526192649747 and parameters: {'macd_fast': 31, 'macd_slow': 33, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 91: MACD(24,37,85) → Sortino: 1.068
# [I 2025-10-27 22:57:19,934] Trial 90 finished with value: -1.067950257758558 and parameters: {'macd_fast': 24, 'macd_slow': 37, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 92: MACD(27,30,77) → Sortino: 1.386
# [I 2025-10-27 22:57:19,966] Trial 91 finished with value: -1.3858310806818734 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 77}. Best is trial 83 with value: -1.5037387049117852.
# Trial 93: MACD(26,30,81) → Sortino: 1.341
# [I 2025-10-27 22:57:20,003] Trial 92 finished with value: -1.3413503756799505 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:20,012] Trial 93 finished with value: 999.0 and parameters: {'macd_fast': 27, 'macd_slow': 27, 'macd_signal': 78}. Best is trial 83 with value: -1.5037387049117852.
# Trial 95: MACD(24,30,73) → Sortino: 1.027
# [I 2025-10-27 22:57:20,042] Trial 94 finished with value: -1.0274739717001546 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 73}. Best is trial 83 with value: -1.5037387049117852.
# Trial 96: MACD(25,35,91) → Sortino: 1.125
# [I 2025-10-27 22:57:20,074] Trial 95 finished with value: -1.1250723890599883 and parameters: {'macd_fast': 25, 'macd_slow': 35, 'macd_signal': 91}. Best is trial 83 with value: -1.5037387049117852.
# Trial 97: MACD(26,29,75) → Sortino: 0.935
# [I 2025-10-27 22:57:20,113] Trial 96 finished with value: -0.9350817402059147 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 75}. Best is trial 83 with value: -1.5037387049117852.
# Trial 98: MACD(29,32,81) → Sortino: 1.188
# [I 2025-10-27 22:57:20,142] Trial 97 finished with value: -1.1883526429315667 and parameters: {'macd_fast': 29, 'macd_slow': 32, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# Trial 99: MACD(23,33,62) → Sortino: 0.836
# [I 2025-10-27 22:57:20,175] Trial 98 finished with value: -0.8363578407211487 and parameters: {'macd_fast': 23, 'macd_slow': 33, 'macd_signal': 62}. Best is trial 83 with value: -1.5037387049117852.
# Trial 100: MACD(26,31,79) → Sortino: 1.273
# [I 2025-10-27 22:57:20,207] Trial 99 finished with value: -1.2731171144985314 and parameters: {'macd_fast': 26, 'macd_slow': 31, 'macd_signal': 79}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:20,221] Trial 100 finished with value: 999.0 and parameters: {'macd_fast': 39, 'macd_slow': 37, 'macd_signal': 77}. Best is trial 83 with value: -1.5037387049117852.
# Trial 102: MACD(27,31,85) → Sortino: 1.353
# [I 2025-10-27 22:57:20,253] Trial 101 finished with value: -1.3525238009770213 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:20,263] Trial 102 finished with value: 999.0 and parameters: {'macd_fast': 28, 'macd_slow': 28, 'macd_signal': 89}. Best is trial 83 with value: -1.5037387049117852.
# Trial 104: MACD(25,34,82) → Sortino: 1.396
# [I 2025-10-27 22:57:20,295] Trial 103 finished with value: -1.3960582138087656 and parameters: {'macd_fast': 25, 'macd_slow': 34, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 105: MACD(22,36,71) → Sortino: 0.924
# [I 2025-10-27 22:57:20,328] Trial 104 finished with value: -0.923638046742529 and parameters: {'macd_fast': 22, 'macd_slow': 36, 'macd_signal': 71}. Best is trial 83 with value: -1.5037387049117852.
# Trial 106: MACD(25,34,67) → Sortino: 0.875
# [I 2025-10-27 22:57:20,362] Trial 105 finished with value: -0.8753164540605858 and parameters: {'macd_fast': 25, 'macd_slow': 34, 'macd_signal': 67}. Best is trial 83 with value: -1.5037387049117852.
# Trial 107: MACD(24,30,86) → Sortino: 1.259
# [I 2025-10-27 22:57:20,393] Trial 106 finished with value: -1.2589958150769385 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 108: MACD(22,32,81) → Sortino: 0.964
# [I 2025-10-27 22:57:20,427] Trial 107 finished with value: -0.9642373817036859 and parameters: {'macd_fast': 22, 'macd_slow': 32, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# Trial 109: MACD(25,29,91) → Sortino: 1.309
# [I 2025-10-27 22:57:20,462] Trial 108 finished with value: -1.3089137554240524 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 91}. Best is trial 83 with value: -1.5037387049117852.
# Trial 110: MACD(23,34,9) → Sortino: 0.746
# [I 2025-10-27 22:57:20,498] Trial 109 finished with value: -0.745626270544247 and parameters: {'macd_fast': 23, 'macd_slow': 34, 'macd_signal': 9}. Best is trial 83 with value: -1.5037387049117852.
# Trial 111: MACD(27,36,88) → Sortino: 0.999
# [I 2025-10-27 22:57:20,528] Trial 110 finished with value: -0.9991249715460553 and parameters: {'macd_fast': 27, 'macd_slow': 36, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 112: MACD(27,31,84) → Sortino: 1.409
# [I 2025-10-27 22:57:20,560] Trial 111 finished with value: -1.4094999300983795 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 113: MACD(28,33,84) → Sortino: 1.262
# [I 2025-10-27 22:57:20,594] Trial 112 finished with value: -1.2620147839514113 and parameters: {'macd_fast': 28, 'macd_slow': 33, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 114: MACD(26,30,45) → Sortino: 0.981
# [I 2025-10-27 22:57:20,628] Trial 113 finished with value: -0.9807734902522242 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 45}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:20,636] Trial 114 finished with value: 999.0 and parameters: {'macd_fast': 27, 'macd_slow': 27, 'macd_signal': 74}. Best is trial 83 with value: -1.5037387049117852.
# Trial 116: MACD(24,39,77) → Sortino: 1.174
# [I 2025-10-27 22:57:20,692] Trial 115 finished with value: -1.1737761519107848 and parameters: {'macd_fast': 24, 'macd_slow': 39, 'macd_signal': 77}. Best is trial 83 with value: -1.5037387049117852.
# Trial 117: MACD(29,31,79) → Sortino: 1.367
# [I 2025-10-27 22:57:20,747] Trial 116 finished with value: -1.3672600892766957 and parameters: {'macd_fast': 29, 'macd_slow': 31, 'macd_signal': 79}. Best is trial 83 with value: -1.5037387049117852.
# Trial 118: MACD(25,28,82) → Sortino: 1.011
# [I 2025-10-27 22:57:20,801] Trial 117 finished with value: -1.010739066114846 and parameters: {'macd_fast': 25, 'macd_slow': 28, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 119: MACD(28,35,85) → Sortino: 1.002
# [I 2025-10-27 22:57:20,847] Trial 118 finished with value: -1.0016503694188865 and parameters: {'macd_fast': 28, 'macd_slow': 35, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 120: MACD(26,32,94) → Sortino: 1.078
# [I 2025-10-27 22:57:20,891] Trial 119 finished with value: -1.078388834623106 and parameters: {'macd_fast': 26, 'macd_slow': 32, 'macd_signal': 94}. Best is trial 83 with value: -1.5037387049117852.
# Trial 121: MACD(30,33,97) → Sortino: 0.822
# [I 2025-10-27 22:57:20,937] Trial 120 finished with value: -0.8222979775084426 and parameters: {'macd_fast': 30, 'macd_slow': 33, 'macd_signal': 97}. Best is trial 83 with value: -1.5037387049117852.
# Trial 122: MACD(27,29,83) → Sortino: 1.391
# [I 2025-10-27 22:57:20,991] Trial 121 finished with value: -1.3911759129173742 and parameters: {'macd_fast': 27, 'macd_slow': 29, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 123: MACD(26,29,88) → Sortino: 1.428
# [I 2025-10-27 22:57:21,036] Trial 122 finished with value: -1.4282123884844444 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 124: MACD(26,29,87) → Sortino: 1.401
# [I 2025-10-27 22:57:21,074] Trial 123 finished with value: -1.4005998962263544 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:21,090] Trial 124 finished with value: 999.0 and parameters: {'macd_fast': 26, 'macd_slow': 26, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 126: MACD(25,29,90) → Sortino: 1.265
# [I 2025-10-27 22:57:21,132] Trial 125 finished with value: -1.264784486854753 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 90}. Best is trial 83 with value: -1.5037387049117852.
# Trial 127: MACD(26,27,92) → Sortino: 1.329
# [I 2025-10-27 22:57:21,175] Trial 126 finished with value: -1.3293779156261982 and parameters: {'macd_fast': 26, 'macd_slow': 27, 'macd_signal': 92}. Best is trial 83 with value: -1.5037387049117852.
# Trial 128: MACD(23,28,87) → Sortino: 0.923
# [I 2025-10-27 22:57:21,219] Trial 127 finished with value: -0.9225238077349881 and parameters: {'macd_fast': 23, 'macd_slow': 28, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 129: MACD(28,29,85) → Sortino: 1.390
# [I 2025-10-27 22:57:21,263] Trial 128 finished with value: -1.389625930555156 and parameters: {'macd_fast': 28, 'macd_slow': 29, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 130: MACD(24,29,89) → Sortino: 1.199
# [I 2025-10-27 22:57:21,310] Trial 129 finished with value: -1.1985960912740816 and parameters: {'macd_fast': 24, 'macd_slow': 29, 'macd_signal': 89}. Best is trial 83 with value: -1.5037387049117852.
# Trial 131: MACD(25,30,81) → Sortino: 1.227
# [I 2025-10-27 22:57:21,363] Trial 130 finished with value: -1.2268767720650782 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# Trial 132: MACD(28,29,85) → Sortino: 1.390
# [I 2025-10-27 22:57:21,404] Trial 131 finished with value: -1.389625930555156 and parameters: {'macd_fast': 28, 'macd_slow': 29, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 133: MACD(27,28,84) → Sortino: 1.353
# [I 2025-10-27 22:57:21,443] Trial 132 finished with value: -1.3529323588495215 and parameters: {'macd_fast': 27, 'macd_slow': 28, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:21,459] Trial 133 finished with value: 999.0 and parameters: {'macd_fast': 28, 'macd_slow': 27, 'macd_signal': 91}. Best is trial 83 with value: -1.5037387049117852.
# Trial 135: MACD(29,31,88) → Sortino: 1.216
# [I 2025-10-27 22:57:21,493] Trial 134 finished with value: -1.215642784778573 and parameters: {'macd_fast': 29, 'macd_slow': 31, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 136: MACD(26,38,86) → Sortino: 0.999
# [I 2025-10-27 22:57:21,528] Trial 135 finished with value: -0.9991249715460553 and parameters: {'macd_fast': 26, 'macd_slow': 38, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 137: MACD(27,30,80) → Sortino: 1.379
# [I 2025-10-27 22:57:21,573] Trial 136 finished with value: -1.3790772681651022 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 80}. Best is trial 83 with value: -1.5037387049117852.
# Trial 138: MACD(25,29,84) → Sortino: 1.129
# [I 2025-10-27 22:57:21,628] Trial 137 finished with value: -1.1289115332365267 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 139: MACD(26,32,82) → Sortino: 1.393
# [I 2025-10-27 22:57:21,686] Trial 138 finished with value: -1.3925731608889085 and parameters: {'macd_fast': 26, 'macd_slow': 32, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 140: MACD(26,33,82) → Sortino: 1.405
# [I 2025-10-27 22:57:21,746] Trial 139 finished with value: -1.4054774591137023 and parameters: {'macd_fast': 26, 'macd_slow': 33, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 141: MACD(24,33,82) → Sortino: 1.398
# [I 2025-10-27 22:57:21,787] Trial 140 finished with value: -1.3981832134542935 and parameters: {'macd_fast': 24, 'macd_slow': 33, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 142: MACD(24,33,82) → Sortino: 1.398
# [I 2025-10-27 22:57:21,823] Trial 141 finished with value: -1.3981832134542935 and parameters: {'macd_fast': 24, 'macd_slow': 33, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 143: MACD(24,34,78) → Sortino: 1.292
# [I 2025-10-27 22:57:21,858] Trial 142 finished with value: -1.2915050524395173 and parameters: {'macd_fast': 24, 'macd_slow': 34, 'macd_signal': 78}. Best is trial 83 with value: -1.5037387049117852.
# Trial 144: MACD(23,33,81) → Sortino: 1.367
# [I 2025-10-27 22:57:21,895] Trial 143 finished with value: -1.3667678365957543 and parameters: {'macd_fast': 23, 'macd_slow': 33, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# Trial 145: MACD(24,32,79) → Sortino: 1.313
# [I 2025-10-27 22:57:21,928] Trial 144 finished with value: -1.3131489035698787 and parameters: {'macd_fast': 24, 'macd_slow': 32, 'macd_signal': 79}. Best is trial 83 with value: -1.5037387049117852.
# Trial 146: MACD(22,35,76) → Sortino: 1.005
# [I 2025-10-27 22:57:21,961] Trial 145 finished with value: -1.0049239254094844 and parameters: {'macd_fast': 22, 'macd_slow': 35, 'macd_signal': 76}. Best is trial 83 with value: -1.5037387049117852.
# Trial 147: MACD(25,37,82) → Sortino: 1.131
# [I 2025-10-27 22:57:21,998] Trial 146 finished with value: -1.1313141771289188 and parameters: {'macd_fast': 25, 'macd_slow': 37, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 148: MACD(24,33,74) → Sortino: 1.004
# [I 2025-10-27 22:57:22,028] Trial 147 finished with value: -1.0042722705102167 and parameters: {'macd_fast': 24, 'macd_slow': 33, 'macd_signal': 74}. Best is trial 83 with value: -1.5037387049117852.
# Trial 149: MACD(26,34,72) → Sortino: 1.133
# [I 2025-10-27 22:57:22,062] Trial 148 finished with value: -1.132955246420989 and parameters: {'macd_fast': 26, 'macd_slow': 34, 'macd_signal': 72}. Best is trial 83 with value: -1.5037387049117852.
# Trial 150: MACD(23,36,56) → Sortino: 0.799
# [I 2025-10-27 22:57:22,097] Trial 149 finished with value: -0.7993950684895239 and parameters: {'macd_fast': 23, 'macd_slow': 36, 'macd_signal': 56}. Best is trial 83 with value: -1.5037387049117852.
# Trial 151: MACD(25,32,80) → Sortino: 1.392
# [I 2025-10-27 22:57:22,128] Trial 150 finished with value: -1.3924650972543269 and parameters: {'macd_fast': 25, 'macd_slow': 32, 'macd_signal': 80}. Best is trial 83 with value: -1.5037387049117852.
# Trial 152: MACD(25,32,80) → Sortino: 1.392
# [I 2025-10-27 22:57:22,164] Trial 151 finished with value: -1.3924650972543269 and parameters: {'macd_fast': 25, 'macd_slow': 32, 'macd_signal': 80}. Best is trial 83 with value: -1.5037387049117852.
# Trial 153: MACD(26,31,82) → Sortino: 1.408
# [I 2025-10-27 22:57:22,199] Trial 152 finished with value: -1.4081413870817199 and parameters: {'macd_fast': 26, 'macd_slow': 31, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 154: MACD(26,31,83) → Sortino: 1.374
# [I 2025-10-27 22:57:22,231] Trial 153 finished with value: -1.3735186939700204 and parameters: {'macd_fast': 26, 'macd_slow': 31, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 155: MACD(26,34,88) → Sortino: 1.164
# [I 2025-10-27 22:57:22,299] Trial 154 finished with value: -1.1640562359102586 and parameters: {'macd_fast': 26, 'macd_slow': 34, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 156: MACD(24,31,82) → Sortino: 1.197
# [I 2025-10-27 22:57:22,359] Trial 155 finished with value: -1.1968775506434255 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 157: MACD(25,33,86) → Sortino: 1.331
# [I 2025-10-27 22:57:22,400] Trial 156 finished with value: -1.3306158559796084 and parameters: {'macd_fast': 25, 'macd_slow': 33, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# [I 2025-10-27 22:57:22,413] Trial 157 finished with value: 999.0 and parameters: {'macd_fast': 35, 'macd_slow': 35, 'macd_signal': 76}. Best is trial 83 with value: -1.5037387049117852.
# Trial 159: MACD(26,32,78) → Sortino: 1.371
# [I 2025-10-27 22:57:22,452] Trial 158 finished with value: -1.3705890981666462 and parameters: {'macd_fast': 26, 'macd_slow': 32, 'macd_signal': 78}. Best is trial 83 with value: -1.5037387049117852.
# Trial 160: MACD(22,30,90) → Sortino: 1.030
# [I 2025-10-27 22:57:22,488] Trial 159 finished with value: -1.029820436024104 and parameters: {'macd_fast': 22, 'macd_slow': 30, 'macd_signal': 90}. Best is trial 83 with value: -1.5037387049117852.
# Trial 161: MACD(24,31,84) → Sortino: 1.365
# [I 2025-10-27 22:57:22,530] Trial 160 finished with value: -1.3649215960299823 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 162: MACD(25,32,79) → Sortino: 1.228
# [I 2025-10-27 22:57:22,571] Trial 161 finished with value: -1.2275279105148083 and parameters: {'macd_fast': 25, 'macd_slow': 32, 'macd_signal': 79}. Best is trial 83 with value: -1.5037387049117852.
# Trial 163: MACD(27,33,82) → Sortino: 1.243
# [I 2025-10-27 22:57:22,607] Trial 162 finished with value: -1.2427165694206628 and parameters: {'macd_fast': 27, 'macd_slow': 33, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 164: MACD(25,34,86) → Sortino: 1.333
# [I 2025-10-27 22:57:22,650] Trial 163 finished with value: -1.3327390761584756 and parameters: {'macd_fast': 25, 'macd_slow': 34, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 165: MACD(26,32,80) → Sortino: 1.373
# [I 2025-10-27 22:57:22,838] Trial 164 finished with value: -1.3725284272533804 and parameters: {'macd_fast': 26, 'macd_slow': 32, 'macd_signal': 80}. Best is trial 83 with value: -1.5037387049117852.
# Trial 166: MACD(26,30,84) → Sortino: 1.393
# [I 2025-10-27 22:57:22,883] Trial 165 finished with value: -1.39262700638448 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 167: MACD(26,30,88) → Sortino: 1.395
# [I 2025-10-27 22:57:22,919] Trial 166 finished with value: -1.3951931942568392 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 168: MACD(27,30,89) → Sortino: 1.362
# [I 2025-10-27 22:57:22,954] Trial 167 finished with value: -1.362454290281569 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 89}. Best is trial 83 with value: -1.5037387049117852.
# Trial 169: MACD(24,30,88) → Sortino: 1.146
# [I 2025-10-27 22:57:22,986] Trial 168 finished with value: -1.1463191113668203 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 170: MACD(27,31,91) → Sortino: 1.118
# [I 2025-10-27 22:57:23,018] Trial 169 finished with value: -1.1178657374451468 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 91}. Best is trial 83 with value: -1.5037387049117852.
# Trial 171: MACD(26,28,93) → Sortino: 1.355
# [I 2025-10-27 22:57:23,056] Trial 170 finished with value: -1.3551360226169489 and parameters: {'macd_fast': 26, 'macd_slow': 28, 'macd_signal': 93}. Best is trial 83 with value: -1.5037387049117852.
# Trial 172: MACD(26,31,84) → Sortino: 1.437
# [I 2025-10-27 22:57:23,106] Trial 171 finished with value: -1.4373611994120647 and parameters: {'macd_fast': 26, 'macd_slow': 31, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 173: MACD(27,30,86) → Sortino: 1.408
# [I 2025-10-27 22:57:23,160] Trial 172 finished with value: -1.408317989061805 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 174: MACD(28,31,87) → Sortino: 1.259
# [I 2025-10-27 22:57:23,217] Trial 173 finished with value: -1.2587182239925105 and parameters: {'macd_fast': 28, 'macd_slow': 31, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 175: MACD(27,58,86) → Sortino: 0.865
# [I 2025-10-27 22:57:23,268] Trial 174 finished with value: -0.8646930009373185 and parameters: {'macd_fast': 27, 'macd_slow': 58, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 176: MACD(25,30,84) → Sortino: 1.335
# [I 2025-10-27 22:57:23,304] Trial 175 finished with value: -1.3345750002819996 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 177: MACD(27,31,90) → Sortino: 1.164
# [I 2025-10-27 22:57:23,342] Trial 176 finished with value: -1.1639069931791548 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 90}. Best is trial 83 with value: -1.5037387049117852.
# Trial 178: MACD(23,28,85) → Sortino: 0.875
# [I 2025-10-27 22:57:23,471] Trial 177 finished with value: -0.8747067434116493 and parameters: {'macd_fast': 23, 'macd_slow': 28, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 179: MACD(28,36,88) → Sortino: 0.900
# [I 2025-10-27 22:57:23,510] Trial 178 finished with value: -0.9002445082645465 and parameters: {'macd_fast': 28, 'macd_slow': 36, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 180: MACD(24,35,69) → Sortino: 0.868
# [I 2025-10-27 22:57:23,557] Trial 179 finished with value: -0.8677555136325297 and parameters: {'macd_fast': 24, 'macd_slow': 35, 'macd_signal': 69}. Best is trial 83 with value: -1.5037387049117852.
# Trial 181: MACD(26,37,83) → Sortino: 1.121
# [I 2025-10-27 22:57:23,606] Trial 180 finished with value: -1.1208522905451457 and parameters: {'macd_fast': 26, 'macd_slow': 37, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 182: MACD(26,30,85) → Sortino: 1.420
# [I 2025-10-27 22:57:23,639] Trial 181 finished with value: -1.420240072712927 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 183: MACD(25,29,86) → Sortino: 1.280
# [I 2025-10-27 22:57:23,674] Trial 182 finished with value: -1.2802912973651885 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 184: MACD(27,30,82) → Sortino: 1.355
# [I 2025-10-27 22:57:23,716] Trial 183 finished with value: -1.3548545835115646 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 185: MACD(26,33,88) → Sortino: 1.167
# [I 2025-10-27 22:57:23,754] Trial 184 finished with value: -1.1665378026458246 and parameters: {'macd_fast': 26, 'macd_slow': 33, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 186: MACD(25,31,85) → Sortino: 1.437
# [I 2025-10-27 22:57:23,795] Trial 185 finished with value: -1.436663720091256 and parameters: {'macd_fast': 25, 'macd_slow': 31, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 187: MACD(25,31,20) → Sortino: 1.178
# [I 2025-10-27 22:57:23,841] Trial 186 finished with value: -1.1776458296572048 and parameters: {'macd_fast': 25, 'macd_slow': 31, 'macd_signal': 20}. Best is trial 83 with value: -1.5037387049117852.
# Trial 188: MACD(24,31,85) → Sortino: 1.407
# [I 2025-10-27 22:57:23,873] Trial 187 finished with value: -1.4065045262886962 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 189: MACD(24,31,85) → Sortino: 1.407
# [I 2025-10-27 22:57:23,907] Trial 188 finished with value: -1.4065045262886962 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 190: MACD(23,31,86) → Sortino: 1.215
# [I 2025-10-27 22:57:23,941] Trial 189 finished with value: -1.2153984745697914 and parameters: {'macd_fast': 23, 'macd_slow': 31, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 191: MACD(23,29,85) → Sortino: 0.955
# [I 2025-10-27 22:57:23,972] Trial 190 finished with value: -0.9554868790849607 and parameters: {'macd_fast': 23, 'macd_slow': 29, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 192: MACD(24,31,84) → Sortino: 1.365
# [I 2025-10-27 22:57:24,006] Trial 191 finished with value: -1.3649215960299823 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 193: MACD(24,30,81) → Sortino: 0.982
# [I 2025-10-27 22:57:24,039] Trial 192 finished with value: -0.9824445973392057 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# Trial 194: MACD(25,32,84) → Sortino: 1.389
# [I 2025-10-27 22:57:24,076] Trial 193 finished with value: -1.38905774091491 and parameters: {'macd_fast': 25, 'macd_slow': 32, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 195: MACD(22,29,90) → Sortino: 0.885
# [I 2025-10-27 22:57:24,107] Trial 194 finished with value: -0.8845737793474989 and parameters: {'macd_fast': 22, 'macd_slow': 29, 'macd_signal': 90}. Best is trial 83 with value: -1.5037387049117852.
# Trial 196: MACD(24,31,87) → Sortino: 1.292
# [I 2025-10-27 22:57:24,139] Trial 195 finished with value: -1.2924468605560853 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 197: MACD(26,39,83) → Sortino: 0.999
# [I 2025-10-27 22:57:24,175] Trial 196 finished with value: -0.9991249715460553 and parameters: {'macd_fast': 26, 'macd_slow': 39, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 198: MACD(23,28,86) → Sortino: 0.875
# [I 2025-10-27 22:57:24,211] Trial 197 finished with value: -0.8747067434116493 and parameters: {'macd_fast': 23, 'macd_slow': 28, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 199: MACD(28,32,92) → Sortino: 1.164
# [I 2025-10-27 22:57:24,242] Trial 198 finished with value: -1.1640562359102586 and parameters: {'macd_fast': 28, 'macd_slow': 32, 'macd_signal': 92}. Best is trial 83 with value: -1.5037387049117852.
# Trial 200: MACD(25,30,78) → Sortino: 0.995
# [I 2025-10-27 22:57:24,275] Trial 199 finished with value: -0.9949092620683814 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 78}. Best is trial 83 with value: -1.5037387049117852.
# Trial 201: MACD(27,29,81) → Sortino: 1.228
# ...
# Trial 936: MACD(23,30,78) → Sortino: 0.873
# [I 2025-10-27 22:57:53,163] Trial 935 finished with value: -0.8732675188677221 and parameters: {'macd_fast': 23, 'macd_slow': 30, 'macd_signal': 78}. Best is trial 83 with value: -1.5037387049117852.
# Trial 937: MACD(26,29,84) → Sortino: 1.353
# [I 2025-10-27 22:57:53,211] Trial 936 finished with value: -1.3529323588495215 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 938: MACD(24,32,87) → Sortino: 1.409
# [I 2025-10-27 22:57:53,254] Trial 937 finished with value: -1.4091901256129256 and parameters: {'macd_fast': 24, 'macd_slow': 32, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 939: MACD(25,31,87) → Sortino: 1.401
# [I 2025-10-27 22:57:53,293] Trial 938 finished with value: -1.4012111960037108 and parameters: {'macd_fast': 25, 'macd_slow': 31, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 940: MACD(25,30,84) → Sortino: 1.335
# [I 2025-10-27 22:57:53,335] Trial 939 finished with value: -1.3345750002819996 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 941: MACD(26,29,85) → Sortino: 1.474
# [I 2025-10-27 22:57:53,378] Trial 940 finished with value: -1.4743923013498237 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 942: MACD(24,30,75) → Sortino: 0.923
# [I 2025-10-27 22:57:53,420] Trial 941 finished with value: -0.9229887204653001 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 75}. Best is trial 83 with value: -1.5037387049117852.
# Trial 943: MACD(26,29,82) → Sortino: 1.400
# [I 2025-10-27 22:57:53,465] Trial 942 finished with value: -1.3999884660296262 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 944: MACD(27,31,65) → Sortino: 0.959
# [I 2025-10-27 22:57:53,507] Trial 943 finished with value: -0.9589546778840382 and parameters: {'macd_fast': 27, 'macd_slow': 31, 'macd_signal': 65}. Best is trial 83 with value: -1.5037387049117852.
# Trial 945: MACD(24,30,87) → Sortino: 1.219
# [I 2025-10-27 22:57:53,547] Trial 944 finished with value: -1.2194322427173456 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 946: MACD(17,29,86) → Sortino: 0.936
# [I 2025-10-27 22:57:53,588] Trial 945 finished with value: -0.9355201572094309 and parameters: {'macd_fast': 17, 'macd_slow': 29, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 947: MACD(25,30,87) → Sortino: 1.447
# [I 2025-10-27 22:57:53,637] Trial 946 finished with value: -1.4468013352265887 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 948: MACD(25,29,84) → Sortino: 1.129
# [I 2025-10-27 22:57:53,676] Trial 947 finished with value: -1.1289115332365267 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 949: MACD(27,53,82) → Sortino: 0.928
# [I 2025-10-27 22:57:53,720] Trial 948 finished with value: -0.9282410338912385 and parameters: {'macd_fast': 27, 'macd_slow': 53, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 950: MACD(24,28,88) → Sortino: 1.081
# [I 2025-10-27 22:57:53,764] Trial 949 finished with value: -1.0807080844530244 and parameters: {'macd_fast': 24, 'macd_slow': 28, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 951: MACD(29,31,85) → Sortino: 1.160
# [I 2025-10-27 22:57:53,803] Trial 950 finished with value: -1.16007931170635 and parameters: {'macd_fast': 29, 'macd_slow': 31, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 952: MACD(25,30,87) → Sortino: 1.447
# [I 2025-10-27 22:57:53,846] Trial 951 finished with value: -1.4468013352265887 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 953: MACD(25,57,80) → Sortino: 1.016
# [I 2025-10-27 22:57:53,889] Trial 952 finished with value: -1.0162644682380988 and parameters: {'macd_fast': 25, 'macd_slow': 57, 'macd_signal': 80}. Best is trial 83 with value: -1.5037387049117852.
# Trial 954: MACD(26,29,83) → Sortino: 1.398
# [I 2025-10-27 22:57:53,930] Trial 953 finished with value: -1.3981354387728477 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 955: MACD(24,30,88) → Sortino: 1.146
# [I 2025-10-27 22:57:53,973] Trial 954 finished with value: -1.1463191113668203 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 956: MACD(26,31,85) → Sortino: 1.395
# [I 2025-10-27 22:57:54,019] Trial 955 finished with value: -1.3951931942568392 and parameters: {'macd_fast': 26, 'macd_slow': 31, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 957: MACD(23,29,86) → Sortino: 0.955
# [I 2025-10-27 22:57:54,058] Trial 956 finished with value: -0.9554868790849607 and parameters: {'macd_fast': 23, 'macd_slow': 29, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 958: MACD(25,28,89) → Sortino: 1.245
# [I 2025-10-27 22:57:54,099] Trial 957 finished with value: -1.244612264891933 and parameters: {'macd_fast': 25, 'macd_slow': 28, 'macd_signal': 89}. Best is trial 83 with value: -1.5037387049117852.
# Trial 959: MACD(24,28,84) → Sortino: 0.866
# [I 2025-10-27 22:57:54,141] Trial 958 finished with value: -0.8655948787512869 and parameters: {'macd_fast': 24, 'macd_slow': 28, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 960: MACD(25,29,87) → Sortino: 1.283
# [I 2025-10-27 22:57:54,180] Trial 959 finished with value: -1.2832016113297753 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 961: MACD(25,32,89) → Sortino: 1.333
# [I 2025-10-27 22:57:54,224] Trial 960 finished with value: -1.333322990284852 and parameters: {'macd_fast': 25, 'macd_slow': 32, 'macd_signal': 89}. Best is trial 83 with value: -1.5037387049117852.
# Trial 962: MACD(26,30,83) → Sortino: 1.388
# [I 2025-10-27 22:57:54,268] Trial 961 finished with value: -1.3875592088330149 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 963: MACD(24,36,86) → Sortino: 1.161
# [I 2025-10-27 22:57:54,307] Trial 962 finished with value: -1.1613819405036665 and parameters: {'macd_fast': 24, 'macd_slow': 36, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 964: MACD(26,30,90) → Sortino: 1.349
# [I 2025-10-27 22:57:54,348] Trial 963 finished with value: -1.348506707559332 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 90}. Best is trial 83 with value: -1.5037387049117852.
# Trial 965: MACD(25,29,88) → Sortino: 1.500
# [I 2025-10-27 22:57:54,391] Trial 964 finished with value: -1.500256840709343 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 966: MACD(23,27,85) → Sortino: 1.094
# [I 2025-10-27 22:57:54,434] Trial 965 finished with value: -1.0935222845208201 and parameters: {'macd_fast': 23, 'macd_slow': 27, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 967: MACD(25,29,87) → Sortino: 1.283
# [I 2025-10-27 22:57:54,477] Trial 966 finished with value: -1.2832016113297753 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 968: MACD(24,31,54) → Sortino: 0.842
# [I 2025-10-27 22:57:54,522] Trial 967 finished with value: -0.8421295431238587 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 54}. Best is trial 83 with value: -1.5037387049117852.
# Trial 969: MACD(26,29,81) → Sortino: 1.364
# [I 2025-10-27 22:57:54,563] Trial 968 finished with value: -1.3640773451715504 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# Trial 970: MACD(27,30,83) → Sortino: 1.355
# [I 2025-10-27 22:57:54,604] Trial 969 finished with value: -1.3548545835115646 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 971: MACD(25,28,46) → Sortino: 0.859
# [I 2025-10-27 22:57:54,650] Trial 970 finished with value: -0.8588892346199114 and parameters: {'macd_fast': 25, 'macd_slow': 28, 'macd_signal': 46}. Best is trial 83 with value: -1.5037387049117852.
# Trial 972: MACD(24,59,88) → Sortino: 1.021
# [I 2025-10-27 22:57:54,689] Trial 971 finished with value: -1.0206498075140757 and parameters: {'macd_fast': 24, 'macd_slow': 59, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 973: MACD(25,28,85) → Sortino: 1.121
# [I 2025-10-27 22:57:54,734] Trial 972 finished with value: -1.1205692944578423 and parameters: {'macd_fast': 25, 'macd_slow': 28, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 974: MACD(25,30,86) → Sortino: 1.375
# [I 2025-10-27 22:57:54,777] Trial 973 finished with value: -1.375126446223888 and parameters: {'macd_fast': 25, 'macd_slow': 30, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 975: MACD(26,29,88) → Sortino: 1.428
# [I 2025-10-27 22:57:54,818] Trial 974 finished with value: -1.4282123884844444 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 976: MACD(24,31,79) → Sortino: 0.978
# [I 2025-10-27 22:57:54,859] Trial 975 finished with value: -0.9781986652348218 and parameters: {'macd_fast': 24, 'macd_slow': 31, 'macd_signal': 79}. Best is trial 83 with value: -1.5037387049117852.
# Trial 977: MACD(25,29,17) → Sortino: 1.038
# [I 2025-10-27 22:57:54,905] Trial 976 finished with value: -1.0383172347418188 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 17}. Best is trial 83 with value: -1.5037387049117852.
# Trial 978: MACD(26,30,84) → Sortino: 1.393
# [I 2025-10-27 22:57:54,944] Trial 977 finished with value: -1.39262700638448 and parameters: {'macd_fast': 26, 'macd_slow': 30, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 979: MACD(25,32,90) → Sortino: 1.333
# [I 2025-10-27 22:57:54,988] Trial 978 finished with value: -1.333322990284852 and parameters: {'macd_fast': 25, 'macd_slow': 32, 'macd_signal': 90}. Best is trial 83 with value: -1.5037387049117852.
# Trial 980: MACD(24,27,51) → Sortino: 0.896
# [I 2025-10-27 22:57:55,036] Trial 979 finished with value: -0.8961195136196729 and parameters: {'macd_fast': 24, 'macd_slow': 27, 'macd_signal': 51}. Best is trial 83 with value: -1.5037387049117852.
# Trial 981: MACD(23,29,82) → Sortino: 0.866
# [I 2025-10-27 22:57:55,074] Trial 980 finished with value: -0.8655948787512869 and parameters: {'macd_fast': 23, 'macd_slow': 29, 'macd_signal': 82}. Best is trial 83 with value: -1.5037387049117852.
# Trial 982: MACD(26,31,86) → Sortino: 1.424
# [I 2025-10-27 22:57:55,114] Trial 981 finished with value: -1.4240241264077704 and parameters: {'macd_fast': 26, 'macd_slow': 31, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 983: MACD(25,28,88) → Sortino: 1.216
# [I 2025-10-27 22:57:55,159] Trial 982 finished with value: -1.2162850954275204 and parameters: {'macd_fast': 25, 'macd_slow': 28, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 984: MACD(26,33,84) → Sortino: 1.391
# [I 2025-10-27 22:57:55,198] Trial 983 finished with value: -1.3905039247042934 and parameters: {'macd_fast': 26, 'macd_slow': 33, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 985: MACD(24,30,90) → Sortino: 1.374
# [I 2025-10-27 22:57:55,244] Trial 984 finished with value: -1.3742334394404754 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 90}. Best is trial 83 with value: -1.5037387049117852.
# Trial 986: MACD(25,31,87) → Sortino: 1.401
# [I 2025-10-27 22:57:55,289] Trial 985 finished with value: -1.4012111960037108 and parameters: {'macd_fast': 25, 'macd_slow': 31, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 987: MACD(24,28,86) → Sortino: 0.955
# [I 2025-10-27 22:57:55,330] Trial 986 finished with value: -0.9554868790849607 and parameters: {'macd_fast': 24, 'macd_slow': 28, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 988: MACD(26,29,89) → Sortino: 1.454
# [I 2025-10-27 22:57:55,372] Trial 987 finished with value: -1.4541352624190895 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 89}. Best is trial 83 with value: -1.5037387049117852.
# Trial 989: MACD(27,30,84) → Sortino: 1.390
# [I 2025-10-27 22:57:55,416] Trial 988 finished with value: -1.389625930555156 and parameters: {'macd_fast': 27, 'macd_slow': 30, 'macd_signal': 84}. Best is trial 83 with value: -1.5037387049117852.
# Trial 990: MACD(25,29,91) → Sortino: 1.309
# [I 2025-10-27 22:57:55,457] Trial 989 finished with value: -1.3089137554240524 and parameters: {'macd_fast': 25, 'macd_slow': 29, 'macd_signal': 91}. Best is trial 83 with value: -1.5037387049117852.
# Trial 991: MACD(28,30,88) → Sortino: 1.189
# [I 2025-10-27 22:57:55,502] Trial 990 finished with value: -1.1892280868267615 and parameters: {'macd_fast': 28, 'macd_slow': 30, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
# Trial 992: MACD(25,27,81) → Sortino: 0.899
# [I 2025-10-27 22:57:55,546] Trial 991 finished with value: -0.8988013332085938 and parameters: {'macd_fast': 25, 'macd_slow': 27, 'macd_signal': 81}. Best is trial 83 with value: -1.5037387049117852.
# Trial 993: MACD(24,30,86) → Sortino: 1.259
# [I 2025-10-27 22:57:55,586] Trial 992 finished with value: -1.2589958150769385 and parameters: {'macd_fast': 24, 'macd_slow': 30, 'macd_signal': 86}. Best is trial 83 with value: -1.5037387049117852.
# Trial 994: MACD(25,28,83) → Sortino: 1.012
# [I 2025-10-27 22:57:55,631] Trial 993 finished with value: -1.0117105709016112 and parameters: {'macd_fast': 25, 'macd_slow': 28, 'macd_signal': 83}. Best is trial 83 with value: -1.5037387049117852.
# Trial 995: MACD(26,29,89) → Sortino: 1.454
# [I 2025-10-27 22:57:55,676] Trial 994 finished with value: -1.4541352624190895 and parameters: {'macd_fast': 26, 'macd_slow': 29, 'macd_signal': 89}. Best is trial 83 with value: -1.5037387049117852.
# Trial 996: MACD(25,31,85) → Sortino: 1.437
# [I 2025-10-27 22:57:55,716] Trial 995 finished with value: -1.436663720091256 and parameters: {'macd_fast': 25, 'macd_slow': 31, 'macd_signal': 85}. Best is trial 83 with value: -1.5037387049117852.
# Trial 997: MACD(24,26,92) → Sortino: 0.965
# [I 2025-10-27 22:57:55,761] Trial 996 finished with value: -0.9649217991494796 and parameters: {'macd_fast': 24, 'macd_slow': 26, 'macd_signal': 92}. Best is trial 83 with value: -1.5037387049117852.
# Trial 998: MACD(23,29,87) → Sortino: 0.923
# [I 2025-10-27 22:57:55,805] Trial 997 finished with value: -0.9225238077349881 and parameters: {'macd_fast': 23, 'macd_slow': 29, 'macd_signal': 87}. Best is trial 83 with value: -1.5037387049117852.
# Trial 999: MACD(22,30,21) → Sortino: 1.119
# [I 2025-10-27 22:57:55,847] Trial 998 finished with value: -1.119231561243975 and parameters: {'macd_fast': 22, 'macd_slow': 30, 'macd_signal': 21}. Best is trial 83 with value: -1.5037387049117852.
# Trial 1000: MACD(26,28,88) → Sortino: 1.481
# [I 2025-10-27 22:57:55,889] Trial 999 finished with value: -1.4813897713856252 and parameters: {'macd_fast': 26, 'macd_slow': 28, 'macd_signal': 88}. Best is trial 83 with value: -1.5037387049117852.
#
# ✅ Optimization complete!
# Best Parameters: MACD(25,30,85)
# Sortino Ratio: 1.504

# %%
# BENCHMARK ANALYSIS: Best Strategy vs Market (Buy & Hold) - ENHANCED

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    macd_fast, macd_slow, macd_signal = int(best['macd_fast']), int(best['macd_slow']), int(best['macd_signal'])

    print(f"BENCHMARK ANALYSIS: Best MACD({macd_fast},{macd_slow},{macd_signal}) vs Buy & Hold")
    print("=" * 70)

    # Recreate the BEST strategy portfolio to get returns
    close_array = train_close.values
    macd, macd_signal_line, macd_hist = talib.MACD(
        close_array,
        fastperiod=macd_fast,
        slowperiod=macd_slow,
        signalperiod=macd_signal
    )
    
    macd_series = pd.Series(macd, index=train_close.index)
    signal_series = pd.Series(macd_signal_line, index=train_close.index)
    
    # MACD crossover signals
    entries = (macd_series > signal_series) & (macd_series.shift(1) <= signal_series.shift(1))
    exits = (macd_series < signal_series) & (macd_series.shift(1) >= signal_series.shift(1))
    
    entries = pd.Series(entries, index=train_close.index).fillna(False)
    exits = pd.Series(exits, index=train_close.index).fillna(False)

    best_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Create buy & hold benchmark
    benchmark_entries = np.zeros(len(train_close), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(train_close), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=train_close,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Get returns for comparison
    strategy_returns = best_pf.returns().dropna()
    benchmark_returns = benchmark_pf.returns().dropna()

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy annualized return
    strategy_annualized_return = best['annualized_return']

    # Performance comparison
    print("\nPERFORMANCE COMPARISON:")
    print(f"Strategy (MACD {macd_fast},{macd_slow},{macd_signal}):")
    print(f"  Total Return:      {best['total_return']:.2%}")
    print(f"  Annualized Return: {strategy_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {best['sharpe_ratio']:.3f}")
    print(f"  Sortino Ratio:     {best['sortino_ratio']:.3f}")
    print(f"  Max Drawdown:      {best['max_drawdown']:.2%}")
    print(f"  Volatility:        {best['volatility']:.2%}")
    print(f"  Total Trades:      {best['total_trades']}")
    print(f"  Win Rate:          {best['win_rate']:.1f}%")
    print(f"  Profit Factor:     {best['profit_factor']:.2f}")

    print(f"\nBenchmark (Buy & Hold {TICKER}):")
    print(f"  Total Return:      {bench_total_return:.2%}")
    print(f"  Annualized Return: {bench_annualized_return:.2%}")
    print(f"  Sharpe Ratio:      {bench_sharpe:.3f}")
    print(f"  Sortino Ratio:     {bench_sortino:.3f}")
    print(f"  Max Drawdown:      {bench_max_drawdown:.2%}")
    print(f"  Volatility:        {bench_volatility:.2%}")

    # Outperformance metrics
    excess_return = best['total_return'] - bench_total_return
    excess_annualized_return = strategy_annualized_return - bench_annualized_return
    sharpe_diff = best['sharpe_ratio'] - bench_sharpe
    sortino_diff = best['sortino_ratio'] - bench_sortino
    excess_max_drawdown = best['max_drawdown'] - bench_max_drawdown

    print(f"\nOUTPERFORMANCE METRICS:")
    print(f"  Excess Return:           {excess_return:.2%}")
    print(f"  Excess Annualized Return: {excess_annualized_return:.2%}")
    print(f"  Sharpe Difference:       {sharpe_diff:.3f}")
    print(f"  Sortino Difference:      {sortino_diff:.3f}")
    print(f"  Excess Max Drawdown:      {excess_max_drawdown:.2%} ({'Better' if excess_max_drawdown > 0 else '❌ Worse'})")
    
    # Calculate beta
    market_beta = best['volatility'] / bench_volatility if bench_volatility != 0 else np.nan
    print(f"  Market Beta (approx):     {market_beta:.3f} ({'Lower risk' if market_beta < 1 else '⚠️ Higher risk'})")
else:
    print("⚠️ No results available for benchmark analysis.")
# Out:
# BENCHMARK ANALYSIS: Best MACD(25,30,85) vs Buy & Hold
# ======================================================================
#
# PERFORMANCE COMPARISON:
# Strategy (MACD 25,30,85):
#   Total Return:      255.06%
#   Annualized Return: 31.10%
#   Sharpe Ratio:      1.084
#   Sortino Ratio:     1.504
#   Max Drawdown:      -34.37%
#   Volatility:        46.14%
#   Total Trades:      13.0
#   Win Rate:          53.8%
#   Profit Factor:     4.29
#
# Benchmark (Buy & Hold TQQQ):
#   Total Return:      127.54%
#   Annualized Return: 28.98%
#   Sharpe Ratio:      0.746
#   Sortino Ratio:     1.028
#   Max Drawdown:      -75.32%
#   Volatility:        91.50%
#
# OUTPERFORMANCE METRICS:
#   Excess Return:           127.52%
#   Excess Annualized Return: 2.12%
#   Sharpe Difference:       0.338
#   Sortino Difference:      0.476
#   Excess Max Drawdown:      40.95% (Better)
#   Market Beta (approx):     0.504 (Lower risk)

# %%
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON

FREQ = "1D"

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    macd_fast, macd_slow, macd_signal = int(best['macd_fast']), int(best['macd_slow']), int(best['macd_signal'])

    # Out-of-sample validation
    close_array_val = val_close.values
    macd_val, macd_signal_line_val, _ = talib.MACD(
        close_array_val,
        fastperiod=macd_fast,
        slowperiod=macd_slow,
        signalperiod=macd_signal
    )
    
    macd_series_val = pd.Series(macd_val, index=val_close.index)
    signal_series_val = pd.Series(macd_signal_line_val, index=val_close.index)
    
    entries_val = pd.Series((macd_series_val > signal_series_val) & (macd_series_val.shift(1) <= signal_series_val.shift(1)), index=val_close.index).fillna(False)
    exits_val = pd.Series((macd_series_val < signal_series_val) & (macd_series_val.shift(1) >= signal_series_val.shift(1)), index=val_close.index).fillna(False)

    pf_val = vbt.Portfolio.from_signals(
        close=val_close,
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    # Out-of-sample metrics
    val_total_return = pf_val.total_return()
    val_annualized_return = pf_val.annualized_return(freq=FREQ)
    val_sharpe = pf_val.sharpe_ratio(freq=FREQ)
    val_sortino = pf_val.sortino_ratio(freq=FREQ)
    val_max_drawdown = pf_val.max_drawdown()
    val_volatility = pf_val.annualized_volatility(freq=FREQ)

    trades_val = pf_val.trades
    val_total_trades = len(trades_val)
    years = max((val_close.index[-1] - val_close.index[0]).days / 365.25, 1e-9)
    val_trades_per_year = val_total_trades / years

    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    def chg(before, after):
        if pd.isna(before) or pd.isna(after) or before == 0:
            return "N/A"
        return f"{((after - before) / abs(before)) * 100:+.1f}%"

    print(f"IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best MACD({macd_fast},{macd_slow},{macd_signal})")
    print("=" * 80)

    print(f"{'METRIC':<25} {'IN-SAMPLE':<15} {'OUT-OF-SAMPLE':<15} {'DEGRADATION':<15}")

    print("\nRETURN METRICS:")
    print(f"{'Total Return':<25} {best['total_return']:<15.2%} {val_total_return:<15.2%} {chg(best['total_return'], val_total_return)}")
    print(f"{'Annualized Return':<25} {best['annualized_return']:<15.2%} {val_annualized_return:<15.2%} {chg(best['annualized_return'], val_annualized_return)}")

    print("\nRISK-ADJUSTED METRICS:")
    print(f"{'Sharpe Ratio':<25} {best['sharpe_ratio']:<15.3f} {val_sharpe:<15.3f} {chg(best['sharpe_ratio'], val_sharpe)}")
    print(f"{'Sortino Ratio':<25} {best['sortino_ratio']:<15.3f} {val_sortino:<15.3f} {chg(best['sortino_ratio'], val_sortino)}")

    print("\nRISK METRICS:")
    print(f"{'Max Drawdown':<25} {best['max_drawdown']:<15.2%} {val_max_drawdown:<15.2%} {chg(best['max_drawdown'], val_max_drawdown)}")
    print(f"{'Volatility':<25} {best['volatility']:<15.2%} {val_volatility:<15.2%} {chg(best['volatility'], val_volatility)}")

    print("\nTRADE METRICS:")
    print(f"{'Total Trades':<25} {best['total_trades']:<15.0f} {val_total_trades:<15.0f} {chg(best['total_trades'], val_total_trades)}")
    print(f"{'Trades per Year':<25} {best['trades_per_year']:<15.1f} {val_trades_per_year:<15.1f} {chg(best['trades_per_year'], val_trades_per_year)}")
    print(f"{'Win Rate %':<25} {best['win_rate']:<15.1f} {val_win_rate_pct:<15.1f} {chg(best['win_rate'], val_win_rate_pct)}")
    print(f"{'Profit Factor':<25} {best['profit_factor']:<15.2f} {val_profit_factor:<15.2f} {chg(best['profit_factor'], val_profit_factor)}")
    print(f"{'Expectancy':<25} {best['expectancy']:<15.4f} {val_expectancy:<15.4f} {chg(best['expectancy'], val_expectancy)}")
else:
    print("⚠️ No results for comparison.")
# Out:
# IN-SAMPLE vs OUT-OF-SAMPLE COMPARISON: Best MACD(25,30,85)
# ================================================================================
# METRIC                    IN-SAMPLE       OUT-OF-SAMPLE   DEGRADATION
#
# RETURN METRICS:
# Total Return              255.06%         158.15%         -38.0%
# Annualized Return         31.10%          55.25%          +77.6%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio              1.084           1.418           +30.8%
# Sortino Ratio             1.504           2.094           +39.3%
#
# RISK METRICS:
# Max Drawdown              -34.37%         -26.94%         +21.6%
# Volatility                46.14%          35.49%          -23.1%
#
# TRADE METRICS:
# Total Trades              13              6               -53.8%
# Trades per Year           2.8             1.9             -31.1%
# Win Rate %                53.8            83.3            +54.8%
# Profit Factor             4.29            11.57           +169.7%
# Expectancy                0.1356          0.1921          +41.7%

# %%
# OUT-OF-SAMPLE BENCHMARK COMPARISON

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    macd_fast, macd_slow, macd_signal = int(best['macd_fast']), int(best['macd_slow']), int(best['macd_signal'])

    print(f"OUT-OF-SAMPLE BENCHMARK: Best MACD({macd_fast},{macd_slow},{macd_signal}) vs Buy & Hold")
    print("=" * 70)

    # Use validation data
    close_data = val_close
    
    # Recreate the BEST strategy portfolio with MACD
    close_array = close_data.values
    macd, macd_signal_line, _ = talib.MACD(
        close_array,
        fastperiod=macd_fast,
        slowperiod=macd_slow,
        signalperiod=macd_signal
    )
    
    macd_series = pd.Series(macd, index=close_data.index)
    signal_series = pd.Series(macd_signal_line, index=close_data.index)
    
    entries = pd.Series((macd_series > signal_series) & (macd_series.shift(1) <= signal_series.shift(1)), index=close_data.index).fillna(False)
    exits = pd.Series((macd_series < signal_series) & (macd_series.shift(1) >= signal_series.shift(1)), index=close_data.index).fillna(False)

    strategy_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=entries,
        exits=exits,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='D'
    )

    # Buy & hold benchmark
    benchmark_entries = np.zeros(len(close_data), dtype=bool)
    benchmark_entries[0] = True
    benchmark_exits = np.zeros(len(close_data), dtype=bool)

    benchmark_pf = vbt.Portfolio.from_signals(
        close=close_data,
        entries=benchmark_entries,
        exits=benchmark_exits,
        init_cash=100_000,
        fees=0.0005,
        freq='D'
    )

    # Benchmark metrics
    bench_total_return = benchmark_pf.total_return()
    bench_annualized_return = benchmark_pf.annualized_return(freq='D')
    bench_sharpe = benchmark_pf.sharpe_ratio(freq='D')
    bench_sortino = benchmark_pf.sortino_ratio(freq='D')
    bench_max_drawdown = benchmark_pf.max_drawdown()
    bench_volatility = benchmark_pf.annualized_volatility(freq='D')

    # Strategy metrics
    trades_val = strategy_pf.trades
    val_total_trades = len(trades_val)
    years = max((close_data.index[-1] - close_data.index[0]).days / 365.25, 1e-9)
    
    val_win_rate_pct = np.nan
    val_profit_factor = np.nan
    val_expectancy = 0.0
    
    if val_total_trades > 0:
        tr = trades_val.returns.values if hasattr(trades_val.returns, 'values') else np.array(trades_val.returns)
        if tr.size > 0:
            pos = tr[tr > 0]
            neg = tr[tr < 0]
            val_win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) > 0 else np.nan
            gains = pos.sum() if len(pos) else 0.0
            losses = abs(neg.sum()) if len(neg) else 0.0
            val_profit_factor = gains / losses if losses > 0 else np.inf
            val_expectancy = tr.mean()

    strategy_total_return = strategy_pf.total_return()
    strategy_annualized_return = strategy_pf.annualized_return(freq='D')
    strategy_sharpe = strategy_pf.sharpe_ratio(freq='D')
    strategy_sortino = strategy_pf.sortino_ratio(freq='D')
    strategy_max_drawdown = strategy_pf.max_drawdown()
    strategy_volatility = strategy_pf.annualized_volatility(freq='D')

    # Performance comparison
    print(f"\n{'METRIC':<30} {'STRATEGY':<20} {'BUY & HOLD':<15} {'OUTPERFORMANCE':<15}")
    print("=" * 80)
    
    print(f"\nRETURN METRICS:")
    excess_return = strategy_total_return - bench_total_return
    print(f"{'Total Return':<30} {strategy_total_return:>20.2%} {bench_total_return:>15.2%} {excess_return:>+15.2%}")
    
    excess_annual = strategy_annualized_return - bench_annualized_return
    print(f"{'Annualized Return':<30} {strategy_annualized_return:>20.2%} {bench_annualized_return:>15.2%} {excess_annual:>+15.2%}")

    print(f"\nRISK-ADJUSTED METRICS:")
    excess_sharpe = strategy_sharpe - bench_sharpe
    print(f"{'Sharpe Ratio':<30} {strategy_sharpe:>20.3f} {bench_sharpe:>15.3f} {excess_sharpe:>+15.3f}")
    
    excess_sortino = strategy_sortino - bench_sortino
    print(f"{'Sortino Ratio':<30} {strategy_sortino:>20.3f} {bench_sortino:>15.3f} {excess_sortino:>+15.3f}")

    print(f"\nRISK METRICS:")
    excess_dd = strategy_max_drawdown - bench_max_drawdown
    print(f"{'Max Drawdown':<30} {strategy_max_drawdown:>20.2%} {bench_max_drawdown:>15.2%} {excess_dd:>+15.2%}")
    
    excess_vol = strategy_volatility - bench_volatility
    print(f"{'Volatility':<30} {strategy_volatility:>20.2%} {bench_volatility:>15.2%} {excess_vol:>+15.2%}")

    print(f"\nTRADE METRICS:")
    print(f"{'Total Trades':<30} {val_total_trades:>20.0f}")
    print(f"{'Win Rate %':<30} {val_win_rate_pct:>20.1f}")
    print(f"{'Profit Factor':<30} {val_profit_factor:>20.2f}")
    print(f"{'Expectancy':<30} {val_expectancy:>20.4f}")

    print(f"\n✅ Out-of-sample evaluation complete!")
    print(f"📊 Period: {close_data.index[0].date()} → {close_data.index[-1].date()}")
    
    # Summary verdict
    if strategy_total_return > bench_total_return and strategy_sharpe > bench_sharpe:
        print(f"🏆 Strategy OUTPERFORMS Buy & Hold on validation set!")
    elif strategy_total_return > bench_total_return:
        print(f"📈 Strategy has higher returns but Buy & Hold has better Sharpe")
    elif strategy_sharpe > bench_sharpe:
        print(f"💪 Strategy has better risk-adjusted returns despite lower total return")
    else:
        print(f"⚠️ Strategy underperforms Buy & Hold on validation set")
else:
    print("⚠️ No results available.")
# Out:
# OUT-OF-SAMPLE BENCHMARK: Best MACD(25,30,85) vs Buy & Hold
# ======================================================================
#
# METRIC                         STRATEGY             BUY & HOLD      OUTPERFORMANCE
# ================================================================================
#
# RETURN METRICS:
# Total Return                                158.15%         332.81%        -174.66%
# Annualized Return                            55.25%          97.29%         -42.04%
#
# RISK-ADJUSTED METRICS:
# Sharpe Ratio                                  1.418           1.262          +0.156
# Sortino Ratio                                 2.094           1.882          +0.212
#
# RISK METRICS:
# Max Drawdown                                -26.94%         -58.04%         +31.10%
# Volatility                                   35.49%          77.31%         -41.82%
#
# TRADE METRICS:
# Total Trades                                      6
# Win Rate %                                     83.3
# Profit Factor                                 11.57
# Expectancy                                   0.1921
#
# ✅ Out-of-sample evaluation complete!
# 📊 Period: 2022-09-08 → 2025-10-27
# 💪 Strategy has better risk-adjusted returns despite lower total return

# %%
# VISUALS: Signals + Equity Curves - BEST STRATEGY

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Build full sample EMAs and signals
    ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
    ema2_full = vbt.MA.run(close, ema2, ewm=True).ma
    ema3_full = vbt.MA.run(close, ema3, ewm=True).ma

    # Triple EMA crossover signals
    entries_1 = ema1_full.vbt.crossed_above(ema2_full)
    entries_2 = ema1_full.vbt.crossed_above(ema3_full)
    entries_3 = ema2_full.vbt.crossed_above(ema3_full)
    entries_full = (entries_1 | entries_2 | entries_3)
    
    exits_1 = ema1_full.vbt.crossed_below(ema2_full)
    exits_2 = ema1_full.vbt.crossed_below(ema3_full)
    exits_3 = ema2_full.vbt.crossed_below(ema3_full)
    exits_full = (exits_1 | exits_2 | exits_3)

    entries_full = entries_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)
    exits_full = exits_full.reindex(close.index).fillna(False).to_numpy(dtype=bool)

    # 1) Price + Triple EMAs + signals (full sample)
    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, close.values, label='Close', color='black', linewidth=1.5, alpha=0.7)
    ax.plot(close.index, ema1_full.values, label=f'Fast EMA ({ema1})', color='blue', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema2_full.values, label=f'Medium EMA ({ema2})', color='orange', alpha=0.8, linewidth=1.2)
    ax.plot(close.index, ema3_full.values, label=f'Slow EMA ({ema3})', color='purple', alpha=0.8, linewidth=1.2)

    buy_idx = close.index[entries_full]
    sell_idx = close.index[exits_full]
    ax.scatter(buy_idx, close.reindex(buy_idx).values, marker='^', color='green', s=80, label='Buy', zorder=5)
    ax.scatter(sell_idx, close.reindex(sell_idx).values, marker='v', color='red', s=80, label='Sell', zorder=5)

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Full Sample Signals', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Price', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    # 2) Equity curves: train / val / full
    price_full = close.to_numpy(dtype=float)
    entries_train = entries_full[:split_idx]
    exits_train = exits_full[:split_idx]
    entries_val = entries_full[split_idx:]
    exits_val = exits_full[split_idx:]

    pf_full = vbt.Portfolio.from_signals(
        close=price_full,
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_train = vbt.Portfolio.from_signals(
        close=train_close.to_numpy(dtype=float),
        entries=entries_train,
        exits=exits_train,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    pf_val2 = vbt.Portfolio.from_signals(
        close=val_close.to_numpy(dtype=float),
        entries=entries_val,
        exits=exits_val,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq=FREQ
    )

    eq_full = (1 + pf_full.returns()).cumprod()
    eq_train = (1 + pf_train.returns()).cumprod()
    eq_val = (1 + pf_val2.returns()).cumprod()

    fig, ax = plt.subplots(figsize=(14, 7))
    ax.plot(close.index, eq_full.values, label='Full Sample', color='black', linewidth=2)
    ax.plot(train_close.index, eq_train.values, label='Train (In-Sample)', color='blue', linewidth=1.5, alpha=0.8)
    ax.plot(val_close.index, eq_val.values, label='Validation (Out-of-Sample)', color='orange', linewidth=1.5, alpha=0.8)

    # Add vertical line to show train/val split
    ax.axvline(x=train_close.index[-1], color='red', linestyle='--', alpha=0.5, label='Train/Val Split')

    ax.set_title(f'Best Triple EMA({ema1},{ema2},{ema3}) - Equity Curves', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date', fontsize=12)
    ax.set_ylabel('Cumulative Returns (normalized to 1)', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()

    print(f"✅ Visualizations complete for best strategy: EMA({ema1},{ema2},{ema3})")
else:
    print("⚠️ No results to visualize.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\harka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ema1_period'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 5
#       3 if 'results_df' in globals() and not results_df.empty:
#       4     best = results_df.iloc[0]
# ----> 5     ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])
#       7     # Build full sample EMAs and signals
#       8     ema1_full = vbt.MA.run(close, ema1, ewm=True).ma
#
# File c:\Users\harka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File c:\Users\harka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File c:\Users\harka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'ema1_period'

# %%
# TRADE-BY-TRADE RETURNS (BAR) + CUMULATIVE PER-TRADE EQUITY

if 'results_df' not in globals() or results_df.empty:
    print("⚠️ No results available.")
else:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    # Resolve full close series
    full_close = close.astype(float)

    # Indicators
    ema1_full = vbt.MA.run(full_close, ema1, ewm=True)
    ema2_full = vbt.MA.run(full_close, ema2, ewm=True)
    ema3_full = vbt.MA.run(full_close, ema3, ewm=True)

    # Signals
    entries_raw = (
        ema1_full.ma_crossed_above(ema2_full.ma) |
        ema1_full.ma_crossed_above(ema3_full.ma) |
        ema2_full.ma_crossed_above(ema3_full.ma)
    )
    exits_raw = (
        ema1_full.ma_crossed_below(ema2_full.ma) |
        ema1_full.ma_crossed_below(ema3_full.ma) |
        ema2_full.ma_crossed_below(ema3_full.ma)
    )

    entries_full = pd.Series(np.asarray(entries_raw).ravel(), index=full_close.index, dtype=bool)
    exits_full = pd.Series(np.asarray(exits_raw).ravel(), index=full_close.index, dtype=bool)

    # Backtest
    pf_full = vbt.Portfolio.from_signals(
        close=full_close.to_numpy(dtype=float),
        entries=entries_full,
        exits=exits_full,
        init_cash=100_000,
        fees=0.0005,
        slippage=0.0005,
        freq='1D'
    )

    # Trade-by-trade returns
    trades = pf_full.trades
    trade_returns = trades.returns.values if hasattr(trades.returns, 'values') else np.asarray(trades.returns)
    trade_returns = np.asarray(trade_returns).ravel()

    if trade_returns.size == 0:
        print("No trades to plot.")
    else:
        # Calculate statistics
        winning_trades = trade_returns[trade_returns > 0]
        losing_trades = trade_returns[trade_returns < 0]

        total_trades = len(trade_returns)
        win_count = len(winning_trades)
        loss_count = len(losing_trades)
        win_rate = (win_count / total_trades * 100) if total_trades > 0 else 0

        avg_win_pct = (winning_trades.mean() * 100) if len(winning_trades) > 0 else 0
        avg_loss_pct = (losing_trades.mean() * 100) if len(losing_trades) > 0 else 0
        max_win_pct = (winning_trades.max() * 100) if len(winning_trades) > 0 else 0
        max_loss_pct = (losing_trades.min() * 100) if len(losing_trades) > 0 else 0

        print(f"Total trades plotted: {total_trades}")
        print(f"Win Rate: {win_rate:.1f}% ({win_count}W / {loss_count}L)")
        print(f"Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%")
        print(f"Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%")

        equity_per_trade = np.cumprod(1.0 + trade_returns)

        fig, axes = plt.subplots(2, 1, figsize=(14, 9), sharex=False)

        # Per-trade returns (%)
        x = np.arange(1, trade_returns.size + 1)
        colors = np.where(trade_returns >= 0, 'green', 'red')
        axes[0].bar(x, trade_returns * 100.0, color=colors, alpha=0.85, width=0.8)
        axes[0].axhline(0, color='black', linewidth=1, alpha=0.6)

        # Add statistics text box
        stats_text = (
            f'Win Rate: {win_rate:.1f}% ({win_count}W/{loss_count}L)\n'
            f'Avg Win: {avg_win_pct:.2f}% | Avg Loss: {avg_loss_pct:.2f}%\n'
            f'Max Win: {max_win_pct:.2f}% | Max Loss: {max_loss_pct:.2f}%'
        )
        axes[0].text(0.02, 0.98, stats_text, transform=axes[0].transAxes,
                    fontsize=10, verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

        axes[0].set_title(f'Per-Trade Returns (%) - Triple EMA({ema1},{ema2},{ema3}) Full Sample',
                         fontsize=13, fontweight='bold')
        axes[0].set_ylabel('Return (%)')
        axes[0].grid(True, alpha=0.3)

        # Cumulative equity per trade
        axes[1].plot(x, equity_per_trade, color='black', linewidth=2)
        axes[1].set_title('Cumulative Equity per Trade (Trade Domain)', fontsize=13)
        axes[1].set_xlabel('Trade #')
        axes[1].set_ylabel('Equity (x)')
        axes[1].grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()
# Out:
# Total trades plotted: 31
# Win Rate: 48.4% (15W / 16L)
# Avg Win: 32.72% | Avg Loss: -5.82%
# Max Win: 126.45% | Max Loss: -11.18%

# %%
# PARAMETER SENSITIVITY TABLE (±15 lookbacks around BEST ema1, ema2, ema3)

if 'results_df' in globals() and not results_df.empty:
    best = results_df.iloc[0]
    ema1, ema2, ema3 = int(best['ema1_period']), int(best['ema2_period']), int(best['ema3_period'])

    print(f"🔬 Parameter Sensitivity Analysis for Best EMA({ema1},{ema2},{ema3})")
    print("=" * 80)

    # Create sensitivity ranges (±15 around each parameter)
    fast_candidates = list(range(max(2, ema1 - 15), ema1 + 16))
    medium_candidates = list(range(max(3, ema2 - 15), ema2 + 16))
    slow_candidates = list(range(max(4, ema3 - 15), ema3 + 16))

    # Test variations: vary one parameter at a time
    combos = ([(f, ema2, ema3) for f in fast_candidates] +
              [(ema1, m, ema3) for m in medium_candidates if m != ema2] +
              [(ema1, ema2, s) for s in slow_candidates if s != ema3])

    price_np = train_close.to_numpy(dtype=float)
    idx = train_close.index

    def series_to_np_bool(s: pd.Series) -> np.ndarray:
        return s.reindex(idx).fillna(False).astype(bool).to_numpy(dtype=bool)

    def eval_combo(e1: int, e2: int, e3: int) -> dict:
        fma = vbt.MA.run(train_close, e1, ewm=True).ma
        mma = vbt.MA.run(train_close, e2, ewm=True).ma
        sma = vbt.MA.run(train_close, e3, ewm=True).ma

        # Triple EMA crossover
        e = series_to_np_bool(
            (fma.vbt.crossed_above(mma) & (fma > sma)) |
            (mma.vbt.crossed_above(sma) & (fma > mma))
        )
        x = series_to_np_bool(
            (fma.vbt.crossed_below(mma) & (fma < sma)) |
            (mma.vbt.crossed_below(sma) & (fma < mma))
        )

        pf = vbt.Portfolio.from_signals(
            close=price_np, entries=e, exits=x,
            init_cash=100_000, fees=0.0005, slippage=0.0005, freq='1D'
        )

        total_return = float(pf.total_return())
        sharpe = float(pf.sharpe_ratio(freq='1D'))
        sortino = float(pf.sortino_ratio(freq='1D'))
        mdd = float(pf.max_drawdown())
        vol = float(pf.annualized_volatility(freq='1D'))

        trades = pf.trades
        ntr = len(trades)
        win_rate_pct = np.nan
        profit_factor = np.nan
        expectancy = 0.0
        if ntr > 0:
            tr = trades.returns.values if hasattr(trades.returns, 'values') else np.array(trades.returns)
            if tr.size > 0:
                pos = tr[tr > 0]
                neg = tr[tr < 0]
                win_rate_pct = (len(pos) / len(tr)) * 100 if len(tr) else np.nan
                gains = pos.sum() if len(pos) else 0.0
                losses = abs(neg.sum()) if len(neg) else 0.0
                profit_factor = gains / losses if losses > 0 else np.inf
                expectancy = float(tr.mean())

        return {
            'ema1': e1, 'ema2': e2, 'ema3': e3,
            'sharpe': sharpe, 'sortino': sortino,
            'total_return': total_return, 'max_drawdown': mdd, 'volatility': vol,
            'total_trades': ntr, 'win_rate_pct': win_rate_pct,
            'profit_factor': profit_factor, 'expectancy': expectancy
        }

    rows = []
    for combo in combos:
        try:
            rows.append(eval_combo(*combo))
        except Exception:
            pass

    if not rows:
        print("⚠️ No sensitivity results computed.")
    else:
        sens = pd.DataFrame(rows)

        # Show as a table
        cols = ['ema1','ema2','ema3','sharpe','sortino','total_return','max_drawdown','volatility',
                'total_trades','win_rate_pct','profit_factor','expectancy']
        sens_table = sens[cols].sort_values(['ema1','ema2','ema3'])

        print(f"\n📊 Sensitivity Results ({len(sens_table)} variations tested):\n")
        print(sens_table.to_string())

        # Compact variation summary
        metric_cols = ['sharpe','sortino','total_return','max_drawdown','volatility',
                       'win_rate_pct','profit_factor','expectancy']
        summary = sens_table[metric_cols].agg(['mean','std','min','max']).T

        print("\n📈 Sensitivity Summary (mean / std / min / max):")
        print(summary.round(4).to_string())

        # Highlight best performer in sensitivity test
        best_sens_idx = sens_table['sharpe'].idxmax()
        best_sens = sens_table.loc[best_sens_idx]
        print(f"\n🏆 Best in Sensitivity Test: EMA({int(best_sens['ema1'])},{int(best_sens['ema2'])},{int(best_sens['ema3'])}) → Sharpe: {best_sens['sharpe']:.3f}")
else:
    print("⚠️ No results available for sensitivity analysis.")
# Out:
# 🔬 Parameter Sensitivity Analysis for Best EMA(7,86,164)
# ================================================================================
#
# 📊 Sensitivity Results (81 variations tested):
#
#     ema1  ema2  ema3    sharpe   sortino  total_return  max_drawdown  volatility  total_trades  win_rate_pct  profit_factor  expectancy
# 0      2    86   164  0.659446  0.892768      2.004780     -0.724110    0.629485             6     33.333333       4.547360    0.415733
# 1      3    86   164  0.559081  0.753364      1.154762     -0.699221    0.635930             5     40.000000       3.444880    0.386767
# 2      4    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 3      5    86   164  0.630888  0.852132      1.733562     -0.699221    0.637703             4     50.000000       4.465391    0.572550
# 4      6    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 21     7    71   164  0.601435  0.811227      1.482211     -0.699221    0.631290             4     50.000000       4.244027    0.466805
# 22     7    72   164  0.601435  0.811227      1.482211     -0.699221    0.631290             4     50.000000       4.244027    0.466805
# 23     7    73   164  0.595197  0.802755      1.431776     -0.699221    0.631360             4     50.000000       4.169029    0.456013
# 24     7    74   164  0.555431  0.746898      1.130101     -0.699221    0.633756             4     50.000000       3.576206    0.432159
# 25     7    75   164  0.576993  0.777551      1.286885     -0.699221    0.635217             4     50.000000       3.803394    0.470270
# 26     7    76   164  0.576841  0.777339      1.285762     -0.699221    0.635179             4     50.000000       3.807084    0.465635
# 27     7    77   164  0.576841  0.777339      1.285762     -0.699221    0.635179             4     50.000000       3.807084    0.465635
# 28     7    78   164  0.576841  0.777339      1.285762     -0.699221    0.635179             4     50.000000       3.807084    0.465635
# 29     7    79   164  0.608226  0.820744      1.535856     -0.699221    0.635980             4     50.000000       4.227274    0.502804
# 30     7    80   164  0.628250  0.848660      1.709939     -0.699221    0.636640             4     50.000000       4.474229    0.541279
# 31     7    81   164  0.623409  0.842076      1.666793     -0.699221    0.636606             4     50.000000       4.393246    0.538407
# 32     7    82   164  0.626588  0.846403      1.695048     -0.699221    0.636631             4     50.000000       4.433203    0.544748
# 33     7    83   164  0.629700  0.850649      1.723009     -0.699221    0.636662             4     50.000000       4.472367    0.550962
# 34     7    84   164  0.617318  0.833688      1.613349     -0.699221    0.636950             4     50.000000       4.279561    0.543813
# 35     7    85   164  0.602845  0.813815      1.490596     -0.699221    0.637302             4     50.000000       4.108110    0.515383
# 51     7    86   149  0.595454  0.803091      1.430949     -0.699221    0.635535             4     50.000000       4.053032    0.484626
# 52     7    86   150  0.595454  0.803091      1.430949     -0.699221    0.635535             4     50.000000       4.053032    0.484626
# 53     7    86   151  0.609452  0.822412      1.546218     -0.699221    0.635877             4     50.000000       4.227227    0.512277
# 54     7    86   152  0.609452  0.822412      1.546218     -0.699221    0.635877             4     50.000000       4.227227    0.512277
# 55     7    86   153  0.623288  0.841913      1.665725     -0.699221    0.636606             4     50.000000       4.391429    0.538342
# 56     7    86   154  0.623409  0.842076      1.666793     -0.699221    0.636606             4     50.000000       4.393246    0.538407
# 57     7    86   155  0.623409  0.842076      1.666793     -0.699221    0.636606             4     50.000000       4.393246    0.538407
# 58     7    86   156  0.626588  0.846403      1.695048     -0.699221    0.636631             4     50.000000       4.433203    0.544748
# 59     7    86   157  0.626588  0.846403      1.695048     -0.699221    0.636631             4     50.000000       4.433203    0.544748
# 60     7    86   158  0.626588  0.846403      1.695048     -0.699221    0.636631             4     50.000000       4.433203    0.544748
# 61     7    86   159  0.629700  0.850649      1.723009     -0.699221    0.636662             4     50.000000       4.472367    0.550962
# 62     7    86   160  0.617052  0.833329      1.611045     -0.699221    0.636951             4     50.000000       4.276343    0.543279
# 63     7    86   161  0.602845  0.813815      1.490596     -0.699221    0.637302             4     50.000000       4.108110    0.515383
# 64     7    86   162  0.602845  0.813815      1.490596     -0.699221    0.637302             4     50.000000       4.108110    0.515383
# 65     7    86   163  0.602845  0.813815      1.490596     -0.699221    0.637302             4     50.000000       4.108110    0.515383
# 5      7    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 66     7    86   165  0.635229  0.859307      1.773871     -0.699221    0.638616             4     50.000000       4.517409    0.581144
# 67     7    86   166  0.635229  0.859307      1.773871     -0.699221    0.638616             4     50.000000       4.517409    0.581144
# 68     7    86   167  0.649242  0.878707      1.906356     -0.699221    0.638914             4     50.000000       4.686423    0.609068
# 69     7    86   168  0.649242  0.878707      1.906356     -0.699221    0.638914             4     50.000000       4.686423    0.609068
# 70     7    86   169  0.646467  0.874981      1.879676     -0.699221    0.638964             4     50.000000       4.649644    0.602992
# 71     7    86   170  0.646467  0.874981      1.879676     -0.699221    0.638964             4     50.000000       4.649644    0.602992
# 72     7    86   171  0.646467  0.874981      1.879676     -0.699221    0.638964             4     50.000000       4.649644    0.602992
# 73     7    86   172  0.689502  0.942286      2.337031     -0.699221    0.645652             4     50.000000       5.732016    0.613066
# 74     7    86   173  0.695663  0.950786      2.406930     -0.699221    0.645701             4     50.000000       5.838056    0.626805
# 75     7    86   174  0.695663  0.950786      2.406930     -0.699221    0.645701             4     50.000000       5.838056    0.626805
# 76     7    86   175  0.695663  0.950786      2.406930     -0.699221    0.645701             4     50.000000       5.838056    0.626805
# 77     7    86   176  0.701527  0.958877      2.474833     -0.699221    0.645752             4     50.000000       5.928358    0.638504
# 78     7    86   177  0.716352  0.979689      2.653064     -0.699221    0.646114             4     50.000000       6.193462    0.672850
# 79     7    86   178  0.668811  0.912219      2.112217     -0.699221    0.648279             4     50.000000       5.398202    0.569819
# 80     7    86   179  0.668811  0.912219      2.112217     -0.699221    0.648279             4     50.000000       5.398202    0.569819
# 36     7    87   164  0.635229  0.859307      1.773871     -0.699221    0.638616             4     50.000000       4.517409    0.581144
# 37     7    88   164  0.649242  0.878707      1.906356     -0.699221    0.638914             4     50.000000       4.686423    0.609068
# 38     7    89   164  0.690003  0.935722      2.330331     -0.699221    0.640247             4     50.000000       5.503297    0.628620
# 39     7    90   164  0.745227  1.020699      3.027487     -0.699221    0.646616             4     50.000000       7.411069    0.664554
# 40     7    91   164  0.732521  1.002978      2.859259     -0.699221    0.646918             4     50.000000       7.164221    0.638966
# 41     7    92   164  0.738668  1.011477      2.940097     -0.699221    0.646966             4     50.000000       7.296757    0.652705
# 42     7    93   164  0.737675  1.010117      2.926936     -0.699221    0.646965             4     50.000000       7.275179    0.650468
# 43     7    94   164  0.738842  1.012048      2.943982     -0.699221    0.647691             4     50.000000       7.334441    0.659174
# 44     7    95   164  0.710115  0.970491      2.580248     -0.699221    0.649617             4     50.000000       6.700651    0.593221
# 45     7    96   164  0.710115  0.970491      2.580248     -0.699221    0.649617             4     50.000000       6.700651    0.593221
# 46     7    97   164  0.706498  0.965521      2.536691     -0.699221    0.649600             4     50.000000       6.542184    0.590700
# 47     7    98   164  0.694031  0.947090      2.391043     -0.699221    0.652046             4     50.000000       6.869493    0.548863
# 48     7    99   164  0.694031  0.947090      2.391043     -0.699221    0.652046             4     50.000000       6.869493    0.548863
# 49     7   100   164  0.761628  1.043901      3.256912     -0.699221    0.646876             4     50.000000      14.195704    0.597123
# 50     7   101   164  0.751234  1.028757      3.117611     -0.699221    0.650692             4     50.000000      13.631525    0.571593
# 6      8    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 7      9    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 8     10    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 9     11    86   164  0.621399  0.839172      1.648771     -0.699221    0.637588             4     50.000000       4.383572    0.525803
# 10    12    86   164  0.621399  0.839172      1.648771     -0.699221    0.637588             4     50.000000       4.383572    0.525803
# 11    13    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 12    14    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 13    15    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 14    16    86   164  0.620506  0.837966      1.640930     -0.699221    0.637588             4     50.000000       4.369050    0.525287
# 15    17    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 16    18    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 17    19    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 18    20    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 19    21    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
# 20    22    86   164  0.603944  0.815301      1.499697     -0.699221    0.637299             4     50.000000       4.123017    0.515983
#
# 📈 Sensitivity Summary (mean / std / min / max):
#                   mean     std      min      max
# sharpe          0.6385  0.0491   0.5554   0.7616
# sortino         0.8653  0.0715   0.7469   1.0439
# total_return    1.8487  0.5066   1.1301   3.2569
# max_drawdown   -0.6995  0.0028  -0.7241  -0.6992
# volatility      0.6394  0.0052   0.6295   0.6520
# win_rate_pct   49.6708  2.1477  33.3333  50.0000
# profit_factor   4.9953  1.7466   3.4449  14.1957
# expectancy      0.5465  0.0594   0.3868   0.6729
#
# 🏆 Best in Sensitivity Test: EMA(7,100,164) → Sharpe: 0.762
